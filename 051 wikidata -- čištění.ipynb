# %%
import os
import json

# %%
with open(os.path.join("wikidata","wiki_ids_raw.json"), "r") as file:
    qecka = json.load(file)

# %% [markdown]
# ## Hledáme blbosti

# %%
qecka
# Out:
# {'Michal Hrůza': ['Q12036727', 'Michal Hrůza', 'Czech singer'],
#  'Kryštof': ['Q1770777', 'Kryštof', 'male given name'],
#  'Chinaski': ['Q2041483', 'Chinaski', 'Czech pop/rock band'],
#  'P!Nk': ['Q160009', 'P!nk', 'US-American singer and songwriter'],
#  'Coldplay': ['Q45188', 'Coldplay', 'British rock band'],
#  'Miro Žbirka': ['Q3509359', 'Miroslav Žbirka', 'Slovak musician (1952–2021)'],
#  'Verona': ['Q2028', 'Verona', 'city in Veneto, northern Italy'],
#  'Support Lesbiens': ['Q1488112', 'Support Lesbiens', 'Czech rock band'],
#  'Ewa Farna': ['Q242302', 'Ewa Farna', 'Polish-Czech singer'],
#  'David Guetta': ['Q8298', 'David Guetta', 'French DJ and record producer'],
#  'Kabát': ['Q938649', 'Kabát', 'Czech rock band'],
#  'No Name': ['Q1264915', 'No Name', 'Montenegrin musical group; boyband'],
#  'Lady Gaga': ['Q19848',
#   'Lady Gaga',
#   'American singer, songwriter, and actress (born 1986)'],
#  'Lucie Bílá': ['Q468282', 'Lucie Bílá', 'Czech singer and actress'],
#  'Maroon 5': ['Q182223', 'Maroon 5', 'American pop rock band'],
#  'Anna K.': ['Q86723556', 'Anna K.', 'refrigerated cargo ship built in 1949'],
#  'Lucie Vondráčková': ['Q2569624',
#   'Lucie Vondráčková',
#   'Czech singer and actress'],
#  'Marek Ztracený': ['Q3551937', 'Marek Ztracený', 'Czech singer and composer'],
#  'Divokej Bill': ['Q2599880', 'Divokej Bill', 'Czech folk rock band'],
#  'Xindl X': ['Q2598276',
#   'Xindl X',
#   'Czech composer, guitarist, scriptwriter and singer'],
#  'Onerepublic': ['Q1438730', 'OneRepublic', 'American pop rock band'],
#  'Tomáš Klus': ['Q1385173',
#   'Tomáš Klus',
#   'Czech actor, pentathlete and singer'],
#  'Rihanna': ['Q36844', 'Rihanna', 'Barbadian singer and actress (born 1988)'],
#  'Mandrage': ['Q602203', 'Mandrage', 'Czech pop rock band'],
#  'Avril Lavigne': ['Q30449', 'Avril Lavigne', 'Canadian singer (born 1984)'],
#  'Katy Perry': ['Q42493',
#   'Katy Perry',
#   'American singer, songwriter, actress and television personality (1984)'],
#  'O5': ['Q6544459',
#   'lieutenant colonel',
#   'military rank of the United States'],
#  'Linkin Park': ['Q261', 'Linkin Park', 'American rock band'],
#  'Jason Derulo': ['Q243639',
#   'Jason Derulo',
#   'American singer-songwriter, dancer and actor'],
#  'Avicii': ['Q505476', 'Avicii', 'Swedish DJ and record producer (1989–2018)'],
#  'Enrique Iglesias': ['Q47122', 'Enrique Iglesias', 'Spanish singer'],
#  'Lucie': ['Q1617357', 'Lucie', 'female given name'],
#  'Mariah Carey': ['Q41076',
#   'Mariah Carey',
#   'American singer and songwriter (born 1969)'],
#  'Eminem': ['Q5608',
#   'Eminem',
#   'American rapper, record producer and actor (born 1972)'],
#  'David Deyl': ['Q5621211', 'David Deyl', 'Czech singer'],
#  'Taylor Swift': ['Q26876',
#   'Taylor Swift',
#   'American singer-songwriter (born 1989)'],
#  'Karel Gott': ['Q333187', 'Karel Gott', 'Czech singer and actor'],
#  'Calvin Harris': ['Q81637',
#   'Calvin Harris',
#   'British DJ, singer and record producer'],
#  'Dan Bárta': ['Q11774157', 'Dan Bárta', 'Czech singer'],
#  'Václav Neckář': ['Q475090', 'Václav Neckář', 'Czech actor and singer'],
#  'Miley Cyrus': ['Q4235',
#   'Miley Cyrus',
#   'American singer, actress, and television personality (born 1992)'],
#  'Ed Sheeran': ['Q47447', 'Ed Sheeran', 'English singer-songwriter'],
#  'Olga Lounová': ['Q12042533',
#   'Olga Lounova',
#   'Czech actress, singer and car racer'],
#  'Sunrise Avenue': ['Q751775', 'Sunrise Avenue', 'Finnish rock band'],
#  'Green Day': ['Q47871', 'Green Day', 'American rock band'],
#  'Imagine Dragons': ['Q391348', 'Imagine Dragons', 'American pop rock band'],
#  'Janek Ledecký': ['Q12023485', 'Janek Ledecký', 'Czech guitarist and singer'],
#  'Ego': ['Q4426116', 'ego', 'self-identity in the psyche'],
#  'Ellie Goulding': ['Q31164',
#   'Ellie Goulding',
#   'English singer and songwriter'],
#  'Ben Cristovao': ['Q11068745',
#   'Ben Cristovao',
#   'Czech actor, presenter, snowboarder, dancer and singer'],
#  'Wham!': ['Q744087', 'Wham!', 'English pop duo'],
#  'Black Eyed Peas': ['Q134541',
#   'Black Eyed Peas',
#   'American hip hop group from California'],
#  'Lana Del Rey': ['Q37150', 'Lana Del Rey', 'American singer (born 1985)'],
#  'Petr Kolář': ['Q7178537', 'Petr Kolář', 'Czech diplomat'],
#  'Shakira': ['Q34424', 'Shakira', 'Colombian singer, songwriter and actress'],
#  'Rybičky 48': [None, None, None],
#  'Justin Bieber': ['Q34086', 'Justin Bieber', 'Canadian singer (born 1994)'],
#  'Selena Gomez': ['Q83287',
#   'Selena Gomez',
#   'American singer and actress (born 1992)'],
#  'Flo Rida': ['Q213538', 'Flo Rida', 'American rapper from Florida'],
#  'Daniel Landa': ['Q159250',
#   'Daniel Landa',
#   'Czech car racer, actor, composer, rally driver and singer'],
#  'Beyoncé': ['Q36153', 'Beyoncé', 'American singer (born 1981)'],
#  'Red Hot Chili Peppers': ['Q10708',
#   'Red Hot Chili Peppers',
#   'American musical group; rock band'],
#  'Mig 21': ['Q150609', 'MiG-21', 'fighter aircraft family by Mikoyan'],
#  'Marpo': ['Q4043742', 'Marpo', 'Czech rapper'],
#  'James Blunt': ['Q130799', 'James Blunt', 'English singer-songwriter'],
#  'Tereza Kerndlová': ['Q203446', 'Tereza Kerndlová', 'Czech singer'],
#  'Robbie Williams': ['Q47875',
#   'Robbie Williams',
#   'British singer-songwriter (born 1974)'],
#  'Billy Mack': ['Q100878487',
#   'Billy Mack',
#   'college basketball player (1989–1989) Long Island University'],
#  'Drake': ['Q7559', 'dragon', 'legendary creature'],
#  'Queen': ['Q116', 'monarch', 'person at the head of a monarchy'],
#  'Lenny': ['Q1667498', 'Lenny', 'male given name'],
#  'Wohnout': ['Q6396977', 'Wohnout', 'Czech rock band'],
#  'Adele': ['Q23215', 'Adele', 'English singer-songwriter (born 1988)'],
#  'Alicia Keys': ['Q121507', 'Alicia Keys', 'American singer'],
#  'Kelly Clarkson': ['Q483507',
#   'Kelly Clarkson',
#   'American singer, songwriter, author, and television personality'],
#  'David Koller': ['Q11774361', 'David Koller', 'Czech musician'],
#  'Bastille': ['Q1865480', 'Bastille', 'former fortress in Paris, France'],
#  'Aneta Langerová': ['Q455191',
#   'Aneta Langerová',
#   'Czech recording artist; singer'],
#  'Eddie Stoilow': ['Q21481397', 'Eddie Stoilow', 'Czech musical group'],
#  'Slza': ['Q21041050', 'Slza', 'Czech band'],
#  'Jelen': ['Q12024449', 'Jelen', 'family name'],
#  'Sia': ['Q181484', 'Sia', 'Australian singer and songwriter'],
#  'Martin Garrix': ['Q14544318',
#   'Martin Garrix',
#   'Dutch DJ and record producer'],
#  'Paulie Garand': ['Q12043983',
#   'Paulie Garand',
#   'Czech music producer and rapper'],
#  'John Lennon': ['Q1203',
#   'John Lennon',
#   'English musician and member of the Beatles (1940–1980)'],
#  'Robin Schulz': ['Q16231940',
#   'Robin Schulz',
#   'German record producer and DJ'],
#  'Madonna': ['Q345', 'Virgin Mary', 'Mother of Jesus'],
#  'Sean Paul': ['Q200577',
#   'Sean Paul',
#   'Jamaican singer, actor and record producer'],
#  'Sam Smith': ['Q15123969', 'Sam Smith', 'English singer and songwriter'],
#  'Chainsmokers': [None, None, None],
#  'Celeste Buckingham': ['Q1093318',
#   'Celeste Buckingham',
#   'Slovak singer and songwriter of Swiss-American origins'],
#  'Michael Bublé': ['Q153694', 'Michael Bublé', 'Canadian singer'],
#  'Kygo': ['Q16845512', 'Kygo', 'Norwegian musician and DJ (born 1991)'],
#  'Rudimental': ['Q50971', 'Rudimental', 'British electronic band'],
#  'Shawn Mendes': ['Q17198340', 'Shawn Mendes', 'Canadian singer'],
#  'Tiësto': ['Q183508', 'Tiësto', 'Dutch DJ and record producer'],
#  'Sebastian': ['Q4844560', 'Sebastian', 'male given name'],
#  'James Arthur': ['Q717626', 'James Arthur', 'English singer and musician'],
#  'Pitbull': ['Q187844', 'Pitbull', 'American singer from Florida'],
#  'Martin Solveig': ['Q359066',
#   'Martin Solveig',
#   'French electro house DJ and producer'],
#  'Ektor': ['Q15534440', 'Ektor', 'Czech rapper'],
#  'Voxel': ['Q663554',
#   'voxel',
#   'element representing a value on a grid in three dimensional space'],
#  'Lily Allen': ['Q58735',
#   'Lily Allen',
#   'English singer, songwriter, author, and television presenter'],
#  'Mirai': ['Q1790116',
#   'Miraí',
#   'Brazilian municipality located in the state of Minas Gerais'],
#  'George Ezra': ['Q15459513', 'George Ezra', 'English singer-songwriter'],
#  'Alle Farben': ['Q15263356', 'Alle Farben', 'German DJ and producer'],
#  'Fergie': ['Q180004', 'Fergie', 'American singer and actress'],
#  'Train': ['Q870',
#   'train',
#   'form of rail transport consisting of a series of connected vehicles'],
#  'Adam Mišík': ['Q10379771',
#   'Adam Mišík',
#   'Czech dubbing actor, guitarist and singer'],
#  'Bruno Mars': ['Q1450',
#   'Bruno Mars',
#   'American singer, songwriter, and record producer'],
#  'Dua Lipa': ['Q21914464',
#   'Dua Lipa',
#   'English and Albanian singer (born 1995)'],
#  'Britney Spears': ['Q11975',
#   'Britney Spears',
#   'American singer and songwriter (born 1981)'],
#  'Justin Timberlake': ['Q43432',
#   'Justin Timberlake',
#   'American singer and actor (born 1981)'],
#  'Bon Jovi': ['Q259254', 'Bon Jovi', 'American rock band'],
#  'Alesso': ['Q965455', 'Alesso', 'Swedish DJ and music producer'],
#  'Nickelback': ['Q483802', 'Nickelback', 'Canadian rock band'],
#  'Michal David': ['Q3506625', 'Michal David', 'Czech composer and singer'],
#  'Bob Sinclar': ['Q223167', 'Bob Sinclar', 'French record producer and DJ'],
#  'Katarína Knechtová': ['Q224559',
#   'Katarína Knechtová',
#   'Slovak singer-songwriter and guitarist'],
#  'Lake Malawi': ['Q5532', 'Lake Malawi', 'African Great Lake'],
#  'Debbi': ['Q739328', 'Debbi', 'German-Czech singer'],
#  'Pil C': ['Q23712816', 'Pil C', 'Slovak rapper'],
#  'Alan Walker': ['Q21808729',
#   'Alan Walker',
#   'Norwegian DJ and music producer'],
#  'Poetika': ['Q50811691',
#   'Jurnal Poetika',
#   'Academic journal published by Universitas Gadjah Mada , covering the subjects:  Language and Literature: Literature (General)'],
#  'Ne-Yo': ['Q193710', 'Ne-Yo', 'American R&B singer'],
#  'Script': ['Q8192',
#   'writing system',
#   'any conventional method of visually representing verbal or signed communication'],
#  'The Weeknd': ['Q2121062',
#   'The Weeknd',
#   'Canadian singer-songwriter (born 1990)'],
#  'Clean Bandit': ['Q11838808',
#   'Clean Bandit',
#   'British electronic music group'],
#  'Demi Lovato': ['Q41173', 'Demi Lovato', 'American singer and actress'],
#  'Twenty One Pilots': ['Q7857806',
#   'Twenty One Pilots',
#   'American musical duo'],
#  'Majk Spirit': ['Q4276957', 'Majk Spirit', 'Slovak rapper'],
#  'Atmo Music': [None, None, None],
#  'Lipo': ['Q898512',
#   'lithium polymer battery',
#   'lithium-ion battery using a polymer electrolyte'],
#  'Rasmus': ['Q485679', 'The Rasmus', 'Finnish rock band'],
#  'Emma Smetana': ['Q11878748', 'Emma Smetana', 'Czech actress and presenter'],
#  'Will.I.Am': ['Q185610',
#   'will.i.am',
#   'American rapper, singer, songwriter and record producer'],
#  'Jonas Blue': ['Q22246459', 'Jonas Blue', 'British DJ and music producer'],
#  'Různí': ['Q115480582',
#   'Ruzniyati binti Mohammad Norwawi',
#   'Daughter of Mohammad Norwawi bin Mohammad Lassim (born 1967)'],
#  'Johny Machette': ['Q15249826', 'Johny Machette', 'Czech rapper'],
#  'Guetta David': [None, None, None],
#  'Viktor Sheen': ['Q75939796', 'Viktor Sheen', 'Czech rapper'],
#  'Little Mix': ['Q158419', 'Little Mix', 'English girl group'],
#  'Lost Frequencies': ['Q18857432', 'Lost Frequencies', 'Belgian DJ'],
#  'Fall Out Boy': ['Q485811', 'Fall Out Boy', 'American pop punk band'],
#  'Alvaro Soler': ['Q20203583', 'Álvaro Soler', 'Spanish-German singer'],
#  'Simple Plan': ['Q485825', 'Simple Plan', 'Canadian rock band'],
#  'U2': ['Q396', 'U2', 'Irish rock band'],
#  'Sigala': ['Q658864', 'Sigale', 'commune in Alpes-Maritimes, France'],
#  'Adam Lambert': ['Q190231', 'Adam Lambert', 'American singer'],
#  'Harry Styles': ['Q3626966',
#   'Harry Styles',
#   'English singer, songwriter, and actor'],
#  'Thirty Seconds To Mars': ['Q40585',
#   'Thirty Seconds to Mars',
#   'American rock band from Los Angeles'],
#  'Sam Feldt': ['Q20972330',
#   'Sam Feldt',
#   'Dutch DJ, record producer and entrepreneur'],
#  'Christina Aguilera': ['Q41594', 'Christina Aguilera', 'American singer'],
#  'Calin': ['Q64785850', 'George A. Calin', 'Molecular Pathology researcher'],
#  'Kylie Minogue': ['Q11998',
#   'Kylie Minogue',
#   'Australian singer and actress (born 1968)'],
#  'Samey': ['Q110746787', 'Samey', 'Slovak rapper'],
#  'Zedd': ['Q21088', 'Zedd', 'Russian-German DJ and music producer'],
#  'Foster The People': ['Q61113', 'Foster the People', 'American rock band'],
#  '5 Seconds Of Summer': ['Q4641147',
#   '5 Seconds of Summer',
#   'Australian pop rock band'],
#  'Shaun Baker': ['Q327220',
#   'Shaun Baker',
#   'English musician, DJ and record producer'],
#  'Inna': ['Q12349', 'Inna', 'Romanian singer'],
#  'Mikolas Josef': ['Q43571872',
#   'Mikolas Josef',
#   'Czech singer-songwriter and former model'],
#  'Swedish House Mafia': ['Q20709',
#   'Swedish House Mafia',
#   'Swedish electronic music group'],
#  'Tata Bojs': ['Q2507263', 'Tata Bojs', 'Czech pop rock band'],
#  'Charli Xcx': ['Q5084390', 'Charli XCX', 'English singer-songwriter'],
#  'Guru Josh Project': [None, None, None],
#  'Nik Tendo': ['Q61666911', 'Nik Tendo', 'Czech rapper'],
#  'Nico Santos': ['Q23806108', 'Nico Santos', 'German singer-songwriter'],
#  'Adam Ďurica': ['Q16515468', 'Adam Ďurica', 'Slovak musician'],
#  'Zara Larsson': ['Q4177928', 'Zara Larsson', 'Swedish singer (born 1997)'],
#  'Seeb': ['Q948050', 'Seeb', 'City in Oman'],
#  'Dara Rolins': ['Q3502562',
#   'Dara Rolins',
#   'Slovak recording artist and entrepreneur'],
#  'Yzomandias': ['Q29066314', 'Yzomandias', 'Czech rapper'],
#  'Nightwork': ['Q7172701', 'Nightwork', 'Czech musical group'],
#  'Škwor': ['Q392143', 'Škwor', 'Czech rock band'],
#  'Hana Zagorová': ['Q3507535', 'Hana Zagorová', 'Czech actress and singer'],
#  'Halsey': ['Q18534249', 'Halsey', 'American singer-songwriter (born 1994)'],
#  'Rita Ora': ['Q229760',
#   'Rita Ora',
#   'British singer, actress, songwriter and model'],
#  'Nelly Furtado': ['Q80424', 'Nelly Furtado', 'Canadian singer'],
#  'Ariana Grande': ['Q151892',
#   'Ariana Grande',
#   'American singer and actress (born 1993)'],
#  'Peter Aristone': ['Q15982799', 'Peter Aristone', 'Slovak singer'],
#  'Mark Ronson': ['Q425821', 'Mark Ronson', 'British musician (born 1975)'],
#  'Jana Kirschner': ['Q575764', 'Jana Kirschner', 'Slovak singer'],
#  'Jaromír Nohavica': ['Q942232',
#   'Jaromír Nohavica',
#   'Czech songwriter, lyricist, and poet'],
#  'Clou': ['Q8074',
#   'cloud',
#   'visible mass of liquid droplets or frozen crystals suspended in the atmosphere'],
#  'Lumineers': ['Q496101', 'The Lumineers', 'American folk rock band'],
#  'Pavel Callta': ['Q20860286', 'Pavel Callta', 'Czech singer, song-writer'],
#  'Marquess': ['Q209726',
#   'marquess',
#   'hereditary rank in various European peerages'],
#  'Felix Jaehn': ['Q18943660', 'Felix Jaehn', 'German DJ and music producer'],
#  'Machine Gun Kelly': ['Q1354843',
#   'Machine Gun Kelly',
#   'American musician (born 1990)'],
#  'Jax Jones': ['Q16995320',
#   'Jax Jones',
#   'English DJ, songwriter, record producer and remixer'],
#  'Macklemore': ['Q484874', 'Macklemore', 'American rapper from Washington'],
#  'Madcon': ['Q842152', 'Madcon', 'Norwegian hip hop duo'],
#  'X Ambassadors': ['Q15963313',
#   'X Ambassadors',
#   'American rock band from Ithaca, New York'],
#  'Lp': ['Q841983', 'LP record', 'longplay record'],
#  'Arash': ['Q236748', 'Arash', 'Iranian singer'],
#  'Jennifer Lopez': ['Q40715', 'Jennifer Lopez', 'American singer and actress'],
#  'Wanastowi Vjecy': ['Q10818511', 'Wanastowi Vjecy', 'Czech rock band'],
#  'Walda Gang': [None, None, None],
#  'Rest': ['Q35831',
#   'sleep',
#   'naturally recurring resting state of mind and body'],
#  'Kanye West': ['Q15935',
#   'Kanye West',
#   'American rapper, singer, and producer (born 1977)'],
#  'Welshly Arms': ['Q28452843', 'Welshly Arms', 'American band'],
#  'Duke Dumont': ['Q9637045', 'Duke Dumont', 'British music producer and DJ'],
#  'Nirvana': ['Q11649', 'Nirvana', 'American rock band'],
#  'Sima': ['Q338009', 'Shima', 'city in Mie Prefecture, Japan'],
#  'Depeche Mode': ['Q482964', 'Depeche Mode', 'British band'],
#  'Alok': ['Q736329', 'Clarias', 'genus of fishes'],
#  'Gleb': ['Q3787148', 'Gleb', 'male given name (Глеб)'],
#  'Usher': ['Q165911', 'Usher', 'American R&B singer (born 1978)'],
#  'Nebe': ['Q1973208', 'Nebe', 'family name'],
#  'Ava Max': ['Q56755505', 'Ava Max', 'American singer and songwriter'],
#  'Niall Horan': ['Q775231', 'Niall Horan', 'Irish singer-songwriter'],
#  'Cascada': ['Q858880', 'Cascada', 'German electronic dance music group'],
#  'Roxette': ['Q173790', 'Roxette', 'Swedish pop duo'],
#  'Sigma': ['Q14413', 'Σ', 'eighteenth letter of the Greek alphabet'],
#  'Louis Tomlinson': ['Q3624971',
#   'Louis Tomlinson',
#   'English singer and songwriter'],
#  'Cruz Taio': [None, None, None],
#  'Gwen Stefani': ['Q483379', 'Gwen Stefani', 'American singer-songwriter'],
#  'Armin Van Buuren': ['Q62617',
#   'Armin van Buuren',
#   'Dutch DJ, record producer and remixer'],
#  'Kali': ['Q51103',
#   'Cali',
#   'capital of the Colombian department of Valle del Cauca'],
#  'Kaiser Chiefs': ['Q192308', 'Kaiser Chiefs', 'English indie rock band'],
#  'Charlie Puth': ['Q19810390',
#   'Charlie Puth',
#   'American singer and songwriter'],
#  'Amy Macdonald': ['Q15902', 'Amy Macdonald', 'Scottish singer-songwriter'],
#  'Aloe Blacc': ['Q49319', 'Aloe Blacc', 'American singer and rapper'],
#  'Smack': ['Q60168',
#   'heroin',
#   'chemical compound; opioid most commonly used as a recreational drug for its euphoric effects'],
#  'Emma Drobná': ['Q27897742', 'Emma Drobná', 'Slovak singer'],
#  'Sergei Barracuda': ['Q20058093', 'Sergei Barracuda', 'Czech rapper'],
#  'Rytmus': ['Q3488250', 'Rytmus', 'Slovak rapper'],
#  'All American Rejects': ['Q214237',
#   'The All-American Rejects',
#   'American rock band'],
#  'Rammstein': ['Q25177', 'Rammstein', 'German rock band'],
#  'Nico': ['Q44634', 'Nico', 'German singer and actress (1938–1988)'],
#  'Martin Jensen': ['Q21039224', 'Martin Jensen', 'Danish DJ and producer'],
#  'Lil Peep': ['Q29388200', 'Lil Peep', 'American rapper'],
#  'R.I.O.': ['Q690183', 'R.I.O.', 'German dance duo (formerly trio)'],
#  'Post Malone': ['Q21621919',
#   'Post Malone',
#   'American rapper, singer, and songwriter'],
#  'Lenka Filipová': ['Q15249858', 'Lenny', 'Czech singer'],
#  'Mista': ['Q1787955', 'Mista', 'Spanish footballer'],
#  'Barbora Poláková': ['Q11052902',
#   'Barbora Poláková',
#   'Czech actress and singer'],
#  'Renne Dang': ['Q29582910', 'Renne Dang', 'Czech rapper'],
#  'Take That': ['Q152066', 'Take That', 'British five-piece vocal pop group'],
#  'Xxxtentacion': ['Q28561969', 'XXXTentacion', 'American rapper (1998–2018)'],
#  'Bebe Rexha': ['Q16185856', 'Bebe Rexha', 'American singer and songwriter'],
#  'Metallica': ['Q15920', 'Metallica', 'American heavy metal band'],
#  'Tinie Tempah': ['Q46321', 'Tinie Tempah', 'English rapper'],
#  'Owl City': ['Q207938',
#   'Owl City',
#   'American electronic musical project by Adam Young'],
#  'Meghan Trainor': ['Q17403494',
#   'Meghan Trainor',
#   'American singer-songwriter (born 1993)'],
#  'Tina': ['Q1670074', 'Tina', 'female given name'],
#  'Marshmello': ['Q26334949', 'Marshmello', 'American music producer and DJ'],
#  'Richard Müller': ['Q1373537',
#   'Richard Müller',
#   'Slovak singer and songwriter'],
#  'Airfare': [None, None, None],
#  'The Silver Spoons': [None, None, None],
#  'Jakub Ondra': ['Q60759671', 'Jakub Ondra', 'Czech singer and songwriter'],
#  'Akon': ['Q32849',
#   'Akon',
#   'Senegalese American singer, songwriter, record producer, and entrepreneur'],
#  'Robin Zoot': [None, None, None],
#  'Earth': ['Q2', 'Earth', 'third planet from the Sun in the Solar System'],
#  'Travis Scott': ['Q13605596',
#   'Travis Scott',
#   'American rapper, singer and record producer (born 1991)'],
#  'Band Aid Ii.': [None, None, None],
#  'Zaz': ['Q167850', 'Zaz', 'French singer; recording artist'],
#  'Milion+': ['Q101418887', 'Milion+ Entertainment', 'Czech hip-hop label'],
#  'Mando Diao': ['Q478814',
#   'Mando Diao',
#   'Swedish musical group; rock band from Borlänge'],
#  'Jay-Z': ['Q62766', 'Jay-Z', 'American rapper and businessman (born 1969)'],
#  'Milow': ['Q674445', 'Milow', 'municipality of Germany'],
#  'Tove Lo': ['Q15948790', 'Tove Lo', 'Swedish singer'],
#  'Olly Murs': ['Q552770', 'Olly Murs', 'British singer'],
#  'Fate Magazine': ['Q3067175',
#   'Fate',
#   'American magazine about paranormal phenomena'],
#  'Route 94': ['Q15920231', 'Route 94', 'British DJ and producer'],
#  'Pharrell Williams': ['Q14313',
#   'Pharrell Williams',
#   'American singer, rapper, producer and songwriter (born 1973)'],
#  'David Stypka': ['Q26677234', 'David Stypka', 'Czech singer'],
#  'Ph Electro': ['Q3359701',
#   'PH Electro',
#   'German disc jockey and record producer'],
#  'Riton': ['Q7336776', 'Riton', 'British DJ and music producer'],
#  'Doctor P.P.': [None, None, None],
#  'Paul Mccartney': ['Q2599',
#   'Paul McCartney',
#   'British rock musician, former member of The Beatles and Wings'],
#  'Nerieš': ['Q108538504', 'Nerieš', 'Slovak musical duo'],
#  "Rag 'N' Bone Man": ['Q26834366',
#   "Rag'n'Bone Man",
#   'British blues and soul singer'],
#  'R3Hab': ['Q3414998', 'R3HAB', 'Dutch-Moroccan DJ and record producer'],
#  'Pussycat Dolls': ['Q102385',
#   'The Pussycat Dolls',
#   'American girl group and dance ensemble'],
#  'Ofenbach': ['Q29380907', 'Ofenbach', 'French house music duo'],
#  'Elán': ['Q222107', 'Elán', 'Slovak pop rock band'],
#  'Offspring': ['Q239526',
#   'offspring',
#   'in biology, the product of reproduction of an organism'],
#  'Dean Lewis': ['Q29905254', 'Dean Lewis', 'Australian singer-songwriter'],
#  'Daddy Yankee': ['Q272591', 'Daddy Yankee', 'Puerto Rican singer'],
#  'Gaudino Alex': [None, None, None],
#  'Dj Antoine': ['Q667014', 'DJ Antoine', 'Swiss record producer and DJ'],
#  'Radůza': ['Q9302686', 'Radůza', 'Czech singer-songwriter and musician'],
#  'Decky': ['Q91078730',
#   'Decky I Junaedi',
#   'researcher (ORCID 0000-0001-5846-6135)'],
#  'Professor Green': ['Q384655',
#   'Professor Green',
#   'English rapper and singer-songwriter'],
#  'Pokáč': ['Q55172176', 'Pokáč', 'Czech singer'],
#  'Dj Fresh': ['Q941738', 'DJ Fresh', 'English DJ and record producer'],
#  'Eric Prydz': ['Q155141', 'Eric Prydz', 'Swedish DJ and record producer'],
#  'One Direction': ['Q146027', 'One Direction', 'English-Irish boy band'],
#  'Dj Wich': ['Q5205502', 'DJ Wich', 'Czech disk jockey'],
#  'Example': ['Q14944328',
#   'example',
#   'thing which acts as a typical representative of a set of things'],
#  'Dermot Kennedy': ['Q61983346', 'Dermot Kennedy', 'Irish singer-songwriter'],
#  'Of Monsters And Men': ['Q509702',
#   'Of Monsters and Men',
#   'Icelandic folk-rock band'],
#  'Duck Sauce': ['Q1165307', 'Duck Sauce', 'DJ duo'],
#  'Timmy White': ['Q19663658', 'Timothy White', 'American kidnap victim'],
#  'Milky Chance': ['Q14623684',
#   'Milky Chance',
#   'German electronic-infused indie pop band based in Kassel'],
#  'Medjmedj Sofian': [None, None, None],
#  'Meduza': ['Q18340732',
#   'Meduza',
#   'Russian bilingual online newspaper headquartered in Riga'],
#  'Team': ['Q327245', 'team', 'group linked in a common purpose'],
#  'Wolf Laurent': [None, None, None],
#  'T.I.': ['Q214227', 'T.I.', 'American rapper and actor'],
#  'Limp Bizkit': ['Q240767', 'Limp Bizkit', 'American rap rock band'],
#  'Bodyrockers': ['Q890054', 'BodyRockers', 'band'],
#  'Alexandra Burke': ['Q234161', 'Alexandra Burke', 'singer'],
#  'Hozier': ['Q16233232', 'Hozier', 'Irish musician'],
#  'Alex Hepburn': ['Q10366783',
#   'Alex Hepburn',
#   'English singer and songwriter'],
#  'Sugababes': ['Q193697', 'Sugababes', 'British pop girl group'],
#  'John Newman': ['Q12433089', 'John Newman', 'British singer-songwriter'],
#  'Stromae': ['Q313453', 'Stromae', 'Belgian singer and producer'],
#  'Mike Posner': ['Q268284', 'Mike Posner', 'American musician'],
#  'Stein27': [None, None, None],
#  'Matt Simons': ['Q4742345',
#   'Matt Simons',
#   'American singer songwriter and musician'],
#  'Linakaro': [None, None, None],
#  'Thom Artway': ['Q29998334', 'Thom Artway', 'Czech singer'],
#  'Těžkej Pokondr': ['Q11837240', 'Těžkej Pokondr', 'Czech musical comedy duo'],
#  'Arakain': ['Q625397', 'Arakain', 'Czech heavy metal band'],
#  'Lykke Li': ['Q270724', 'Lykke Li', 'Swedish singer'],
#  'Jonas Brothers': ['Q134233', 'Jonas Brothers', 'American pop rock band'],
#  'Udg': ['Q1814503',
#   'University of Girona',
#   'public university based in Girona'],
#  'Axwell': ['Q20713', 'Axwell', 'Swedish DJ, remixer and record producer'],
#  'Tři Sestry': ['Q164928', 'Tři sestry', 'Czech punk band'],
#  'B.O.B.': ['Q2876628', 'B.O.B.', '1993 video game'],
#  'Billie Eilish': ['Q29564107',
#   'Billie Eilish',
#   'American singer-songwriter (born 2001)'],
#  'Anne-Marie': ['Q18091413', 'Anne-Marie', 'female given name'],
#  'Junge Junge': ['Q30589129', 'Junge Junge', 'German producer duo'],
#  'Tom Walker': ['Q30122853', 'Tom Walker', 'Scottish singer-songwriter'],
#  'Benassi Bros.': ['Q2895671', 'Benassi Bros.', 'Italian electronica group'],
#  'Timbaland': ['Q179257', 'Timbaland', 'American record producer and rapper'],
#  'Wiley': ['Q1479654', 'Wiley', 'American multinational publishing company'],
#  'Like-It': ['Q61993939', 'Like It', '2019 single by Zinaida Kupriyanovich'],
#  'Kateřina Marie Tichá': ['Q21684336', 'Kateřina Marie Tichá', 'Czech singer'],
#  'Victoria': ['Q36687', 'Victoria', 'state of Australia'],
#  'Lenka': ['Q1865968', 'Lenka', 'female given name'],
#  'Separ': ['Q6130863',
#   'Sociedad Española de Neumología y Cirugía Torácica',
#   'other organization in Barcelona, Spain'],
#  'Naughty Boy': ['Q6981132',
#   'Naughty Boy',
#   'British DJ and musician (born 1985)'],
#  'Kodaline': ['Q2482563', 'Kodaline', 'irish rock band'],
#  'Konex': ['Q115271316', '2K', 'French songwriter, record producer'],
#  'Klingande': ['Q15041224', 'Klingande', 'French DJ and house music producer'],
#  'Cheryl Cole': ['Q212772',
#   'Cheryl',
#   'English singer, dancer, and television presenter'],
#  'Ke$Ha': ['Q33605', 'Kesha', 'American singer and songwriter'],
#  'Lauv': ['Q804970', 'Liu', 'surname (劉/刘)'],
#  'My Chemical Romance': ['Q483285',
#   'My Chemical Romance',
#   'American musical group; rock band'],
#  'Gryffin': ['Q27956380', 'Gryffin', 'American DJ and music producer'],
#  'Muse': ['Q579348', 'alprostadil', 'chemical compound'],
#  'Sheppard': ['Q27429821', 'Sheppard', 'family name'],
#  'Hailee Steinfeld': ['Q231726',
#   'Hailee Steinfeld',
#   'American actress, singer and model'],
#  'Cee-Lo Green': ['Q4042', 'CeeLo Green', 'American singer and rapper'],
#  'Lewis Capaldi': ['Q42315001', 'Lewis Capaldi', 'Scottish singer-songwriter'],
#  'Helena Vondráčková': ['Q288578',
#   'Helena Vondráčková',
#   'Czech recording artist; actress and singer'],
#  'Kristina': ['Q19798802', 'Kristina', 'female given name'],
#  'Ca$Hanova Bulhar': ['Q110270668', 'Cashanova Bulhar', 'Czech rapper'],
#  'Yolanda Be Cool': ['Q1058926', 'Yolanda Be Cool', 'Australian music duo'],
#  'Helena Zeťová': ['Q12019443', 'Helena Zeťová', 'Czech singer'],
#  'Scooter': ['Q193234',
#   'motor scooter',
#   'type of motorcycle with an emphasis on fuel economy and a riding position of sitting upright'],
#  'September': ['Q123',
#   'September',
#   'ninth month in the Julian and Gregorian calendars'],
#  'Mohombi': ['Q379117',
#   'Mohombi',
#   'Congolese-Swedish musician, singer, composer and dancer.'],
#  'Hasan': ['Q13564155', 'Hasan', 'male given name'],
#  'Labello': ['Q1799401', 'Labello', 'brand of lip balm stick'],
#  'Monkey Business': ['Q580022',
#   'Monkey Business',
#   '2005 studio album by Black Eyed Peas'],
#  'Peter Bič Project': ['Q18536373', 'Peter Bič Project', 'musical group'],
#  'Kontrafakt': ['Q1473875', 'Kontrafakt', 'Slovak music group'],
#  'Pop Smoke': ['Q81698554', 'Pop Smoke', 'American rapper (1999–2020)'],
#  'Petr Bende': ['Q95393472', 'Petr Bende', 'Czechoslovak singer'],
#  'Joy Vance': [None, None, None],
#  'Light': ['Q76299',
#   'visible spectrum',
#   'portion of the electromagnetic spectrum that is visible to the human eye'],
#  'Juice Wrld': ['Q52151598',
#   'Juice WRLD',
#   'American rapper and singer (1998–2019)'],
#  'Dynoro': ['Q55006974', 'Dynoro', 'Lithuanian DJ and music producer'],
#  'Kojo': ['Q931600', 'Kojo', 'Finnish singer'],
#  'Lorde': ['Q13476175', 'Lorde', 'New Zealand singer-songwriter (born 1996)'],
#  'Kamakawiwo´ Ole Israel': [None, None, None],
#  'Lmfao': ['Q48978', 'LMFAO', 'American electronic dance music duo'],
#  'Kapitán Demo': ['Q13550846', 'Jiří Burian', 'Czech musician and presenter'],
#  'Kingston Sean': [None, None, None],
#  'Khaled': ['Q312609', 'Khaled', 'Algerian raï musician'],
#  'Elton John': ['Q2808', 'Elton John', 'English singer and pianist'],
#  'Lil Nas X': ['Q62591281',
#   'Lil Nas X',
#   'American rapper and singer (born 1999)'],
#  'Liam Payne': ['Q2756349', 'Liam Payne', 'English singer'],
#  'Karin Ann': ['Q108529528', 'Karin Ann', 'Slovak singer'],
#  'Global Deejays': ['Q877283', 'Global Deejays', 'Austrian band'],
#  'Joel Corry': ['Q67172196',
#   'Joel Corry',
#   'English DJ, producer and television personality'],
#  'Nicky Jam': ['Q1374560', 'Nicky Jam', 'American singer'],
#  'Hodiny': [None, None, None],
#  'Hilson Keri': [None, None, None],
#  'Mk': ['Q221', 'North Macedonia', 'country in southeastern Europe'],
#  'Moby': ['Q14045', 'Moby', 'American musician'],
#  'G-Eazy': ['Q5511893', 'G-Eazy', 'American rapper'],
#  'Hardwell': ['Q923731', 'Hardwell', 'Dutch DJ and music producer'],
#  'Morandi': ['Q904842', 'Morandi', 'pop band from Romania'],
#  'Galantis': ['Q18071093', 'Galantis', 'Swedish electronic music duo'],
#  'Nicki Minaj': ['Q162202',
#   'Nicki Minaj',
#   'Trinidadian-born rapper (born 1982)'],
#  'Joe Face': [None, None, None],
#  'Grey256': [None, None, None],
#  'Natasha Bedingfield': ['Q212906', 'Natasha Bedingfield', 'British singer'],
#  'Nathan Dawe': ['Q91044263', 'Nathan Dawe', 'English DJ and Music Producer'],
#  'Nick Jonas': ['Q201656',
#   'Nick Jonas',
#   'American singer, actor and musician'],
#  'Get Far': ['Q1396608', 'Fargetta', 'Italian musician'],
#  'Nf': ['Q19571648', 'NF', 'American rapper from Michigan'],
#  'Gipsy.Cz': ['Q945417', 'Gipsy.cz', 'band'],
#  'Neiked': ['Q26703294', 'NEIKED', 'Swedish artist collective'],
#  'Milk': ['Q8495',
#   'milk',
#   'white liquid produced by the mammary glands of mammals'],
#  'Olympic': ['Q321007',
#   'RMS Olympic',
#   'Lead ship of the Olympic-Class ocean liners. Sister ship to RMS Titanic and HMHS Britannic'],
#  'Mike Candys': ['Q625246', 'Mike Candys', 'Swiss DJ and record producer'],
#  'Flipsyde': ['Q761385', 'Flipsyde', 'band'],
#  'Mabel': ['Q949355', 'Mabel', 'female given name'],
#  'Far East Movement': ['Q104625', 'Far East Movement', 'band'],
#  'Major Lazer': ['Q2604214',
#   'Major Lazer',
#   'Jamaican-American electronic music band'],
#  'Faul': ['Q56245818', 'Faul', 'family name'],
#  'Panic! At The Disco': ['Q277551',
#   'Panic! At The Disco',
#   'American musical group; rock solo project band'],
#  'Jason Mraz': ['Q192515', 'Jason Mraz', 'American singer-songwriter'],
#  'Marlon Roudette': ['Q21076',
#   'Marlon Roudette',
#   'English singer and songwriter'],
#  'James Harries': ['Q75297546', 'James Hugh Harries', '(born 1972)'],
#  'Jamelia': ['Q234199', 'Jamelia', 'British singer'],
#  'Nelly': ['Q218992',
#   'Nelly',
#   'American rapper, singer, songwriter and entrepreneur'],
#  'J.A.R.': ['Q933794', 'J.A.R.', 'single'],
#  'Martin Harich': ['Q12035723', 'Martin Harich', 'Slovak singer'],
#  'Matej Smutný': [None, None, None],
#  'Outkast': ['Q472595', 'OutKast', 'American hip hop duo'],
#  'Otto Knows': ['Q400094', 'Otto Knows', 'Swedish DJ'],
#  'Hurts': ['Q493042', 'Hurts', 'English synthpop duo'],
#  'Hugo Toxxx': ['Q12020903', 'Hugo Toxxx', 'Czech rapper'],
#  'Mika': ['Q186329', 'Mika', 'British-Lebanese singer'],
#  'Kungs': ['Q23826199', 'Kungs', 'French DJ, record producer and musician'],
#  'Dorian': ['Q909104', 'Dorian', 'male given name'],
#  'Dennis Lloyd': ['Q51033104', 'Dennis Lloyd', 'Israeli singer-songwriter'],
#  'Remady': ['Q503925', 'Remady', 'Swiss music producer'],
#  'Anna Jiřina': ['Q81906077',
#   'Anna Jiřina Pavlasová',
#   'Czech ice hockey player'],
#  'Tereza Mašková': ['Q90726700',
#   'Tereza Mašková',
#   'researcher (ORCID 0000-0001-8386-5146)'],
#  'Regard': ['Q70912825', 'Regard', 'Kosovo-Albanian DJ and record producer'],
#  'Walk The Moon': ['Q3653206', 'Walk the Moon', 'American pop/rock band'],
#  'Coco Jambo': [None, None, None],
#  'Ready Kirken': ['Q7238093',
#   'Ready Kirken',
#   'musical group from the Czech Republic'],
#  'The Faim': ['Q60846768', 'The Faim', 'Australian rock band'],
#  'Andrea Bocelli': ['Q42402',
#   'Andrea Bocelli',
#   'Italian tenor and singer-songwriter (1958-)'],
#  'Wanted': ['Q4444', 'Wanted', '2008 film directed by Timur Bekmambetov'],
#  'Tate Mcrae': ['Q95129121', 'Tate McRae', 'Canadian singer and songwriter'],
#  'Dido': ['Q905162', 'Dido', 'legendary founder and first queen of Carthage'],
#  'Scherzinger Nicole': [None, None, None],
#  'Alexandra Stan': ['Q1453', 'Alexandra Stan', 'Romanian singer'],
#  'Blackbear': ['Q22974007', 'Blackbear', 'American singer'],
#  'Vladimír Mišík': ['Q762854',
#   'Vladimír Mišík',
#   'Czech member of Czech National Council, guitarist and singer'],
#  'Dione Aura': [None, None, None],
#  'Ting Tings': ['Q219939', 'The Ting Tings', 'English musical duo'],
#  'Topic': ['Q2751586',
#   'resolution',
#   'written declaration adopted by a deliberative body'],
#  'Tones And I': ['Q62887629',
#   'Tones and I',
#   'Australian singer, songwriter and record producer'],
#  'Troye Sivan': ['Q1362028',
#   'Troye Sivan',
#   'Australian singer-songwriter, actor and YouTuber'],
#  'Twiins': ['Q539894', 'TWiiNS', 'Slovak musical group; twin pop duo'],
#  'Rodan': ['Q30755', 'Auguste Rodin', 'French sculptor'],
#  'Becky Hill': ['Q16236194', 'Becky Hill', 'English singer and songwriter'],
#  'D.H.T.': ['Q1755076', 'DHT', 'Belgian eurodance band'],
#  'Deaf Heart': [None, None, None],
#  'Robin Mood': [None, None, None],
#  'Czech It': [None, None, None],
#  'Atb': ['Q855199',
#   'CD Atlético Baleares',
#   'association football club in Palma, Majorca, Spain'],
#  'Ryan Kate': [None, None, None],
#  'Tiggi Hawke': [None, None, None],
#  'Craig David': ['Q154222', 'Craig David', 'British singer (born 1981)'],
#  'Digital Fever': ['Q58548836',
#   "Digital fever: A scholar's copyright dilemma1",
#   'article'],
#  'Amy Winehouse': ['Q15897',
#   'Amy Winehouse',
#   'British singer and songwriter (1983–2011)'],
#  'Zayn': ['Q3626950', 'Zayn Malik', 'English singer'],
#  'R.E.M.': ['Q134969', 'R.E.M.', 'American rock band (1980–2011)'],
#  'Camila Cabello': ['Q18810940',
#   'Camila Cabello',
#   'Cuban-Mexican-American singer, actress and songwriter'],
#  'Shaggy': ['Q310763', 'Shaggy', 'Jamaican reggae musician'],
#  'Za100Let': [None, None, None],
#  'Purple Disco Machine': ['Q61746813',
#   'Purple Disco Machine',
#   'German DJ and record producer'],
#  'Chris Brown': ['Q155700', 'Chris Brown', 'American R&B singer (born 1989)'],
#  'Zoe Wees': ['Q96119730', 'Zoe Wees', 'German singer'],
#  'Sensey': ['Q30263181',
#   'SENSEYE LIMITED',
#   'company in Southampton, United Kingdom'],
#  'Shayne Ward': ['Q266091', 'Shayne Ward', 'English singer'],
#  'Dms': ['Q831677',
#   'document management system',
#   'software that provides an automated way to store, manage and track electronic documents'],
#  '50 Cent': ['Q6060', '50 Cent', 'American rapper and actor (born 1975)'],
#  'Čechomor': ['Q2424041', 'Čechomor', 'Czech traditional music band'],
#  'Afrojack': ['Q349041', 'Afrojack', 'Dutch DJ and record producer'],
#  'Seal': ['Q162919',
#   'seal',
#   'mark of a personal distinctive emblem intended to guarantee the authenticity of the author of a document onto which it is printed, embossed or affixed'],
#  'Sto Zvířat': ['Q7617750', 'Sto zvířat', 'Czech ska and reggae band'],
#  '24Kgoldn': ['Q83751918', '24kGoldn', 'American rapper and singer'],
#  'Years': ['Q24564698', 'years old', 'unit for age'],
#  'Snoop Dogg': ['Q6096', 'Snoop Dogg', 'American rapper (born 1971)'],
#  'Carly Rae Jepsen': ['Q52583',
#   'Carly Rae Jepsen',
#   'Canadian singer and songwriter'],
#  'Biffy Clyro': ['Q858365', 'Biffy Clyro', 'Scottish rock band'],
#  'Markéta Konvičková': ['Q12035611', 'Markéta Konvičková', 'Czech singer'],
#  'Hana Hegerová': ['Q82688',
#   'Hana Hegerová',
#   'Czech actress, singer and chansonier'],
#  'Jackson Michael': ['Q3701494', 'Dane', 'comic character'],
#  'Sigrid': ['Q634916', 'Sigrid', 'female given name'],
#  'Momo': ['Q22508', 'Momo', 'Italian comune in Piedmont'],
#  'Tokio Hotel': ['Q386216', 'Tokio Hotel', 'German pop band'],
#  'Marta Jandová': ['Q470233', 'Marta Jandová', 'Czech singer'],
#  'Beatles': ['Q1299', 'The Beatles', 'English rock band (1960–1970)'],
#  'Basto!': ['Q810666', 'Basto', 'Belgian musician and DJ'],
#  'Tom Grennan': ['Q54357938', 'Tom Grennan', 'English singer-songwriter'],
#  'Hard Rico': [None, None, None],
#  'Tim Berg': ['Q505476',
#   'Avicii',
#   'Swedish DJ and record producer (1989–2018)'],
#  'Timmy Trumpet': ['Q7806850',
#   'Timmy Trumpet',
#   'Australian house DJ and producer'],
#  'Jan Kalousek': ['Q12022644', 'Jan Kalousek', 'Czech actor and singer'],
#  'Monika Absolonová': ['Q3508501',
#   'Monika Absolonová',
#   'Czech singer and actress'],
#  'Markéta': ['Q17457234', 'Markéta', 'female given name'],
#  'Basshunter': ['Q383541',
#   'Basshunter',
#   'Swedish singer, record producer and DJ'],
#  'Prago Union': ['Q3502494', 'Prago Union', 'Czech band'],
#  'Big Ali': ['Q858418', 'Big Ali', 'American singer, rapper and songwriter'],
#  'Mena Maria': [None, None, None],
#  'Michael Schulte': ['Q1242168',
#   'Michael Schulte',
#   'German singer-songwriter'],
#  'Michael Jackson': ['Q2831',
#   'Michael Jackson',
#   'American singer, songwriter, and dancer (1958–2009)'],
#  'Mike Shinoda': ['Q19201', 'Mike Shinoda', 'American musician'],
#  'Bts': ['Q13580495', 'BTS', 'South Korean musical group; boy band'],
#  'Icona Pop': ['Q808703', 'Icona Pop', 'Swedish DJ duo'],
#  'Michael Burian': [None, None, None],
#  'Sparks Jordin': [None, None, None],
#  'Blur': ['Q485820', 'Blur', 'English alternative rock band'],
#  'Imanbek': ['Q83688261', 'Imanbek', 'Kazakh record producer'],
#  'Banners': ['Q22276958', 'Banners', 'English musician'],
#  'Imany': ['Q115206', 'Imany', 'French pop-soul singer'],
#  'Mimi Webb': ['Q106613064', 'Mimi Webb', 'English singer and songwriter'],
#  'Buty': ['Q3563284', 'Buty', 'Czech musical group'],
#  'Melanie C': ['Q151830', 'Melanie C', 'British singer'],
#  'Indy': ['Q6346',
#   'Indianapolis',
#   'city in and county seat of Marion County, Indiana, United States and the Indiana federated state capital city'],
#  'Burak Yeter': ['Q19668785', 'Burak Yeter', 'Turkish musician'],
#  'Mind Michael': [None, None, None],
#  'Minelli': ['Q37543529', 'Minelli', 'family name'],
#  'Ingrosso Sebastian': [None, None, None],
#  'The Carsleepers': [None, None, None],
#  'Mccoy Travie': [None, None, None],
#  'Snow Patrol': ['Q188407',
#   'Snow Patrol',
#   'Northern Irish-Scottish rock band'],
#  'Bodybangers': ['Q890089', 'Bodybangers', 'german dance band'],
#  'Iveta Bartošová': ['Q3270208', 'Iveta Bartošová', 'Czech singer'],
#  'Marcell': ['Q27553744', 'Marcell', 'male given name'],
#  'Avidan Asaf': [None, None, None],
#  'Mans Zelmerlöw': ['Q372460',
#   'Måns Zelmerlöw',
#   'Swedish singer and television presenter'],
#  'Alessia Cara': ['Q20090091',
#   'Alessia Cara',
#   'Canadian-Italian singer and songwriter'],
#  'Kelis': ['Q294979', 'Kelis', 'American singer'],
#  'Ajr': ['Q1430874', 'Arvidsjaur Airport', 'airport'],
#  'Alanis Morissette': ['Q130742',
#   'Alanis Morissette',
#   'Canadian-American singer (born 1974)'],
#  'Alec Benjamin': ['Q19560068', 'Alec Benjamin', 'American singer-songwriter'],
#  'Kateřina Brožová': ['Q455170',
#   'Kateřina Brožová',
#   'Czech actress, singer and presenter'],
#  'Alesha Dixon': ['Q19182',
#   'Alesha Dixon',
#   'British singer, rapper and dancer'],
#  'Alex C.': ['Q61986',
#   'Alex Christensen',
#   'German composer, producer, and DJ'],
#  'Leoš Mareš': ['Q1954437', 'Leoš Mareš', 'Czech presenter and singer'],
#  'Lilly Wood': ['Q3240920',
#   'Lilly Wood and the Prick',
#   'French pop folk collective'],
#  'Wolf Karl': [None, None, None],
#  'Wiz Khalifa': ['Q117139', 'Wiz Khalifa', 'American rapper and singer'],
#  'All Time Low': ['Q909731', 'All Time Low', 'American rock band'],
#  'Alma': ['Q656870', 'Alma', 'female given name'],
#  'Westlife': ['Q151241', 'Westlife', 'Irish boy band'],
#  'Agnes': ['Q394431', 'Agnes', 'female given name'],
#  'Leona Lewis': ['Q183519', 'Leona Lewis', 'British singer'],
#  'Toxique': ['Q12059454', 'Toxique', 'Czech musical group'],
#  'Lany': ['Q1852483',
#   'Lány',
#   'village in Kladno District of Central Bohemian region'],
#  'K´ Naan': [None, None, None],
#  'Labrinth': ['Q48959', 'Labrinth', 'English singer and rapper'],
#  '58G': ['Q61667270',
#   'Washington County Regional Medical Center heliport',
#   'heliport in Washington County, Georgia, United States'],
#  'Koky': ['Q15208105', 'Koky', 'family name'],
#  'Kokab': ['Q4260626', 'Kokabiel', 'fallen angel in the Hebrew bible'],
#  '6Ix9Ine': ['Q44479972',
#   '6ix9ine',
#   'American rapper from New York (born. 1996)'],
#  'Last Goodnight': [None, None, None],
#  'Kid Laroi': [None, None, None],
#  'Zayo': ['Q428311',
#   'Józef Zajączek',
#   'Polish general and politician (1752-1826)'],
#  'A$Ap Rocky': ['Q129910',
#   'A$AP Rocky',
#   'American rapper and record producer'],
#  'Le Monde': ['Q12461',
#   'Le Monde',
#   'French daily evening newspaper founded in 1944'],
#  'Lenka Dusilová': ['Q3490011', 'Lenka Dusilová', 'Czech musician'],
#  'Killers': ['Q275550', 'Killers', '1981 studio album by Iron Maiden'],
#  'Yungblud': ['Q47500295', 'Yungblud', 'English musician'],
#  'Logic': ['Q8078', 'logic', 'study of correct reasoning'],
#  'Anastacia': ['Q34584', 'Anastacia', 'American singer'],
#  'Loreen': ['Q483376', 'Loreen', 'Swedish singer and songwriter'],
#  'Jess Glynne': ['Q15744507', 'Jess Glynne', 'British singer'],
#  'Vadak': [None, None, None],
#  'Jitka Zelenková': ['Q12024968', 'Jitka Zelenková', 'Czech singer'],
#  'Avener': ['Q4828049', 'Avener', 'chief officer of the stables of a king'],
#  'Mr. Probz': ['Q2750788',
#   'Mr. Probz',
#   'Dutch singer, producer, musician and actor'],
#  'Maduar': ['Q60376371', 'Maduarchak', 'village in Bankura district'],
#  'Jessie J.': ['Q69773990',
#   'Jessie J. Edwards Public Library',
#   'public library in Coldwater, Mississippi, USA'],
#  'Twocolors': ['Q98910385', 'Twocolors', 'German electronic dance band'],
#  'Justin Jesso': ['Q44068438', 'Justin Jesso', 'Norwegian singer'],
#  'Backstreet Boys': ['Q17140', 'Backstreet Boys', 'American boy band'],
#  'Jc Stewart': ['Q105103226', 'JC Stewart', 'singer'],
#  'Bakermat': ['Q13383449', 'Bakermat', 'Dutch DJ and record producer'],
#  'Traktor': ['Q1985954', 'Torpedo Olleart FC', 'Russian football club'],
#  'Maneskin': ['Q56884561', 'Måneskin', 'Italian rock band'],
#  'Maniak': ['Q36913816', 'Maniak', 'family name'],
#  'Jiří Schelinger': ['Q1082574',
#   'Jiří Schelinger',
#   'Czech musician (1951-1981)'],
#  'Velile': ['Q567793', 'Velile', 'South African actor'],
#  'Lvcas Dope': ['Q58875497', 'Lvcas Dope', 'Czech singer'],
#  'Lunchmoney Lewis': ['Q19669354',
#   'LunchMoney Lewis',
#   'American singer and songwriter'],
#  'Lumidee': ['Q272244', 'Lumidee', 'American singer and rapper'],
#  'Vize': ['Q65246672', 'Vize', 'German electro house band'],
#  'Lukas Graham': ['Q300935', 'Lukas Graham', 'Danish band'],
#  'Luis Fonsi': ['Q1387726', 'Luis Fonsi', 'Puerto Rican singer'],
#  'Vojtěch Dyk': ['Q11925857', 'Vojtěch Dyk', 'Czech actor'],
#  'Annabelle': ['Q15816857', 'Annabelle', 'female given name'],
#  'Anna Naklab': ['Q20061746', 'Anna Naklab', 'German female singer'],
#  'Jp Cooper': ['Q27807517', 'JP Cooper', 'British musician'],
#  'Lucas': ['Q320980', 'Lucas van Leyden', 'artist, painter (1494-1533)'],
#  'Andy Grammer': ['Q4299814', 'Andy Grammer', 'American singer-songwriter'],
#  'Julia Michaels': ['Q20051697', 'Julia Michaels', 'American singer'],
#  'Walking On Cars': ['Q18712621', 'Walking on Cars', 'Irish rock band'],
#  'Andrews Michael': [None, None, None],
#  'Shouse': ['Q56245135', 'Shouse', 'family name'],
#  'Lady Sovereign': ['Q230754',
#   'Lady Sovereign',
#   'English rapper and grime artist'],
#  'Colbie Caillat': ['Q228860', 'Colbie Caillat', 'American singer-songwriter'],
#  'Pink Floyd': ['Q2306', 'Pink Floyd', 'English rock band'],
#  'Neon Trees': ['Q1508269', 'Neon Trees', 'American band'],
#  'Evanescence': ['Q1777698',
#   'Evanescence',
#   'American rock band from Little Rock'],
#  'Reamonn': ['Q101592', 'Reamonn', 'German rock band'],
#  'Gnarls Barkley': ['Q726773', 'Gnarls Barkley', 'American soul duo'],
#  'Desmod': ['Q2218009', 'Desmod', 'Slovak pop-rock band'],
#  'Good Charlotte': ['Q485220', 'Good Charlotte', 'American rock band'],
#  'Novaspace': ['Q458579', 'Novaspace', 'band'],
#  'Dj Khaled': ['Q80805', 'DJ Khaled', 'American DJ and music producer'],
#  'Disclosure': ['Q1228440', 'Disclosure', 'English electronic music duo'],
#  'Nykki': [None, None, None],
#  'Dalyb': ['Q1958225', 'Ivan Vahylevych', 'Ukrainian poet'],
#  'Passenger': ['Q319604',
#   'passenger',
#   'person who travels in a vehicle without operating it'],
#  'D.Y.K.': ['Q61657631', 'Deryck Chan', 'researcher, Wikimedian'],
#  'Plain White T´S': ['Q169316', "Plain White T's", 'American band'],
#  'Dj Snake': ['Q16728588', 'DJ Snake', 'French DJ and record producer'],
#  'Gorillaz': ['Q189991', 'Gorillaz', 'English virtual band'],
#  'Sarah Connor': ['Q63664', 'Sarah Connor', 'German singer'],
#  'Petr Muk': ['Q3086091',
#   'Petr Muk',
#   'Czech pop musician, composer, and performer (1965-2010)'],
#  'Gotye': ['Q489643', 'Gotye', 'Australian musician'],
#  'Rowland Kelly': [None, None, None],
#  'Gabriella Cilmi': ['Q234767', 'Gabriella Cilmi', 'Australian singer'],
#  'Gabriela Gunčíková': ['Q3496995', 'Gabriela Gunčíková', 'Czech singer'],
#  'Gayle': ['Q1417358', 'Gayle', 'unisex given name'],
#  'Razorlight': ['Q913779', 'Razorlight', 'English rock band'],
#  'Ray Dalton': ['Q13426816', 'Ray Dalton', 'American singer'],
#  'Daft Punk': ['Q185828', 'Daft Punk', 'French electronic music band'],
#  'Peha': ['Q1632697', 'Peha', 'Slovak band'],
#  'Sam Fischer': ['Q86749847',
#   'Sam Fischer',
#   'Australian singer-songwriter and musician'],
#  'Cobra Starship': ['Q524822', 'Cobra Starship', 'American band'],
#  'Dalibor Janda': ['Q836436',
#   'Dalibor Janda',
#   'Czech composer, lyricist and singer (*1953)'],
#  'Conan Gray': ['Q65214814', 'Conan Gray', 'American singer-songwriter'],
#  'Diplo': ['Q533781', 'Diplo', 'American DJ and music producer'],
#  'Fun.': ['Q838984', 'Fun', 'American indie rock band'],
#  'Pavol Habera': ['Q578393', 'Pavol Habera', 'Slovak musician and actor'],
#  'Sandro Cavazza': ['Q26258299',
#   'Sandro Cavazza',
#   'Swedish singer-songwriter'],
#  'Petr Kotvald': ['Q473120', 'Petr Kotvald', 'Czech singer'],
#  'Daniel Powter': ['Q313698', 'Daniel Powter', 'Canadian musician and singer'],
#  'Gabry Ponte': ['Q468692', 'Gabry Ponte', 'Italian DJ and record producer'],
#  'Natalia Imbruglia': ['Q488353',
#   'Natalie Imbruglia',
#   'Australian singer and actress'],
#  'Celine Dion': ['Q5105', 'Céline Dion', 'Canadian singer (born 1968)'],
#  'Duffy': ['Q192587', 'Duffy', 'Welsh singer-songwriter'],
#  'Progres 2': ['Q3502525', 'Progres 2', 'Czech progressive rock band'],
#  'Daya': ['Q21005558', 'Daya', 'American singer'],
#  'Guetta David Vs. The Egg': [None, None, None],
#  'Onemanshow Foundation': [None, None, None],
#  'Gromee': ['Q28672611', 'Gromee', 'Polish DJ, music producer, lyricist'],
#  'Palaye Royale': ['Q48699789',
#   'Palaye Royale',
#   'Canadian-American rock band'],
#  'Fifth Harmony': ['Q3087893', 'Fifth Harmony', 'American girl group'],
#  'Edward Maya': ['Q317169',
#   'Edward Maya',
#   'Romanian singer, record producer and DJ'],
#  'Don Omar': ['Q310539', 'Don Omar', 'Puerto Rican singer'],
#  'Popcorn Drama': [None, None, None],
#  'Dollar Prync': [None, None, None],
#  'Doja Cat': ['Q51120673',
#   'Doja Cat',
#   'American rapper, singer-songwriter, and record producer (born 1995)'],
#  'E2 Crew': [None, None, None],
#  'P T K': ['Q47749550', 'Praveen T. Krishnamurthy', 'researcher'],
#  'Djane Housekat': ['Q106352',
#   'DJane HouseKat',
#   'Danish singer, songwriter, DJ, music producer'],
#  'Ronan Keating': ['Q311467', 'Ronan Keating', 'Irish singer and songwriter'],
#  'Gym Class Heros': [None, None, None],
#  'Pam Rabbit': [None, None, None],
#  'Christina Perri': ['Q229341',
#   'Christina Perri',
#   'American singer-songwriter'],
#  'Deethane': ['Q69481982', 'DeeThane', 'Czech streamer'],
#  'Olivia Rodrigo': ['Q63243883',
#   'Olivia Rodrigo',
#   'American singer and actress (born 2003)'],
#  'Scissor Sisters': ['Q464109', 'Scissor Sisters', 'American pop/rock band'],
#  'Paramore': ['Q473466', 'Paramore', 'American rock band'],
#  'Nea': ['Q217526',
# ...
#  'Spirituál Kvintet': ['Q3564752', 'Spirituál kvintet', 'Czech folk band'],
#  'Schyzo': ['Q50981751', 'Schyzo', 'Czech rapper'],
#  'Nela': ['Q18086568', 'Nela', 'female given name'],
#  'Saul': ['Q9200',
#   'Paul the Apostle',
#   'Early Christian apostle and missionary (c. AD 5 – c. 64/65)'],
#  'Michael Foret': ['Q12036625', 'Michael Foret', 'Czech singer'],
#  'Nena': ['Q153996', 'Nena', 'German singer and actress'],
#  'Metro Station': ['Q928830',
#   'metro station',
#   'railway station of a rapid transit system'],
#  'Metro Boomin': ['Q16235273',
#   'Metro Boomin',
#   'American record producer, DJ, and record executive'],
#  'Nerez': [None, None, None],
#  'Tatu': ['Q161723', 't.A.T.u.', 'Russian music duo'],
#  'Santana': ['Q873384', 'Santana', 'American band led by Carlos Santana'],
#  'Nessa Barrett': ['Q107413717', 'Nessa Barrett', 'American singer'],
#  'Starley': ['Q28054068', 'Starley', 'Australian singer'],
#  'Spice Girls': ['Q55641', 'Spice Girls', 'British girl group'],
#  'Verve': ['Q16682455',
#   'Verve',
#   'French magazine devoted to art and literature'],
#  'Simon From Deep Divas': [None, None, None],
#  'Shifty': ['Q21528271', 'Shifty', 'Happy Tree Friends character'],
#  'Morrison James': [None, None, None],
#  'Shimmi': ['Q26444682', 'Shinmi', 'Japanese family name (人見)'],
#  'Showtek': ['Q1067714',
#   'Showtek',
#   'Dutch electronic dance music sibling duo'],
#  'Sheen': ['Q2303477',
#   'Sheen',
#   'village and civil parish in Staffordshire, England'],
#  'Monika Bagárová': ['Q62081535', 'Monika Bagárová', 'Czech Romani singer'],
#  'Mustard': ['Q58677', 'Brassica', 'genus of plants'],
#  'Shawn Hook': ['Q18357706',
#   'Shawn Hook',
#   'Canadian singer, songwriter, producer'],
#  'Sia Diplo Labrinth': [None, None, None],
#  'Molly Petersson Hammar': [None, None, None],
#  'Sharkass': ['Q21685625', 'Sharkass', 'Czech rapper'],
#  'Sinclair Didier': [None, None, None],
#  'Nayer': ['Q166444', 'Nayer', 'American singer'],
#  'Skyline': ['Q43261',
#   'horizon',
#   'apparent line that separates earth from sky'],
#  'Slash': ['Q34166', 'Slash', 'British-American guitarist'],
#  'Mo': ['Q105', 'Monday', 'day of the week'],
#  'Mnek': ['Q6716905',
#   'MNEK',
#   'English singer, songwriter and record producer'],
#  'Snakehips': ['Q22116844', 'Snakehips', 'British electronic music band'],
#  'Mňága': ['Q3490405', 'Mňága a Žďorp', 'Czech alternative rock band'],
#  'Shaed': ['Q60643444', 'Shaed', 'American musical group'],
#  'Spankers': ['Q11312712', 'Spankers', 'Italian DJ duo'],
#  'Nathan Evans': ['Q105044427', 'Nathan Evans', 'Scottish musician'],
#  'Mimoza': ['Q20000751', 'Mimoza', 'female given name'],
#  'Serebro': ['Q318882', 'Serebro', 'Russian pop girl group'],
#  'Tavares David': [None, None, None],
#  'Teló Michel': [None, None, None],
#  'Samson Sidney': [None, None, None],
#  'Roll Deep': ['Q913194', 'Roll Deep', 'British hip hop group'],
#  'Tony Bennett': ['Q296729', 'Tony Bennett', 'American singer'],
#  'Tool': ['Q39546',
#   'tool',
#   'physical item that can be used to achieve a goal'],
#  'Notd': ['Q55624499', 'NOTD', 'Swedish production duo'],
#  'Torrini Emiliana': [None, None, None],
#  'Oceana': ['Q148360', '224 Oceana', 'main-belt asteroid'],
#  'Rosa Linn': ['Q111193171', 'Rosa Linn', 'armenisk singer-songwriter'],
#  'Ropero Jerry': [None, None, None],
#  'Rooney': ['Q16882268', 'Rooney', 'surname of Irish origins'],
#  'Tribbs': [None, None, None],
#  'Oliver Heldens': ['Q16667903', 'Oliver Heldens', 'Dutch DJ'],
#  'Moss Kena': [None, None, None],
#  'Omi': ['Q1336967',
#   'Missionary Oblates of Mary Immaculate',
#   'Catholic missionary congregation for men'],
#  'Nick Cave': ['Q192668', 'Nick Cave', 'Australian musician'],
#  'Maitre Gims': ['Q3303251',
#   'Gims',
#   'Congolese-French singer-songwriter and rapper'],
#  'Robyn': ['Q229445', 'Robyn', 'Swedish singer (born 1979)'],
#  'Magic!': ['Q16596856', 'Magic!', 'Canadian reggae-pop band'],
#  'Roby Lion': [None, None, None],
#  'Ondřej Brzobohatý': ['Q12042658',
#   'Ondřej Brzobohatý',
#   'Czech actor, composer, keyboard player and presenter (*1983)'],
#  'Robin Thicke': ['Q467423',
#   'Robin Thicke',
#   'American singer, songwriter, and record producer'],
#  'One Night Band': [None, None, None],
#  'Orrico Stacie': [None, None, None],
#  'Robert Plant': ['Q428223',
#   'Robert Plant',
#   'English musician and lead vocalist of Led Zeppelin'],
#  'M.I.A.': ['Q204019', 'M.I.A.', 'British rapper (born 1975)'],
#  'Veronicas': ['Q721992', 'The Veronicas', 'Australian pop duo'],
#  'Marie Rottrová': ['Q3512331',
#   'Marie Rottrová',
#   'Czech actress, presenter, singer, composer and lyricist'],
#  'Marián Vojtko': ['Q12035361',
#   'Marian Vojtko',
#   'Slovak actor, opera singer and singer'],
#  'Normandie': ['Q18677875', 'Normandy', 'region of France'],
#  'Mark Dann': [None, None, None],
#  'Mcclarnon Liz': [None, None, None],
#  'Mattafix': ['Q21075', 'Mattafix', 'British duo'],
#  'Matrix': ['Q44337',
#   'matrix',
#   'rectangular array of numbers, symbols, or expressions, arranged in rows and columns'],
#  'Sam And The Womp': ['Q2115414',
#   'Sam and the Womp',
#   'three piece music group from the United Kingdom'],
#  'Masked Wolf': ['Q105490126', 'Masked Wolf', 'Australian rapper'],
#  'Martin Tungevaag': ['Q17319322',
#   'Martin Tungevaag',
#   'Norwegian DJ and producer'],
#  'Sabaton': ['Q740159', 'Sabaton', 'Swedish power metal band'],
#  'Nicky Romero': ['Q260214',
#   'Nicky Romero',
#   'Dutch DJ, record producer and remixer'],
#  'Thomas Gold': ['Q93562',
#   'Thomas Gold',
#   'Austrian astrophysicist (1920-2004)'],
#  'Thxsomch': ['Q118143958', 'ThxSoMch', 'musical artist'],
#  'Rumpál': ['Q12050356', 'Rumpál', 'protected area in Czech Republic'],
#  'Martin Chodúr': ['Q12035689', 'Martin Chodúr', 'Czech singer'],
#  'Marta Kubišová': ['Q272424', 'Marta Kubišová', 'Czech singer'],
#  'Rudolf Kevin': [None, None, None],
#  'Tinchy Stryder': ['Q712992',
#   'Tinchy Stryder',
#   'British businessman, investor, multi-millionaire, actor and musician'],
#  'Niko': ['Q11884464', 'Niko', 'male given name'],
#  'Toby Romeo': ['Q100731387', 'Toby Romeo', 'Austrian DJ and producer'],
#  'Tom Boxer': ['Q7002010', 'Tom Boxer', 'Romanian DJ'],
#  'Noel Sak': [None, None, None],
#  'Markus Schulz': ['Q57784', 'Markus Schulz', 'German DJ and music producer'],
#  'Nohavica': ['Q282947', '6539 Nohavica', 'asteroid'],
#  'Mark Knopfler': ['Q185343', 'Mark Knopfler', 'British musician'],
#  'Nonono': ['Q14624084', 'NoNoNo', 'Swedish rock band'],
#  'Mike Perry': ['Q27749823',
#   'Mike Perry',
#   'American mixed martial arts fighter'],
#  '- Universal Music': [None, None, None],
#  'Duran Duran': ['Q58381', 'Duran Duran', 'English New Wave band'],
#  'Bingo Players': ['Q863851',
#   'Bingo Players',
#   'Dutch electronic music project by Maarten Hoogstraten'],
#  'Hollywood Undead': ['Q44637', 'Hollywood Undead', 'American rap rock band'],
#  'Birdy': ['Q288525', 'Birdy', 'English singer'],
#  'Him': ['Q23479', 'HIM', 'Finnish rock band'],
#  'Hi-Tack': ['Q72254', 'Klubbheads', 'Dutch house music band'],
#  'Hex': ['Q82828', 'hexadecimal', 'numeral system with 16 as its base'],
#  'Blige Mary J.': [None, None, None],
#  'Hello Goodbye': ['Q281911',
#   'Hello, Goodbye',
#   'original song written and composed by Lennon-McCartney; first recorded by The Beatles'],
#  'Blog 27': ['Q804514', 'Blog 27', 'Polish band'],
#  'Hansard Glen': [None, None, None],
#  'Blue Effect': ['Q657758', 'Blue Effect', 'Czech progressive rock band'],
#  'Bohouš Josef': ['Q26171419', 'Bohouš Josef', 'Czech singer'],
#  'Bomfunk Mcďs': [None, None, None],
#  'Gym Class Heroes': ['Q818377', 'Gym Class Heroes', 'band'],
#  'Gracey (': ['Q5591483',
#   'Gracey (Leontine) Elementary School',
#   'in Merced, California'],
#  'Bring Me The Horizon': ['Q494784',
#   'Bring Me the Horizon',
#   'British rock band'],
#  'Bruce Springsteen': ['Q1225',
#   'Bruce Springsteen',
#   'American rock singer (born 1949)'],
#  'Gold 1': ['Q2701567', 'Gold 1', 'American singer'],
#  'Bryan Adams': ['Q482907', 'Bryan Adams', 'Canadian guitarist'],
#  'Buena Mutya': [None, None, None],
#  'Glass Animals': ['Q16839267',
#   'Glass Animals',
#   'English psychedelic pop band'],
#  'Bălan Dan': [None, None, None],
#  'Gabriela': ['Q11971424', 'Gabriela', 'female given name'],
#  'Frenship': ['Q27429874', 'Frenship', 'American pop duo'],
#  'Calum Scott': ['Q20685460', 'Calum Scott', 'English singer'],
#  'Cann': ['Q16825463', 'Cann', 'family name'],
#  'Capital Cities': ['Q5035696', 'Capital Cities', 'American pop band'],
#  'František Segrado': ['Q46094764', 'František Segrado', 'actor'],
#  'Hoobastank': ['Q49724', 'Hoobastank', 'American rock band'],
#  'Bimbo Jones': [None, None, None],
#  'Cash Cash': ['Q1047317',
#   'Cash Cash',
#   'American electronic dance music band'],
#  'Horkýže Slíže': ['Q1628217', 'Horkýže Slíže', 'Slovak rock band'],
#  'Jasmine Thompson': ['Q15216612',
#   'Jasmine Thompson',
#   'English singer and songwriter'],
#  'Astrid S': ['Q17107619', 'Astrid S', 'Norwegian singer and songwriter'],
#  'Avaion': [None, None, None],
#  'Janota Adam': [None, None, None],
#  'Aysel': ['Q236078', 'Aysel Teymurzadeh', 'Azerbaijani singer'],
#  'James Tw': ['Q26703160', 'James TW', 'British singer-songwriter'],
#  'James Bay': ['Q223810',
#   'James Bay',
#   'bay in Nunavut at the southern end of the Hudson Bay, Canada'],
#  'B.O.B': ['Q45667', 'B.o.B', 'American rapper, singer and record producer'],
#  'Jakub Děkan': ['Q29513099', 'Jakub Děkan', 'Czech singer'],
#  'J Balvin': ['Q966845', 'J Balvin', 'Colombian singer'],
#  'Iyaz': ['Q317101',
#   'Iyaz',
#   'singer-songwriter and dancer from the British Virgin Islands'],
#  'Ivan Kral': ['Q3046138', 'Ivan Král', 'Czech-American musician'],
#  'Baracuda': ['Q828760', 'Baracuda', 'German electronic band'],
#  'Ironik': ['Q1622313', 'Ironik', 'British musician'],
#  'Iron Maiden': ['Q42482', 'Iron Maiden', 'English heavy metal band'],
#  'Iné Kafe': ['Q1097632', 'Iné Kafe', 'punk rock group from Slovakia'],
#  'Beatfreakz': ['Q2892968', 'Beatfreakz', 'Dutch house music band'],
#  'Becky G': ['Q1393997', 'Becky G', 'American singer and actress'],
#  'Iglu': ['Q23045094', 'Iglu', 'public art in Turku, Finland'],
#  'Bek Ofis': [None, None, None],
#  'Iggy Azalea': ['Q2748803', 'Iggy Azalea', 'Australian rapper'],
#  'Iann Dior': ['Q65631841', 'Iann Dior', 'American rapper and singer'],
#  'I.M.T.Smile': [None, None, None],
#  'I Am Kuba': [None, None, None],
#  'Berenika Kohoutová': ['Q11132273',
#   'Berenika Kohoutová',
#   'Czech actress and singer (*1991)'],
#  'Berry Maty': [None, None, None],
#  'Houston Whitney': [None, None, None],
#  'Frans': ['Q3480175', 'Frans', 'male given name'],
#  'Frank Wild': ['Q591807',
#   'Frank Wild',
#   'British Antarctica explorer (1873-1939)'],
#  'Jay Sean': ['Q294907', 'Jay Sean', 'British singer and songwriter'],
#  'Elly': ['Q2293288', 'Elly', 'female given name'],
#  'Daniell': ['Q708907',
#   'Thomas Daniell',
#   'English landscape painter (1749-1840)'],
#  'Ella Henderson': ['Q12309788',
#   'Ella Henderson',
#   'English singer and songwriter'],
#  'Elize': ['Q21142460', 'Elize', 'given name'],
#  'Eli': ['Q1328791', 'Eli', 'unisex given name'],
#  'Elena': ['Q1209486', 'Elena', 'female given name'],
#  'Echosmith': ['Q15044343', 'Echosmith', 'American rock and indie pop band'],
#  'Dymytry': ['Q11837020', 'Dymytry', 'Czech band'],
#  'Kroeger Chad': [None, None, None],
#  'Duncan And Wilde': [None, None, None],
#  'Dony': ['Q7075271', 'Obolo people', 'ethnic group in southeastern Nigeria'],
#  'Don Diablo': ['Q2464558', 'Don Diablo', 'Dutch DJ and record producer'],
#  'Dommi': ['Q12045',
#   'Dommitzsch',
#   'town in the district Nordsachsen, in the Free State of Saxony, Germany'],
#  'Domi Band': [None, None, None],
#  'David Michal': ['Q20755140', 'David Michal', 'Czech lawyer'],
#  'Dnce': ['Q21648421', 'DNCE', 'American pop band'],
#  'Dj Tiesto': ['Q183508', 'Tiësto', 'Dutch DJ and record producer'],
#  'Dj Scotty': ['Q1154255', 'DJ Scotty', 'German disc jockey'],
#  'Dawin': ['Q22270660',
#   'Dawin',
#   'American singer, songwriter and record producer'],
#  'Dj Kadr': [None, None, None],
#  'Dj Boccelli': [None, None, None],
#  'Dj Bobo': ['Q192108', 'DJ BoBo', 'Swiss singer, rapper and dancer'],
#  'Declan J Donovan': [None, None, None],
#  'Disturbed': ['Q131366', 'Disturbed', 'American heavy metal band'],
#  'Disciples': ['Q1541206',
#   'Christian Church (Disciples of Christ)',
#   'Restorationist Mainline Protestant denomination in the United States and Canada'],
#  'Deep Purple': ['Q101505', 'Deep Purple', 'English rock band'],
#  'Dimitri Vegas': ['Q12308641',
#   'Dimitri Vegas',
#   'Belgian DJ and record producer'],
#  'Diddy': ['Q216936',
#   'Sean Combs',
#   'American rapper, record producer, and entrepreneur'],
#  'Elle King': ['Q5364665',
#   'Elle King',
#   'American singer, songwriter, and actress'],
#  'Dan + Shay': ['Q16959408', 'Dan + Shay', 'American country music duo'],
#  'Fragma': ['Q694778', 'Fragma', 'band'],
#  'Dagny': ['Q1418583', 'Dagny', 'commune in Seine-et-Marne, France'],
#  'Ceha': ['Q67587235',
#   'Centro de Estudos de História do Atlântico',
#   'Portuguese research center in Madeira'],
#  'Chad Kroeger': ['Q294723', 'Chad Kroeger', 'Canadian rock musician'],
#  'Fort Minor': ['Q493729',
#   'Fort Minor',
#   'Hip hop side project of Mike Shinoda'],
#  'Forks Jasper': [None, None, None],
#  'Charlie Straight': ['Q3331492', 'Charlie Straight', 'Czech musical group'],
#  'Foo Fighters': ['Q483718', 'Foo Fighters', 'American rock band'],
#  'Fobia Kid': [None, None, None],
#  'Charming Horses': [None, None, None],
#  'Chemical Brothers': ['Q208507',
#   'The Chemical Brothers',
#   'British electronic music duo'],
#  'Cherish': ['Q1070284', 'Cherish', 'Madonna song'],
#  'Chipmunk': ['Q22364', 'Tamias', 'genus of mammals'],
#  'Fil Bo Riva': ['Q61997551', 'Fil Bo Riva', 'Italian musician'],
#  'Fiedlerski': [None, None, None],
#  'Fiasco Lupe': [None, None, None],
#  'Fences': ['Q25136220', 'Fences', '2016 film by Denzel Washington'],
#  'Felix  Jaehn': [None, None, None],
#  'Feder': ['Q1399295', 'Feder', 'family name'],
#  'Clean Bandit Ft. Louisa Johnson': [None, None, None],
#  'Clockclock': [None, None, None],
#  'Cnco': ['Q26270552', 'CNCO', 'Latin American musical group'],
#  'Cocoman': [None, None, None],
#  'Coolers': ['Q31621233',
#   'Coolers Knob Mountain',
#   'mountain in North Carolina, United States of America'],
#  'Eva Burešová': ['Q13433830',
#   'Eva Burešová',
#   'Czech actress and singer (*1993)'],
#  'Eros Ramazzotti': ['Q153708',
#   'Eros Ramazzotti',
#   'Italian musician (born 1963)'],
#  'Crapfruit': [None, None, None],
#  'Empire Of The Sun': ['Q271281',
#   'Empire of the Sun',
#   '1987 film directed by Steven Spielberg'],
#  'Cypress Hill': ['Q322196', 'Cypress Hill', 'American hip hop group'],
#  'Aronchupa': ['Q18237389', 'AronChupa', 'Swedish music producer'],
#  'Blink 182': ['Q482477', 'Blink-182', 'American rock band'],
#  'Jaymes Young': ['Q16887162',
#   'Jaymes Young',
#   'American singer-songwriter and musician'],
#  'Klubbingman': ['Q73595', 'Tommy Schleh', 'German DJ'],
#  'Alžběta': ['Q18073645', 'Alžběta', 'female given name'],
#  'Kendrick Lamar': ['Q130798',
#   'Kendrick Lamar',
#   'American rapper from California'],
#  'Alžběta Kolečkářová': ['Q10787284', 'Alžběta Kolečkářová', 'Czech singer'],
#  'American Authors': ['Q15044381', 'American Authors', 'American rock band'],
#  'André Rieu': ['Q159832', 'André Rieu', 'Dutch violinist and conductor'],
#  'John Legend': ['Q44857', 'John Legend', 'American singer-songwriter'],
#  'Khalid': ['Q28816483', 'Khalid', 'American singer (born 1998)'],
#  'Kid Cudi': ['Q299138', 'Kid Cudi', 'American rapper and singer (born 1984)'],
#  'Andy Cermak': [None, None, None],
#  'A Fine Frenzy': ['Q240830', 'Alison Sudol', 'American musician'],
#  'Kiesza': ['Q16730833', 'Kiesza', 'Canadian singer and songwriter'],
#  'Kim Wilde': ['Q1790', 'Kim Wilde', 'English pop singer (born 1960)'],
#  'Klaas': ['Q19688670', 'Klaas', 'male given name'],
#  'Klangkarussell': ['Q1385280', 'Klangkarussell', 'Austrian band'],
#  'Klara': ['Q18199028', 'Klara', 'female given name'],
#  'Annet Charitonova': [None, None, None],
#  'Jitka Charvátová': ['Q12024947',
#   'Jitka Charvátová',
#   'Czech actress and singer'],
#  'Keane': ['Q484311', 'Keane', 'English alternative rock band'],
#  'Abba': ['Q18233', 'ABBA', 'Swedish pop group'],
#  ...}

# %%
hudebni_slova = ["singer", "songwr", "guitar", "band", "producer", "rapper", "pop ","hip hop","orchest","group","DJ","choir","disc jockey", "actor","actress","composer","vocalist","musician","violinist","ensemble","musical"," duo"," trio","YouTuber","producer","mezzo-soprano","collective","lyricist"]

# %%
nepochybni = {key: value for key, value in qecka.items() if value[2] is not None and any(word in value[2] for word in hudebni_slova)}

# %%
len(nepochybni)
# Out:
# 1020

# %%
nepochybni
# Out:
# {'Michal Hrůza': ['Q12036727', 'Michal Hrůza', 'Czech singer'],
#  'Chinaski': ['Q2041483', 'Chinaski', 'Czech pop/rock band'],
#  'P!Nk': ['Q160009', 'P!nk', 'US-American singer and songwriter'],
#  'Coldplay': ['Q45188', 'Coldplay', 'British rock band'],
#  'Miro Žbirka': ['Q3509359', 'Miroslav Žbirka', 'Slovak musician (1952–2021)'],
#  'Support Lesbiens': ['Q1488112', 'Support Lesbiens', 'Czech rock band'],
#  'Ewa Farna': ['Q242302', 'Ewa Farna', 'Polish-Czech singer'],
#  'David Guetta': ['Q8298', 'David Guetta', 'French DJ and record producer'],
#  'Kabát': ['Q938649', 'Kabát', 'Czech rock band'],
#  'No Name': ['Q1264915', 'No Name', 'Montenegrin musical group; boyband'],
#  'Lady Gaga': ['Q19848',
#   'Lady Gaga',
#   'American singer, songwriter, and actress (born 1986)'],
#  'Lucie Bílá': ['Q468282', 'Lucie Bílá', 'Czech singer and actress'],
#  'Maroon 5': ['Q182223', 'Maroon 5', 'American pop rock band'],
#  'Lucie Vondráčková': ['Q2569624',
#   'Lucie Vondráčková',
#   'Czech singer and actress'],
#  'Marek Ztracený': ['Q3551937', 'Marek Ztracený', 'Czech singer and composer'],
#  'Divokej Bill': ['Q2599880', 'Divokej Bill', 'Czech folk rock band'],
#  'Xindl X': ['Q2598276',
#   'Xindl X',
#   'Czech composer, guitarist, scriptwriter and singer'],
#  'Onerepublic': ['Q1438730', 'OneRepublic', 'American pop rock band'],
#  'Tomáš Klus': ['Q1385173',
#   'Tomáš Klus',
#   'Czech actor, pentathlete and singer'],
#  'Rihanna': ['Q36844', 'Rihanna', 'Barbadian singer and actress (born 1988)'],
#  'Mandrage': ['Q602203', 'Mandrage', 'Czech pop rock band'],
#  'Avril Lavigne': ['Q30449', 'Avril Lavigne', 'Canadian singer (born 1984)'],
#  'Katy Perry': ['Q42493',
#   'Katy Perry',
#   'American singer, songwriter, actress and television personality (1984)'],
#  'Linkin Park': ['Q261', 'Linkin Park', 'American rock band'],
#  'Jason Derulo': ['Q243639',
#   'Jason Derulo',
#   'American singer-songwriter, dancer and actor'],
#  'Avicii': ['Q505476', 'Avicii', 'Swedish DJ and record producer (1989–2018)'],
#  'Enrique Iglesias': ['Q47122', 'Enrique Iglesias', 'Spanish singer'],
#  'Mariah Carey': ['Q41076',
#   'Mariah Carey',
#   'American singer and songwriter (born 1969)'],
#  'Eminem': ['Q5608',
#   'Eminem',
#   'American rapper, record producer and actor (born 1972)'],
#  'David Deyl': ['Q5621211', 'David Deyl', 'Czech singer'],
#  'Taylor Swift': ['Q26876',
#   'Taylor Swift',
#   'American singer-songwriter (born 1989)'],
#  'Karel Gott': ['Q333187', 'Karel Gott', 'Czech singer and actor'],
#  'Calvin Harris': ['Q81637',
#   'Calvin Harris',
#   'British DJ, singer and record producer'],
#  'Dan Bárta': ['Q11774157', 'Dan Bárta', 'Czech singer'],
#  'Václav Neckář': ['Q475090', 'Václav Neckář', 'Czech actor and singer'],
#  'Miley Cyrus': ['Q4235',
#   'Miley Cyrus',
#   'American singer, actress, and television personality (born 1992)'],
#  'Ed Sheeran': ['Q47447', 'Ed Sheeran', 'English singer-songwriter'],
#  'Olga Lounová': ['Q12042533',
#   'Olga Lounova',
#   'Czech actress, singer and car racer'],
#  'Sunrise Avenue': ['Q751775', 'Sunrise Avenue', 'Finnish rock band'],
#  'Green Day': ['Q47871', 'Green Day', 'American rock band'],
#  'Imagine Dragons': ['Q391348', 'Imagine Dragons', 'American pop rock band'],
#  'Janek Ledecký': ['Q12023485', 'Janek Ledecký', 'Czech guitarist and singer'],
#  'Ellie Goulding': ['Q31164',
#   'Ellie Goulding',
#   'English singer and songwriter'],
#  'Ben Cristovao': ['Q11068745',
#   'Ben Cristovao',
#   'Czech actor, presenter, snowboarder, dancer and singer'],
#  'Wham!': ['Q744087', 'Wham!', 'English pop duo'],
#  'Black Eyed Peas': ['Q134541',
#   'Black Eyed Peas',
#   'American hip hop group from California'],
#  'Lana Del Rey': ['Q37150', 'Lana Del Rey', 'American singer (born 1985)'],
#  'Shakira': ['Q34424', 'Shakira', 'Colombian singer, songwriter and actress'],
#  'Justin Bieber': ['Q34086', 'Justin Bieber', 'Canadian singer (born 1994)'],
#  'Selena Gomez': ['Q83287',
#   'Selena Gomez',
#   'American singer and actress (born 1992)'],
#  'Flo Rida': ['Q213538', 'Flo Rida', 'American rapper from Florida'],
#  'Daniel Landa': ['Q159250',
#   'Daniel Landa',
#   'Czech car racer, actor, composer, rally driver and singer'],
#  'Beyoncé': ['Q36153', 'Beyoncé', 'American singer (born 1981)'],
#  'Red Hot Chili Peppers': ['Q10708',
#   'Red Hot Chili Peppers',
#   'American musical group; rock band'],
#  'Marpo': ['Q4043742', 'Marpo', 'Czech rapper'],
#  'James Blunt': ['Q130799', 'James Blunt', 'English singer-songwriter'],
#  'Tereza Kerndlová': ['Q203446', 'Tereza Kerndlová', 'Czech singer'],
#  'Robbie Williams': ['Q47875',
#   'Robbie Williams',
#   'British singer-songwriter (born 1974)'],
#  'Wohnout': ['Q6396977', 'Wohnout', 'Czech rock band'],
#  'Adele': ['Q23215', 'Adele', 'English singer-songwriter (born 1988)'],
#  'Alicia Keys': ['Q121507', 'Alicia Keys', 'American singer'],
#  'Kelly Clarkson': ['Q483507',
#   'Kelly Clarkson',
#   'American singer, songwriter, author, and television personality'],
#  'David Koller': ['Q11774361', 'David Koller', 'Czech musician'],
#  'Aneta Langerová': ['Q455191',
#   'Aneta Langerová',
#   'Czech recording artist; singer'],
#  'Eddie Stoilow': ['Q21481397', 'Eddie Stoilow', 'Czech musical group'],
#  'Slza': ['Q21041050', 'Slza', 'Czech band'],
#  'Sia': ['Q181484', 'Sia', 'Australian singer and songwriter'],
#  'Martin Garrix': ['Q14544318',
#   'Martin Garrix',
#   'Dutch DJ and record producer'],
#  'Paulie Garand': ['Q12043983',
#   'Paulie Garand',
#   'Czech music producer and rapper'],
#  'John Lennon': ['Q1203',
#   'John Lennon',
#   'English musician and member of the Beatles (1940–1980)'],
#  'Robin Schulz': ['Q16231940',
#   'Robin Schulz',
#   'German record producer and DJ'],
#  'Sean Paul': ['Q200577',
#   'Sean Paul',
#   'Jamaican singer, actor and record producer'],
#  'Sam Smith': ['Q15123969', 'Sam Smith', 'English singer and songwriter'],
#  'Celeste Buckingham': ['Q1093318',
#   'Celeste Buckingham',
#   'Slovak singer and songwriter of Swiss-American origins'],
#  'Michael Bublé': ['Q153694', 'Michael Bublé', 'Canadian singer'],
#  'Kygo': ['Q16845512', 'Kygo', 'Norwegian musician and DJ (born 1991)'],
#  'Rudimental': ['Q50971', 'Rudimental', 'British electronic band'],
#  'Shawn Mendes': ['Q17198340', 'Shawn Mendes', 'Canadian singer'],
#  'Tiësto': ['Q183508', 'Tiësto', 'Dutch DJ and record producer'],
#  'James Arthur': ['Q717626', 'James Arthur', 'English singer and musician'],
#  'Pitbull': ['Q187844', 'Pitbull', 'American singer from Florida'],
#  'Martin Solveig': ['Q359066',
#   'Martin Solveig',
#   'French electro house DJ and producer'],
#  'Ektor': ['Q15534440', 'Ektor', 'Czech rapper'],
#  'Lily Allen': ['Q58735',
#   'Lily Allen',
#   'English singer, songwriter, author, and television presenter'],
#  'George Ezra': ['Q15459513', 'George Ezra', 'English singer-songwriter'],
#  'Alle Farben': ['Q15263356', 'Alle Farben', 'German DJ and producer'],
#  'Fergie': ['Q180004', 'Fergie', 'American singer and actress'],
#  'Adam Mišík': ['Q10379771',
#   'Adam Mišík',
#   'Czech dubbing actor, guitarist and singer'],
#  'Bruno Mars': ['Q1450',
#   'Bruno Mars',
#   'American singer, songwriter, and record producer'],
#  'Dua Lipa': ['Q21914464',
#   'Dua Lipa',
#   'English and Albanian singer (born 1995)'],
#  'Britney Spears': ['Q11975',
#   'Britney Spears',
#   'American singer and songwriter (born 1981)'],
#  'Justin Timberlake': ['Q43432',
#   'Justin Timberlake',
#   'American singer and actor (born 1981)'],
#  'Bon Jovi': ['Q259254', 'Bon Jovi', 'American rock band'],
#  'Alesso': ['Q965455', 'Alesso', 'Swedish DJ and music producer'],
#  'Nickelback': ['Q483802', 'Nickelback', 'Canadian rock band'],
#  'Michal David': ['Q3506625', 'Michal David', 'Czech composer and singer'],
#  'Bob Sinclar': ['Q223167', 'Bob Sinclar', 'French record producer and DJ'],
#  'Katarína Knechtová': ['Q224559',
#   'Katarína Knechtová',
#   'Slovak singer-songwriter and guitarist'],
#  'Debbi': ['Q739328', 'Debbi', 'German-Czech singer'],
#  'Pil C': ['Q23712816', 'Pil C', 'Slovak rapper'],
#  'Alan Walker': ['Q21808729',
#   'Alan Walker',
#   'Norwegian DJ and music producer'],
#  'Ne-Yo': ['Q193710', 'Ne-Yo', 'American R&B singer'],
#  'The Weeknd': ['Q2121062',
#   'The Weeknd',
#   'Canadian singer-songwriter (born 1990)'],
#  'Clean Bandit': ['Q11838808',
#   'Clean Bandit',
#   'British electronic music group'],
#  'Demi Lovato': ['Q41173', 'Demi Lovato', 'American singer and actress'],
#  'Twenty One Pilots': ['Q7857806',
#   'Twenty One Pilots',
#   'American musical duo'],
#  'Majk Spirit': ['Q4276957', 'Majk Spirit', 'Slovak rapper'],
#  'Rasmus': ['Q485679', 'The Rasmus', 'Finnish rock band'],
#  'Emma Smetana': ['Q11878748', 'Emma Smetana', 'Czech actress and presenter'],
#  'Will.I.Am': ['Q185610',
#   'will.i.am',
#   'American rapper, singer, songwriter and record producer'],
#  'Jonas Blue': ['Q22246459', 'Jonas Blue', 'British DJ and music producer'],
#  'Johny Machette': ['Q15249826', 'Johny Machette', 'Czech rapper'],
#  'Viktor Sheen': ['Q75939796', 'Viktor Sheen', 'Czech rapper'],
#  'Little Mix': ['Q158419', 'Little Mix', 'English girl group'],
#  'Lost Frequencies': ['Q18857432', 'Lost Frequencies', 'Belgian DJ'],
#  'Fall Out Boy': ['Q485811', 'Fall Out Boy', 'American pop punk band'],
#  'Alvaro Soler': ['Q20203583', 'Álvaro Soler', 'Spanish-German singer'],
#  'Simple Plan': ['Q485825', 'Simple Plan', 'Canadian rock band'],
#  'U2': ['Q396', 'U2', 'Irish rock band'],
#  'Adam Lambert': ['Q190231', 'Adam Lambert', 'American singer'],
#  'Harry Styles': ['Q3626966',
#   'Harry Styles',
#   'English singer, songwriter, and actor'],
#  'Thirty Seconds To Mars': ['Q40585',
#   'Thirty Seconds to Mars',
#   'American rock band from Los Angeles'],
#  'Sam Feldt': ['Q20972330',
#   'Sam Feldt',
#   'Dutch DJ, record producer and entrepreneur'],
#  'Christina Aguilera': ['Q41594', 'Christina Aguilera', 'American singer'],
#  'Kylie Minogue': ['Q11998',
#   'Kylie Minogue',
#   'Australian singer and actress (born 1968)'],
#  'Samey': ['Q110746787', 'Samey', 'Slovak rapper'],
#  'Zedd': ['Q21088', 'Zedd', 'Russian-German DJ and music producer'],
#  'Foster The People': ['Q61113', 'Foster the People', 'American rock band'],
#  '5 Seconds Of Summer': ['Q4641147',
#   '5 Seconds of Summer',
#   'Australian pop rock band'],
#  'Shaun Baker': ['Q327220',
#   'Shaun Baker',
#   'English musician, DJ and record producer'],
#  'Inna': ['Q12349', 'Inna', 'Romanian singer'],
#  'Mikolas Josef': ['Q43571872',
#   'Mikolas Josef',
#   'Czech singer-songwriter and former model'],
#  'Swedish House Mafia': ['Q20709',
#   'Swedish House Mafia',
#   'Swedish electronic music group'],
#  'Tata Bojs': ['Q2507263', 'Tata Bojs', 'Czech pop rock band'],
#  'Charli Xcx': ['Q5084390', 'Charli XCX', 'English singer-songwriter'],
#  'Nik Tendo': ['Q61666911', 'Nik Tendo', 'Czech rapper'],
#  'Nico Santos': ['Q23806108', 'Nico Santos', 'German singer-songwriter'],
#  'Adam Ďurica': ['Q16515468', 'Adam Ďurica', 'Slovak musician'],
#  'Zara Larsson': ['Q4177928', 'Zara Larsson', 'Swedish singer (born 1997)'],
#  'Yzomandias': ['Q29066314', 'Yzomandias', 'Czech rapper'],
#  'Nightwork': ['Q7172701', 'Nightwork', 'Czech musical group'],
#  'Škwor': ['Q392143', 'Škwor', 'Czech rock band'],
#  'Hana Zagorová': ['Q3507535', 'Hana Zagorová', 'Czech actress and singer'],
#  'Halsey': ['Q18534249', 'Halsey', 'American singer-songwriter (born 1994)'],
#  'Rita Ora': ['Q229760',
#   'Rita Ora',
#   'British singer, actress, songwriter and model'],
#  'Nelly Furtado': ['Q80424', 'Nelly Furtado', 'Canadian singer'],
#  'Ariana Grande': ['Q151892',
#   'Ariana Grande',
#   'American singer and actress (born 1993)'],
#  'Peter Aristone': ['Q15982799', 'Peter Aristone', 'Slovak singer'],
#  'Mark Ronson': ['Q425821', 'Mark Ronson', 'British musician (born 1975)'],
#  'Jana Kirschner': ['Q575764', 'Jana Kirschner', 'Slovak singer'],
#  'Jaromír Nohavica': ['Q942232',
#   'Jaromír Nohavica',
#   'Czech songwriter, lyricist, and poet'],
#  'Lumineers': ['Q496101', 'The Lumineers', 'American folk rock band'],
#  'Pavel Callta': ['Q20860286', 'Pavel Callta', 'Czech singer, song-writer'],
#  'Felix Jaehn': ['Q18943660', 'Felix Jaehn', 'German DJ and music producer'],
#  'Machine Gun Kelly': ['Q1354843',
#   'Machine Gun Kelly',
#   'American musician (born 1990)'],
#  'Jax Jones': ['Q16995320',
#   'Jax Jones',
#   'English DJ, songwriter, record producer and remixer'],
#  'Macklemore': ['Q484874', 'Macklemore', 'American rapper from Washington'],
#  'Madcon': ['Q842152', 'Madcon', 'Norwegian hip hop duo'],
#  'X Ambassadors': ['Q15963313',
#   'X Ambassadors',
#   'American rock band from Ithaca, New York'],
#  'Arash': ['Q236748', 'Arash', 'Iranian singer'],
#  'Jennifer Lopez': ['Q40715', 'Jennifer Lopez', 'American singer and actress'],
#  'Wanastowi Vjecy': ['Q10818511', 'Wanastowi Vjecy', 'Czech rock band'],
#  'Kanye West': ['Q15935',
#   'Kanye West',
#   'American rapper, singer, and producer (born 1977)'],
#  'Welshly Arms': ['Q28452843', 'Welshly Arms', 'American band'],
#  'Duke Dumont': ['Q9637045', 'Duke Dumont', 'British music producer and DJ'],
#  'Nirvana': ['Q11649', 'Nirvana', 'American rock band'],
#  'Depeche Mode': ['Q482964', 'Depeche Mode', 'British band'],
#  'Usher': ['Q165911', 'Usher', 'American R&B singer (born 1978)'],
#  'Ava Max': ['Q56755505', 'Ava Max', 'American singer and songwriter'],
#  'Niall Horan': ['Q775231', 'Niall Horan', 'Irish singer-songwriter'],
#  'Cascada': ['Q858880', 'Cascada', 'German electronic dance music group'],
#  'Roxette': ['Q173790', 'Roxette', 'Swedish pop duo'],
#  'Louis Tomlinson': ['Q3624971',
#   'Louis Tomlinson',
#   'English singer and songwriter'],
#  'Gwen Stefani': ['Q483379', 'Gwen Stefani', 'American singer-songwriter'],
#  'Armin Van Buuren': ['Q62617',
#   'Armin van Buuren',
#   'Dutch DJ, record producer and remixer'],
#  'Kaiser Chiefs': ['Q192308', 'Kaiser Chiefs', 'English indie rock band'],
#  'Charlie Puth': ['Q19810390',
#   'Charlie Puth',
#   'American singer and songwriter'],
#  'Amy Macdonald': ['Q15902', 'Amy Macdonald', 'Scottish singer-songwriter'],
#  'Aloe Blacc': ['Q49319', 'Aloe Blacc', 'American singer and rapper'],
#  'Emma Drobná': ['Q27897742', 'Emma Drobná', 'Slovak singer'],
#  'Sergei Barracuda': ['Q20058093', 'Sergei Barracuda', 'Czech rapper'],
#  'Rytmus': ['Q3488250', 'Rytmus', 'Slovak rapper'],
#  'All American Rejects': ['Q214237',
#   'The All-American Rejects',
#   'American rock band'],
#  'Rammstein': ['Q25177', 'Rammstein', 'German rock band'],
#  'Nico': ['Q44634', 'Nico', 'German singer and actress (1938–1988)'],
#  'Martin Jensen': ['Q21039224', 'Martin Jensen', 'Danish DJ and producer'],
#  'Lil Peep': ['Q29388200', 'Lil Peep', 'American rapper'],
#  'R.I.O.': ['Q690183', 'R.I.O.', 'German dance duo (formerly trio)'],
#  'Post Malone': ['Q21621919',
#   'Post Malone',
#   'American rapper, singer, and songwriter'],
#  'Lenka Filipová': ['Q15249858', 'Lenny', 'Czech singer'],
#  'Barbora Poláková': ['Q11052902',
#   'Barbora Poláková',
#   'Czech actress and singer'],
#  'Renne Dang': ['Q29582910', 'Renne Dang', 'Czech rapper'],
#  'Take That': ['Q152066', 'Take That', 'British five-piece vocal pop group'],
#  'Xxxtentacion': ['Q28561969', 'XXXTentacion', 'American rapper (1998–2018)'],
#  'Bebe Rexha': ['Q16185856', 'Bebe Rexha', 'American singer and songwriter'],
#  'Metallica': ['Q15920', 'Metallica', 'American heavy metal band'],
#  'Tinie Tempah': ['Q46321', 'Tinie Tempah', 'English rapper'],
#  'Owl City': ['Q207938',
#   'Owl City',
#   'American electronic musical project by Adam Young'],
#  'Meghan Trainor': ['Q17403494',
#   'Meghan Trainor',
#   'American singer-songwriter (born 1993)'],
#  'Marshmello': ['Q26334949', 'Marshmello', 'American music producer and DJ'],
#  'Richard Müller': ['Q1373537',
#   'Richard Müller',
#   'Slovak singer and songwriter'],
#  'Jakub Ondra': ['Q60759671', 'Jakub Ondra', 'Czech singer and songwriter'],
#  'Akon': ['Q32849',
#   'Akon',
#   'Senegalese American singer, songwriter, record producer, and entrepreneur'],
#  'Travis Scott': ['Q13605596',
#   'Travis Scott',
#   'American rapper, singer and record producer (born 1991)'],
#  'Zaz': ['Q167850', 'Zaz', 'French singer; recording artist'],
#  'Mando Diao': ['Q478814',
#   'Mando Diao',
#   'Swedish musical group; rock band from Borlänge'],
#  'Jay-Z': ['Q62766', 'Jay-Z', 'American rapper and businessman (born 1969)'],
#  'Tove Lo': ['Q15948790', 'Tove Lo', 'Swedish singer'],
#  'Olly Murs': ['Q552770', 'Olly Murs', 'British singer'],
#  'Route 94': ['Q15920231', 'Route 94', 'British DJ and producer'],
#  'Pharrell Williams': ['Q14313',
#   'Pharrell Williams',
#   'American singer, rapper, producer and songwriter (born 1973)'],
#  'David Stypka': ['Q26677234', 'David Stypka', 'Czech singer'],
#  'Ph Electro': ['Q3359701',
#   'PH Electro',
#   'German disc jockey and record producer'],
#  'Riton': ['Q7336776', 'Riton', 'British DJ and music producer'],
#  'Paul Mccartney': ['Q2599',
#   'Paul McCartney',
#   'British rock musician, former member of The Beatles and Wings'],
#  'Nerieš': ['Q108538504', 'Nerieš', 'Slovak musical duo'],
#  "Rag 'N' Bone Man": ['Q26834366',
#   "Rag'n'Bone Man",
#   'British blues and soul singer'],
#  'R3Hab': ['Q3414998', 'R3HAB', 'Dutch-Moroccan DJ and record producer'],
#  'Pussycat Dolls': ['Q102385',
#   'The Pussycat Dolls',
#   'American girl group and dance ensemble'],
#  'Ofenbach': ['Q29380907', 'Ofenbach', 'French house music duo'],
#  'Elán': ['Q222107', 'Elán', 'Slovak pop rock band'],
#  'Dean Lewis': ['Q29905254', 'Dean Lewis', 'Australian singer-songwriter'],
#  'Daddy Yankee': ['Q272591', 'Daddy Yankee', 'Puerto Rican singer'],
#  'Dj Antoine': ['Q667014', 'DJ Antoine', 'Swiss record producer and DJ'],
#  'Radůza': ['Q9302686', 'Radůza', 'Czech singer-songwriter and musician'],
#  'Professor Green': ['Q384655',
#   'Professor Green',
#   'English rapper and singer-songwriter'],
#  'Pokáč': ['Q55172176', 'Pokáč', 'Czech singer'],
#  'Dj Fresh': ['Q941738', 'DJ Fresh', 'English DJ and record producer'],
#  'Eric Prydz': ['Q155141', 'Eric Prydz', 'Swedish DJ and record producer'],
#  'One Direction': ['Q146027', 'One Direction', 'English-Irish boy band'],
#  'Dermot Kennedy': ['Q61983346', 'Dermot Kennedy', 'Irish singer-songwriter'],
#  'Of Monsters And Men': ['Q509702',
#   'Of Monsters and Men',
#   'Icelandic folk-rock band'],
#  'Duck Sauce': ['Q1165307', 'Duck Sauce', 'DJ duo'],
#  'Milky Chance': ['Q14623684',
#   'Milky Chance',
#   'German electronic-infused indie pop band based in Kassel'],
#  'Team': ['Q327245', 'team', 'group linked in a common purpose'],
#  'T.I.': ['Q214227', 'T.I.', 'American rapper and actor'],
#  'Limp Bizkit': ['Q240767', 'Limp Bizkit', 'American rap rock band'],
#  'Bodyrockers': ['Q890054', 'BodyRockers', 'band'],
#  'Alexandra Burke': ['Q234161', 'Alexandra Burke', 'singer'],
#  'Hozier': ['Q16233232', 'Hozier', 'Irish musician'],
#  'Alex Hepburn': ['Q10366783',
#   'Alex Hepburn',
#   'English singer and songwriter'],
#  'Sugababes': ['Q193697', 'Sugababes', 'British pop girl group'],
#  'John Newman': ['Q12433089', 'John Newman', 'British singer-songwriter'],
#  'Stromae': ['Q313453', 'Stromae', 'Belgian singer and producer'],
#  'Mike Posner': ['Q268284', 'Mike Posner', 'American musician'],
#  'Matt Simons': ['Q4742345',
#   'Matt Simons',
#   'American singer songwriter and musician'],
#  'Thom Artway': ['Q29998334', 'Thom Artway', 'Czech singer'],
#  'Těžkej Pokondr': ['Q11837240', 'Těžkej Pokondr', 'Czech musical comedy duo'],
#  'Arakain': ['Q625397', 'Arakain', 'Czech heavy metal band'],
#  'Lykke Li': ['Q270724', 'Lykke Li', 'Swedish singer'],
#  'Jonas Brothers': ['Q134233', 'Jonas Brothers', 'American pop rock band'],
#  'Axwell': ['Q20713', 'Axwell', 'Swedish DJ, remixer and record producer'],
#  'Tři Sestry': ['Q164928', 'Tři sestry', 'Czech punk band'],
#  'Billie Eilish': ['Q29564107',
#   'Billie Eilish',
#   'American singer-songwriter (born 2001)'],
#  'Junge Junge': ['Q30589129', 'Junge Junge', 'German producer duo'],
#  'Tom Walker': ['Q30122853', 'Tom Walker', 'Scottish singer-songwriter'],
#  'Benassi Bros.': ['Q2895671', 'Benassi Bros.', 'Italian electronica group'],
#  'Timbaland': ['Q179257', 'Timbaland', 'American record producer and rapper'],
#  'Kateřina Marie Tichá': ['Q21684336', 'Kateřina Marie Tichá', 'Czech singer'],
#  'Naughty Boy': ['Q6981132',
#   'Naughty Boy',
#   'British DJ and musician (born 1985)'],
#  'Kodaline': ['Q2482563', 'Kodaline', 'irish rock band'],
#  'Konex': ['Q115271316', '2K', 'French songwriter, record producer'],
#  'Klingande': ['Q15041224', 'Klingande', 'French DJ and house music producer'],
#  'Cheryl Cole': ['Q212772',
#   'Cheryl',
#   'English singer, dancer, and television presenter'],
#  'Ke$Ha': ['Q33605', 'Kesha', 'American singer and songwriter'],
#  'My Chemical Romance': ['Q483285',
#   'My Chemical Romance',
#   'American musical group; rock band'],
#  'Gryffin': ['Q27956380', 'Gryffin', 'American DJ and music producer'],
#  'Hailee Steinfeld': ['Q231726',
#   'Hailee Steinfeld',
#   'American actress, singer and model'],
#  'Cee-Lo Green': ['Q4042', 'CeeLo Green', 'American singer and rapper'],
#  'Lewis Capaldi': ['Q42315001', 'Lewis Capaldi', 'Scottish singer-songwriter'],
#  'Helena Vondráčková': ['Q288578',
#   'Helena Vondráčková',
#   'Czech recording artist; actress and singer'],
#  'Ca$Hanova Bulhar': ['Q110270668', 'Cashanova Bulhar', 'Czech rapper'],
#  'Yolanda Be Cool': ['Q1058926', 'Yolanda Be Cool', 'Australian music duo'],
#  'Helena Zeťová': ['Q12019443', 'Helena Zeťová', 'Czech singer'],
#  'Mohombi': ['Q379117',
#   'Mohombi',
#   'Congolese-Swedish musician, singer, composer and dancer.'],
#  'Peter Bič Project': ['Q18536373', 'Peter Bič Project', 'musical group'],
#  'Kontrafakt': ['Q1473875', 'Kontrafakt', 'Slovak music group'],
#  'Pop Smoke': ['Q81698554', 'Pop Smoke', 'American rapper (1999–2020)'],
#  'Petr Bende': ['Q95393472', 'Petr Bende', 'Czechoslovak singer'],
#  'Juice Wrld': ['Q52151598',
#   'Juice WRLD',
#   'American rapper and singer (1998–2019)'],
#  'Dynoro': ['Q55006974', 'Dynoro', 'Lithuanian DJ and music producer'],
#  'Kojo': ['Q931600', 'Kojo', 'Finnish singer'],
#  'Lorde': ['Q13476175', 'Lorde', 'New Zealand singer-songwriter (born 1996)'],
#  'Lmfao': ['Q48978', 'LMFAO', 'American electronic dance music duo'],
#  'Kapitán Demo': ['Q13550846', 'Jiří Burian', 'Czech musician and presenter'],
#  'Khaled': ['Q312609', 'Khaled', 'Algerian raï musician'],
#  'Elton John': ['Q2808', 'Elton John', 'English singer and pianist'],
#  'Lil Nas X': ['Q62591281',
#   'Lil Nas X',
#   'American rapper and singer (born 1999)'],
#  'Liam Payne': ['Q2756349', 'Liam Payne', 'English singer'],
#  'Karin Ann': ['Q108529528', 'Karin Ann', 'Slovak singer'],
#  'Global Deejays': ['Q877283', 'Global Deejays', 'Austrian band'],
#  'Joel Corry': ['Q67172196',
#   'Joel Corry',
#   'English DJ, producer and television personality'],
#  'Nicky Jam': ['Q1374560', 'Nicky Jam', 'American singer'],
#  'Moby': ['Q14045', 'Moby', 'American musician'],
#  'G-Eazy': ['Q5511893', 'G-Eazy', 'American rapper'],
#  'Hardwell': ['Q923731', 'Hardwell', 'Dutch DJ and music producer'],
#  'Morandi': ['Q904842', 'Morandi', 'pop band from Romania'],
#  'Galantis': ['Q18071093', 'Galantis', 'Swedish electronic music duo'],
#  'Nicki Minaj': ['Q162202',
#   'Nicki Minaj',
#   'Trinidadian-born rapper (born 1982)'],
#  'Natasha Bedingfield': ['Q212906', 'Natasha Bedingfield', 'British singer'],
#  'Nathan Dawe': ['Q91044263', 'Nathan Dawe', 'English DJ and Music Producer'],
#  'Nick Jonas': ['Q201656',
#   'Nick Jonas',
#   'American singer, actor and musician'],
#  'Get Far': ['Q1396608', 'Fargetta', 'Italian musician'],
#  'Nf': ['Q19571648', 'NF', 'American rapper from Michigan'],
#  'Gipsy.Cz': ['Q945417', 'Gipsy.cz', 'band'],
#  'Neiked': ['Q26703294', 'NEIKED', 'Swedish artist collective'],
#  'Mike Candys': ['Q625246', 'Mike Candys', 'Swiss DJ and record producer'],
#  'Flipsyde': ['Q761385', 'Flipsyde', 'band'],
#  'Far East Movement': ['Q104625', 'Far East Movement', 'band'],
#  'Major Lazer': ['Q2604214',
#   'Major Lazer',
#   'Jamaican-American electronic music band'],
#  'Panic! At The Disco': ['Q277551',
#   'Panic! At The Disco',
#   'American musical group; rock solo project band'],
#  'Jason Mraz': ['Q192515', 'Jason Mraz', 'American singer-songwriter'],
#  'Marlon Roudette': ['Q21076',
#   'Marlon Roudette',
#   'English singer and songwriter'],
#  'Jamelia': ['Q234199', 'Jamelia', 'British singer'],
#  'Nelly': ['Q218992',
#   'Nelly',
#   'American rapper, singer, songwriter and entrepreneur'],
#  'Martin Harich': ['Q12035723', 'Martin Harich', 'Slovak singer'],
#  'Outkast': ['Q472595', 'OutKast', 'American hip hop duo'],
#  'Otto Knows': ['Q400094', 'Otto Knows', 'Swedish DJ'],
#  'Hurts': ['Q493042', 'Hurts', 'English synthpop duo'],
#  'Hugo Toxxx': ['Q12020903', 'Hugo Toxxx', 'Czech rapper'],
#  'Mika': ['Q186329', 'Mika', 'British-Lebanese singer'],
#  'Kungs': ['Q23826199', 'Kungs', 'French DJ, record producer and musician'],
#  'Dennis Lloyd': ['Q51033104', 'Dennis Lloyd', 'Israeli singer-songwriter'],
#  'Remady': ['Q503925', 'Remady', 'Swiss music producer'],
#  'Regard': ['Q70912825', 'Regard', 'Kosovo-Albanian DJ and record producer'],
#  'Walk The Moon': ['Q3653206', 'Walk the Moon', 'American pop/rock band'],
#  'Ready Kirken': ['Q7238093',
#   'Ready Kirken',
#   'musical group from the Czech Republic'],
#  'The Faim': ['Q60846768', 'The Faim', 'Australian rock band'],
#  'Andrea Bocelli': ['Q42402',
#   'Andrea Bocelli',
#   'Italian tenor and singer-songwriter (1958-)'],
#  'Tate Mcrae': ['Q95129121', 'Tate McRae', 'Canadian singer and songwriter'],
#  'Alexandra Stan': ['Q1453', 'Alexandra Stan', 'Romanian singer'],
#  'Blackbear': ['Q22974007', 'Blackbear', 'American singer'],
#  'Vladimír Mišík': ['Q762854',
#   'Vladimír Mišík',
#   'Czech member of Czech National Council, guitarist and singer'],
#  'Ting Tings': ['Q219939', 'The Ting Tings', 'English musical duo'],
#  'Tones And I': ['Q62887629',
#   'Tones and I',
#   'Australian singer, songwriter and record producer'],
#  'Troye Sivan': ['Q1362028',
#   'Troye Sivan',
#   'Australian singer-songwriter, actor and YouTuber'],
#  'Twiins': ['Q539894', 'TWiiNS', 'Slovak musical group; twin pop duo'],
#  'Becky Hill': ['Q16236194', 'Becky Hill', 'English singer and songwriter'],
#  'D.H.T.': ['Q1755076', 'DHT', 'Belgian eurodance band'],
#  'Craig David': ['Q154222', 'Craig David', 'British singer (born 1981)'],
#  'Amy Winehouse': ['Q15897',
#   'Amy Winehouse',
#   'British singer and songwriter (1983–2011)'],
#  'Zayn': ['Q3626950', 'Zayn Malik', 'English singer'],
#  'R.E.M.': ['Q134969', 'R.E.M.', 'American rock band (1980–2011)'],
#  'Camila Cabello': ['Q18810940',
#   'Camila Cabello',
#   'Cuban-Mexican-American singer, actress and songwriter'],
#  'Shaggy': ['Q310763', 'Shaggy', 'Jamaican reggae musician'],
#  'Purple Disco Machine': ['Q61746813',
#   'Purple Disco Machine',
#   'German DJ and record producer'],
#  'Chris Brown': ['Q155700', 'Chris Brown', 'American R&B singer (born 1989)'],
#  'Zoe Wees': ['Q96119730', 'Zoe Wees', 'German singer'],
#  'Shayne Ward': ['Q266091', 'Shayne Ward', 'English singer'],
#  '50 Cent': ['Q6060', '50 Cent', 'American rapper and actor (born 1975)'],
#  'Čechomor': ['Q2424041', 'Čechomor', 'Czech traditional music band'],
#  'Afrojack': ['Q349041', 'Afrojack', 'Dutch DJ and record producer'],
#  'Sto Zvířat': ['Q7617750', 'Sto zvířat', 'Czech ska and reggae band'],
#  '24Kgoldn': ['Q83751918', '24kGoldn', 'American rapper and singer'],
#  'Snoop Dogg': ['Q6096', 'Snoop Dogg', 'American rapper (born 1971)'],
#  'Carly Rae Jepsen': ['Q52583',
#   'Carly Rae Jepsen',
#   'Canadian singer and songwriter'],
#  'Biffy Clyro': ['Q858365', 'Biffy Clyro', 'Scottish rock band'],
#  'Markéta Konvičková': ['Q12035611', 'Markéta Konvičková', 'Czech singer'],
#  'Hana Hegerová': ['Q82688',
#   'Hana Hegerová',
#   'Czech actress, singer and chansonier'],
#  'Tokio Hotel': ['Q386216', 'Tokio Hotel', 'German pop band'],
#  'Marta Jandová': ['Q470233', 'Marta Jandová', 'Czech singer'],
#  'Beatles': ['Q1299', 'The Beatles', 'English rock band (1960–1970)'],
#  'Basto!': ['Q810666', 'Basto', 'Belgian musician and DJ'],
#  'Tom Grennan': ['Q54357938', 'Tom Grennan', 'English singer-songwriter'],
#  'Tim Berg': ['Q505476',
#   'Avicii',
#   'Swedish DJ and record producer (1989–2018)'],
#  'Timmy Trumpet': ['Q7806850',
#   'Timmy Trumpet',
#   'Australian house DJ and producer'],
#  'Jan Kalousek': ['Q12022644', 'Jan Kalousek', 'Czech actor and singer'],
#  'Monika Absolonová': ['Q3508501',
#   'Monika Absolonová',
#   'Czech singer and actress'],
#  'Basshunter': ['Q383541',
#   'Basshunter',
#   'Swedish singer, record producer and DJ'],
#  'Prago Union': ['Q3502494', 'Prago Union', 'Czech band'],
#  'Big Ali': ['Q858418', 'Big Ali', 'American singer, rapper and songwriter'],
#  'Michael Schulte': ['Q1242168',
#   'Michael Schulte',
#   'German singer-songwriter'],
#  'Michael Jackson': ['Q2831',
#   'Michael Jackson',
#   'American singer, songwriter, and dancer (1958–2009)'],
#  'Mike Shinoda': ['Q19201', 'Mike Shinoda', 'American musician'],
#  'Bts': ['Q13580495', 'BTS', 'South Korean musical group; boy band'],
#  'Icona Pop': ['Q808703', 'Icona Pop', 'Swedish DJ duo'],
#  'Blur': ['Q485820', 'Blur', 'English alternative rock band'],
#  'Imanbek': ['Q83688261', 'Imanbek', 'Kazakh record producer'],
#  'Banners': ['Q22276958', 'Banners', 'English musician'],
#  'Imany': ['Q115206', 'Imany', 'French pop-soul singer'],
#  'Mimi Webb': ['Q106613064', 'Mimi Webb', 'English singer and songwriter'],
#  'Buty': ['Q3563284', 'Buty', 'Czech musical group'],
#  'Melanie C': ['Q151830', 'Melanie C', 'British singer'],
#  'Burak Yeter': ['Q19668785', 'Burak Yeter', 'Turkish musician'],
#  'Snow Patrol': ['Q188407',
#   'Snow Patrol',
#   'Northern Irish-Scottish rock band'],
#  'Bodybangers': ['Q890089', 'Bodybangers', 'german dance band'],
#  'Iveta Bartošová': ['Q3270208', 'Iveta Bartošová', 'Czech singer'],
#  'Mans Zelmerlöw': ['Q372460',
#   'Måns Zelmerlöw',
#   'Swedish singer and television presenter'],
#  'Alessia Cara': ['Q20090091',
#   'Alessia Cara',
#   'Canadian-Italian singer and songwriter'],
#  'Kelis': ['Q294979', 'Kelis', 'American singer'],
#  'Alanis Morissette': ['Q130742',
#   'Alanis Morissette',
#   'Canadian-American singer (born 1974)'],
#  'Alec Benjamin': ['Q19560068', 'Alec Benjamin', 'American singer-songwriter'],
#  'Kateřina Brožová': ['Q455170',
#   'Kateřina Brožová',
#   'Czech actress, singer and presenter'],
#  'Alesha Dixon': ['Q19182',
#   'Alesha Dixon',
#   'British singer, rapper and dancer'],
#  'Alex C.': ['Q61986',
#   'Alex Christensen',
#   'German composer, producer, and DJ'],
#  'Leoš Mareš': ['Q1954437', 'Leoš Mareš', 'Czech presenter and singer'],
#  'Lilly Wood': ['Q3240920',
#   'Lilly Wood and the Prick',
#   'French pop folk collective'],
#  'Wiz Khalifa': ['Q117139', 'Wiz Khalifa', 'American rapper and singer'],
#  'All Time Low': ['Q909731', 'All Time Low', 'American rock band'],
#  'Westlife': ['Q151241', 'Westlife', 'Irish boy band'],
#  'Leona Lewis': ['Q183519', 'Leona Lewis', 'British singer'],
#  'Toxique': ['Q12059454', 'Toxique', 'Czech musical group'],
#  'Labrinth': ['Q48959', 'Labrinth', 'English singer and rapper'],
#  '6Ix9Ine': ['Q44479972',
#   '6ix9ine',
#   'American rapper from New York (born. 1996)'],
#  'A$Ap Rocky': ['Q129910',
#   'A$AP Rocky',
#   'American rapper and record producer'],
#  'Lenka Dusilová': ['Q3490011', 'Lenka Dusilová', 'Czech musician'],
#  'Yungblud': ['Q47500295', 'Yungblud', 'English musician'],
#  'Anastacia': ['Q34584', 'Anastacia', 'American singer'],
#  'Loreen': ['Q483376', 'Loreen', 'Swedish singer and songwriter'],
#  'Jess Glynne': ['Q15744507', 'Jess Glynne', 'British singer'],
#  'Jitka Zelenková': ['Q12024968', 'Jitka Zelenková', 'Czech singer'],
#  'Mr. Probz': ['Q2750788',
#   'Mr. Probz',
#   'Dutch singer, producer, musician and actor'],
#  'Twocolors': ['Q98910385', 'Twocolors', 'German electronic dance band'],
#  'Justin Jesso': ['Q44068438', 'Justin Jesso', 'Norwegian singer'],
#  'Backstreet Boys': ['Q17140', 'Backstreet Boys', 'American boy band'],
#  'Jc Stewart': ['Q105103226', 'JC Stewart', 'singer'],
#  'Bakermat': ['Q13383449', 'Bakermat', 'Dutch DJ and record producer'],
#  'Maneskin': ['Q56884561', 'Måneskin', 'Italian rock band'],
#  'Jiří Schelinger': ['Q1082574',
#   'Jiří Schelinger',
#   'Czech musician (1951-1981)'],
#  'Velile': ['Q567793', 'Velile', 'South African actor'],
#  'Lvcas Dope': ['Q58875497', 'Lvcas Dope', 'Czech singer'],
#  'Lunchmoney Lewis': ['Q19669354',
#   'LunchMoney Lewis',
#   'American singer and songwriter'],
#  'Lumidee': ['Q272244', 'Lumidee', 'American singer and rapper'],
#  'Vize': ['Q65246672', 'Vize', 'German electro house band'],
#  'Lukas Graham': ['Q300935', 'Lukas Graham', 'Danish band'],
#  'Luis Fonsi': ['Q1387726', 'Luis Fonsi', 'Puerto Rican singer'],
#  'Vojtěch Dyk': ['Q11925857', 'Vojtěch Dyk', 'Czech actor'],
#  'Anna Naklab': ['Q20061746', 'Anna Naklab', 'German female singer'],
#  'Jp Cooper': ['Q27807517', 'JP Cooper', 'British musician'],
#  'Andy Grammer': ['Q4299814', 'Andy Grammer', 'American singer-songwriter'],
#  'Julia Michaels': ['Q20051697', 'Julia Michaels', 'American singer'],
#  'Walking On Cars': ['Q18712621', 'Walking on Cars', 'Irish rock band'],
#  'Lady Sovereign': ['Q230754',
#   'Lady Sovereign',
#   'English rapper and grime artist'],
#  'Colbie Caillat': ['Q228860', 'Colbie Caillat', 'American singer-songwriter'],
#  'Pink Floyd': ['Q2306', 'Pink Floyd', 'English rock band'],
#  'Neon Trees': ['Q1508269', 'Neon Trees', 'American band'],
#  'Evanescence': ['Q1777698',
#   'Evanescence',
#   'American rock band from Little Rock'],
#  'Reamonn': ['Q101592', 'Reamonn', 'German rock band'],
#  'Gnarls Barkley': ['Q726773', 'Gnarls Barkley', 'American soul duo'],
#  'Desmod': ['Q2218009', 'Desmod', 'Slovak pop-rock band'],
#  'Good Charlotte': ['Q485220', 'Good Charlotte', 'American rock band'],
#  'Novaspace': ['Q458579', 'Novaspace', 'band'],
#  'Dj Khaled': ['Q80805', 'DJ Khaled', 'American DJ and music producer'],
#  'Disclosure': ['Q1228440', 'Disclosure', 'English electronic music duo'],
#  'Plain White T´S': ['Q169316', "Plain White T's", 'American band'],
#  'Dj Snake': ['Q16728588', 'DJ Snake', 'French DJ and record producer'],
#  'Gorillaz': ['Q189991', 'Gorillaz', 'English virtual band'],
#  'Sarah Connor': ['Q63664', 'Sarah Connor', 'German singer'],
#  'Petr Muk': ['Q3086091',
#   'Petr Muk',
#   'Czech pop musician, composer, and performer (1965-2010)'],
#  'Gotye': ['Q489643', 'Gotye', 'Australian musician'],
#  'Gabriella Cilmi': ['Q234767', 'Gabriella Cilmi', 'Australian singer'],
#  'Gabriela Gunčíková': ['Q3496995', 'Gabriela Gunčíková', 'Czech singer'],
#  'Razorlight': ['Q913779', 'Razorlight', 'English rock band'],
#  'Ray Dalton': ['Q13426816', 'Ray Dalton', 'American singer'],
#  'Daft Punk': ['Q185828', 'Daft Punk', 'French electronic music band'],
#  'Peha': ['Q1632697', 'Peha', 'Slovak band'],
#  'Sam Fischer': ['Q86749847',
#   'Sam Fischer',
#   'Australian singer-songwriter and musician'],
#  'Cobra Starship': ['Q524822', 'Cobra Starship', 'American band'],
#  'Dalibor Janda': ['Q836436',
#   'Dalibor Janda',
#   'Czech composer, lyricist and singer (*1953)'],
#  'Conan Gray': ['Q65214814', 'Conan Gray', 'American singer-songwriter'],
#  'Diplo': ['Q533781', 'Diplo', 'American DJ and music producer'],
#  'Fun.': ['Q838984', 'Fun', 'American indie rock band'],
#  'Pavol Habera': ['Q578393', 'Pavol Habera', 'Slovak musician and actor'],
#  'Sandro Cavazza': ['Q26258299',
#   'Sandro Cavazza',
#   'Swedish singer-songwriter'],
#  'Petr Kotvald': ['Q473120', 'Petr Kotvald', 'Czech singer'],
#  'Daniel Powter': ['Q313698', 'Daniel Powter', 'Canadian musician and singer'],
#  'Gabry Ponte': ['Q468692', 'Gabry Ponte', 'Italian DJ and record producer'],
#  'Natalia Imbruglia': ['Q488353',
#   'Natalie Imbruglia',
#   'Australian singer and actress'],
#  'Celine Dion': ['Q5105', 'Céline Dion', 'Canadian singer (born 1968)'],
#  'Duffy': ['Q192587', 'Duffy', 'Welsh singer-songwriter'],
#  'Progres 2': ['Q3502525', 'Progres 2', 'Czech progressive rock band'],
#  'Daya': ['Q21005558', 'Daya', 'American singer'],
#  'Gromee': ['Q28672611', 'Gromee', 'Polish DJ, music producer, lyricist'],
#  'Palaye Royale': ['Q48699789',
#   'Palaye Royale',
#   'Canadian-American rock band'],
#  'Fifth Harmony': ['Q3087893', 'Fifth Harmony', 'American girl group'],
#  'Edward Maya': ['Q317169',
#   'Edward Maya',
#   'Romanian singer, record producer and DJ'],
#  'Don Omar': ['Q310539', 'Don Omar', 'Puerto Rican singer'],
#  'Doja Cat': ['Q51120673',
#   'Doja Cat',
#   'American rapper, singer-songwriter, and record producer (born 1995)'],
#  'Djane Housekat': ['Q106352',
#   'DJane HouseKat',
#   'Danish singer, songwriter, DJ, music producer'],
#  'Ronan Keating': ['Q311467', 'Ronan Keating', 'Irish singer and songwriter'],
#  'Christina Perri': ['Q229341',
#   'Christina Perri',
#   'American singer-songwriter'],
#  'Olivia Rodrigo': ['Q63243883',
#   'Olivia Rodrigo',
#   'American singer and actress (born 2003)'],
#  'Scissor Sisters': ['Q464109', 'Scissor Sisters', 'American pop/rock band'],
#  'Paramore': ['Q473466', 'Paramore', 'American rock band'],
#  'Vinylshakerz': ['Q551091', 'Vinylshakerz', 'band'],
#  'Vigiland': ['Q18636147',
#   'Vigiland',
#   'Swedish DJ/music producing house music duo'],
#  'Pearl Jam': ['Q142701', 'Pearl Jam', 'American rock band'],
#  'Ozzy Osbourne': ['Q133151',
#   'Ozzy Osbourne',
#   'English musician and TV personality (born 1948)'],
#  'We Are Domi': ['Q110157843',
#   'We Are Domi',
#   'Czech-Norwegian electropop band'],
#  'Parov Stelar': ['Q89525',
#   'Parov Stelar',
#   'Austrian musician, producer and DJ'],
#  'Wankelmut': ['Q1154301', 'Wankelmut', 'German DJ and music producer'],
#  'Loona': ['Q28025953', 'Loona', 'South Korean girl group'],
#  'Pavel Vítek': ['Q12044307', 'Pavel Vítek', 'Czech actor-singer'],
#  'Ludacris': ['Q193676', 'Ludacris', 'American rapper and actor'],
#  'Vlastimil Horváth': ['Q7939035', 'Vlastimil Horváth', 'Czech singer'],
#  'Rea Garvey': ['Q319429',
#   'Rea Garvey',
#   'Irish singer, songwriter, record producer and guitarist'],
#  'Louane': ['Q18684181', 'Louane', 'French actress and singer'],
#  'Papa Roach': ['Q254371', 'Papa Roach', 'American rock band'],
#  'Wabi Daněk': ['Q10838330',
#   'Wabi Daněk',
#   'Czech guitarist and singer (1947-2017)'],
#  'Pascal Letoublon': ['Q109773015',
#   'Pascal Letoublon',
#   'French music producer'],
#  'Pnau': ['Q2761963', 'Pnau', 'Australian dance music trio'],
#  'Polarkreis 18': ['Q695121', 'Polarkreis 18', 'German band'],
#  'Zuzana Smatanová': ['Q750809', 'Zuzana Smatanová', 'Slovak singer'],
#  '2 Chainz': ['Q129668', '2 Chainz', 'American rapper (born 1977)'],
#  'Lacuna Coil': ['Q46573', 'Lacuna Coil', 'Italian gothic metal band'],
#  'La Roux': ['Q200002', 'La Roux', 'English musical group'],
#  'Kwabs': ['Q18536523', 'Kwabs', 'British Soul singer'],
#  'Lenny Kravitz': ['Q180224',
#   'Lenny Kravitz',
#   'American musician and actor (born 1964)'],
#  'Pixie Lott': ['Q207177',
#   'Pixie Lott',
#   'English singer and songwriter, actress'],
#  'Leonard Cohen': ['Q1276',
#   'Leonard Cohen',
#   'Canadian poet and singer-songwriter (1934–2016)'],
#  'Lizzo': ['Q16232225', 'Lizzo', 'American singer and rapper (born 1988)'],
#  'Rat City': ['Q89699194', 'Rat City', 'music band'],
#  'Lil Wayne': ['Q15615', 'Lil Wayne', 'American rapper (born 1982)'],
#  'Robert Křesťan': ['Q12049508',
#   'Robert Křesťan',
#   'Czech singer, composer and translator'],
#  'Lil Uzi Vert': ['Q23771950',
#   'Lil Uzi Vert',
#   'American rapper from Pennsylvania'],
#  'Yall': ['Q22680890', 'Yall', 'Spanish electronica music group'],
#  'Raego': ['Q15124211', 'Raego', 'Czech singer'],
#  'Radio Killer': ['Q4047956', 'Radio Killer', 'Romanian dance music group'],
#  'Radim Hladík': ['Q3566227', 'Radim Hladík', 'Czech guitarist'],
#  'Ylvis': ['Q640053', 'Ylvis', 'Norwegian comedy duo'],
#  'R. City': ['Q7201184', 'R. City', 'American hip hop group'],
#  'Younotus': ['Q21050484', 'YouNotUs', 'German DJ duo from Berlin'],
#  'Oliver Tree': ['Q55956050',
#   'Oliver Tree',
#   'American singer, record producer and comedian'],
#  'T-Pain': ['Q221155',
#   'T-Pain',
#   'American rapper, singer, and record producer'],
#  'Sting': ['Q483203', 'Sting', 'British musician'],
#  'Super-Hi': ['Q107340166', 'Super-Hi', 'British production duo'],
#  'Michal Tučný': ['Q538916', 'Michal Tučný', 'Czech guitarist and singer'],
#  'Sza': ['Q16210722', 'SZA', 'American singer'],
#  'Michal Prokop': ['Q12036790',
#   'Michal Prokop',
#   'Czech guitarist, presenter and singer; member of Czech Parliament (1996–1998)'],
#  'Spirituál Kvintet': ['Q3564752', 'Spirituál kvintet', 'Czech folk band'],
#  'Schyzo': ['Q50981751', 'Schyzo', 'Czech rapper'],
#  'Michael Foret': ['Q12036625', 'Michael Foret', 'Czech singer'],
#  'Nena': ['Q153996', 'Nena', 'German singer and actress'],
#  'Metro Boomin': ['Q16235273',
#   'Metro Boomin',
#   'American record producer, DJ, and record executive'],
#  'Tatu': ['Q161723', 't.A.T.u.', 'Russian music duo'],
#  'Santana': ['Q873384', 'Santana', 'American band led by Carlos Santana'],
#  'Nessa Barrett': ['Q107413717', 'Nessa Barrett', 'American singer'],
#  'Starley': ['Q28054068', 'Starley', 'Australian singer'],
#  'Spice Girls': ['Q55641', 'Spice Girls', 'British girl group'],
#  'Showtek': ['Q1067714',
#   'Showtek',
#   'Dutch electronic dance music sibling duo'],
#  'Monika Bagárová': ['Q62081535', 'Monika Bagárová', 'Czech Romani singer'],
#  'Shawn Hook': ['Q18357706',
#   'Shawn Hook',
#   'Canadian singer, songwriter, producer'],
#  'Sharkass': ['Q21685625', 'Sharkass', 'Czech rapper'],
#  'Nayer': ['Q166444', 'Nayer', 'American singer'],
#  'Slash': ['Q34166', 'Slash', 'British-American guitarist'],
#  'Mnek': ['Q6716905',
#   'MNEK',
#   'English singer, songwriter and record producer'],
#  'Snakehips': ['Q22116844', 'Snakehips', 'British electronic music band'],
#  'Mňága': ['Q3490405', 'Mňága a Žďorp', 'Czech alternative rock band'],
#  'Shaed': ['Q60643444', 'Shaed', 'American musical group'],
#  'Spankers': ['Q11312712', 'Spankers', 'Italian DJ duo'],
#  'Nathan Evans': ['Q105044427', 'Nathan Evans', 'Scottish musician'],
#  'Serebro': ['Q318882', 'Serebro', 'Russian pop girl group'],
#  'Roll Deep': ['Q913194', 'Roll Deep', 'British hip hop group'],
#  'Tony Bennett': ['Q296729', 'Tony Bennett', 'American singer'],
#  'Notd': ['Q55624499', 'NOTD', 'Swedish production duo'],
#  'Rosa Linn': ['Q111193171', 'Rosa Linn', 'armenisk singer-songwriter'],
#  'Oliver Heldens': ['Q16667903', 'Oliver Heldens', 'Dutch DJ'],
#  'Nick Cave': ['Q192668', 'Nick Cave', 'Australian musician'],
#  'Maitre Gims': ['Q3303251',
#   'Gims',
#   'Congolese-French singer-songwriter and rapper'],
#  'Robyn': ['Q229445', 'Robyn', 'Swedish singer (born 1979)'],
#  'Magic!': ['Q16596856', 'Magic!', 'Canadian reggae-pop band'],
#  'Ondřej Brzobohatý': ['Q12042658',
#   'Ondřej Brzobohatý',
#   'Czech actor, composer, keyboard player and presenter (*1983)'],
#  'Robin Thicke': ['Q467423',
#   'Robin Thicke',
#   'American singer, songwriter, and record producer'],
#  'Robert Plant': ['Q428223',
#   'Robert Plant',
#   'English musician and lead vocalist of Led Zeppelin'],
#  'M.I.A.': ['Q204019', 'M.I.A.', 'British rapper (born 1975)'],
#  'Veronicas': ['Q721992', 'The Veronicas', 'Australian pop duo'],
#  'Marie Rottrová': ['Q3512331',
#   'Marie Rottrová',
#   'Czech actress, presenter, singer, composer and lyricist'],
#  'Marián Vojtko': ['Q12035361',
#   'Marian Vojtko',
#   'Slovak actor, opera singer and singer'],
#  'Mattafix': ['Q21075', 'Mattafix', 'British duo'],
#  'Sam And The Womp': ['Q2115414',
#   'Sam and the Womp',
#   'three piece music group from the United Kingdom'],
#  'Masked Wolf': ['Q105490126', 'Masked Wolf', 'Australian rapper'],
#  'Martin Tungevaag': ['Q17319322',
#   'Martin Tungevaag',
#   'Norwegian DJ and producer'],
#  'Sabaton': ['Q740159', 'Sabaton', 'Swedish power metal band'],
#  'Nicky Romero': ['Q260214',
#   'Nicky Romero',
#   'Dutch DJ, record producer and remixer'],
#  'Thxsomch': ['Q118143958', 'ThxSoMch', 'musical artist'],
#  'Martin Chodúr': ['Q12035689', 'Martin Chodúr', 'Czech singer'],
#  'Marta Kubišová': ['Q272424', 'Marta Kubišová', 'Czech singer'],
#  'Tinchy Stryder': ['Q712992',
#   'Tinchy Stryder',
#   'British businessman, investor, multi-millionaire, actor and musician'],
#  'Toby Romeo': ['Q100731387', 'Toby Romeo', 'Austrian DJ and producer'],
#  'Tom Boxer': ['Q7002010', 'Tom Boxer', 'Romanian DJ'],
#  'Markus Schulz': ['Q57784', 'Markus Schulz', 'German DJ and music producer'],
#  'Mark Knopfler': ['Q185343', 'Mark Knopfler', 'British musician'],
#  'Nonono': ['Q14624084', 'NoNoNo', 'Swedish rock band'],
#  'Duran Duran': ['Q58381', 'Duran Duran', 'English New Wave band'],
#  'Hollywood Undead': ['Q44637', 'Hollywood Undead', 'American rap rock band'],
#  'Birdy': ['Q288525', 'Birdy', 'English singer'],
#  'Him': ['Q23479', 'HIM', 'Finnish rock band'],
#  'Hi-Tack': ['Q72254', 'Klubbheads', 'Dutch house music band'],
#  'Blog 27': ['Q804514', 'Blog 27', 'Polish band'],
#  'Blue Effect': ['Q657758', 'Blue Effect', 'Czech progressive rock band'],
#  'Bohouš Josef': ['Q26171419', 'Bohouš Josef', 'Czech singer'],
#  'Gym Class Heroes': ['Q818377', 'Gym Class Heroes', 'band'],
#  'Bring Me The Horizon': ['Q494784',
#   'Bring Me the Horizon',
#   'British rock band'],
#  'Bruce Springsteen': ['Q1225',
#   'Bruce Springsteen',
#   'American rock singer (born 1949)'],
#  'Gold 1': ['Q2701567', 'Gold 1', 'American singer'],
#  'Bryan Adams': ['Q482907', 'Bryan Adams', 'Canadian guitarist'],
#  'Glass Animals': ['Q16839267',
#   'Glass Animals',
#   'English psychedelic pop band'],
#  'Frenship': ['Q27429874', 'Frenship', 'American pop duo'],
#  'Calum Scott': ['Q20685460', 'Calum Scott', 'English singer'],
#  'Capital Cities': ['Q5035696', 'Capital Cities', 'American pop band'],
#  'František Segrado': ['Q46094764', 'František Segrado', 'actor'],
#  'Hoobastank': ['Q49724', 'Hoobastank', 'American rock band'],
#  'Cash Cash': ['Q1047317',
#   'Cash Cash',
#   'American electronic dance music band'],
#  'Horkýže Slíže': ['Q1628217', 'Horkýže Slíže', 'Slovak rock band'],
#  'Jasmine Thompson': ['Q15216612',
#   'Jasmine Thompson',
#   'English singer and songwriter'],
#  'Astrid S': ['Q17107619', 'Astrid S', 'Norwegian singer and songwriter'],
#  'Aysel': ['Q236078', 'Aysel Teymurzadeh', 'Azerbaijani singer'],
#  'James Tw': ['Q26703160', 'James TW', 'British singer-songwriter'],
#  'B.O.B': ['Q45667', 'B.o.B', 'American rapper, singer and record producer'],
#  'Jakub Děkan': ['Q29513099', 'Jakub Děkan', 'Czech singer'],
#  'J Balvin': ['Q966845', 'J Balvin', 'Colombian singer'],
#  'Iyaz': ['Q317101',
#   'Iyaz',
#   'singer-songwriter and dancer from the British Virgin Islands'],
#  'Ivan Kral': ['Q3046138', 'Ivan Král', 'Czech-American musician'],
#  'Baracuda': ['Q828760', 'Baracuda', 'German electronic band'],
#  'Ironik': ['Q1622313', 'Ironik', 'British musician'],
#  'Iron Maiden': ['Q42482', 'Iron Maiden', 'English heavy metal band'],
#  'Iné Kafe': ['Q1097632', 'Iné Kafe', 'punk rock group from Slovakia'],
#  'Beatfreakz': ['Q2892968', 'Beatfreakz', 'Dutch house music band'],
#  'Becky G': ['Q1393997', 'Becky G', 'American singer and actress'],
#  'Iggy Azalea': ['Q2748803', 'Iggy Azalea', 'Australian rapper'],
#  'Iann Dior': ['Q65631841', 'Iann Dior', 'American rapper and singer'],
#  'Berenika Kohoutová': ['Q11132273',
#   'Berenika Kohoutová',
#   'Czech actress and singer (*1991)'],
#  'Jay Sean': ['Q294907', 'Jay Sean', 'British singer and songwriter'],
#  'Ella Henderson': ['Q12309788',
#   'Ella Henderson',
#   'English singer and songwriter'],
#  'Echosmith': ['Q15044343', 'Echosmith', 'American rock and indie pop band'],
#  'Dymytry': ['Q11837020', 'Dymytry', 'Czech band'],
#  'Dony': ['Q7075271', 'Obolo people', 'ethnic group in southeastern Nigeria'],
#  'Don Diablo': ['Q2464558', 'Don Diablo', 'Dutch DJ and record producer'],
#  'Dnce': ['Q21648421', 'DNCE', 'American pop band'],
#  'Dj Tiesto': ['Q183508', 'Tiësto', 'Dutch DJ and record producer'],
#  'Dj Scotty': ['Q1154255', 'DJ Scotty', 'German disc jockey'],
#  'Dawin': ['Q22270660',
#   'Dawin',
#   'American singer, songwriter and record producer'],
#  'Dj Bobo': ['Q192108', 'DJ BoBo', 'Swiss singer, rapper and dancer'],
#  'Disturbed': ['Q131366', 'Disturbed', 'American heavy metal band'],
#  'Deep Purple': ['Q101505', 'Deep Purple', 'English rock band'],
#  'Dimitri Vegas': ['Q12308641',
#   'Dimitri Vegas',
#   'Belgian DJ and record producer'],
#  'Diddy': ['Q216936',
#   'Sean Combs',
#   'American rapper, record producer, and entrepreneur'],
#  'Elle King': ['Q5364665',
#   'Elle King',
#   'American singer, songwriter, and actress'],
#  'Dan + Shay': ['Q16959408', 'Dan + Shay', 'American country music duo'],
#  'Fragma': ['Q694778', 'Fragma', 'band'],
#  'Chad Kroeger': ['Q294723', 'Chad Kroeger', 'Canadian rock musician'],
#  'Charlie Straight': ['Q3331492', 'Charlie Straight', 'Czech musical group'],
#  'Foo Fighters': ['Q483718', 'Foo Fighters', 'American rock band'],
# ...
#  'Baby Bash': ['Q708231', 'Baby Bash', 'American rapper'],
#  'Vláďa Šafránek': ['Q56670096', 'Vladimír Šafránek', 'Czech singer'],
#  'Vlny': ['Q25396332', 'VLNY', 'Russian indie-rock band'],
#  'B.B.King': ['Q188969',
#   'B.B. King',
#   'American blues guitarist, singer, and songwriter (1925–2015)'],
#  'Tyler, The Creator': ['Q167635',
#   'Tyler, the Creator',
#   'American rapper, producer, visual artist, and fashion designer from California'],
#  'Three 6 Mafia': ['Q1027165', 'Three 6 Mafia', 'American hip-hop group'],
#  'Stereophonics': ['Q28963', 'Stereophonics', 'Welsh rock band'],
#  'Stormzy': ['Q20055659', 'Stormzy', 'English rapper'],
#  'Brian May': ['Q15873', 'Brian May', 'English musician (born 1947)'],
#  'Within Temptation': ['Q57138',
#   'Within Temptation',
#   'Dutch symphonic metal band'],
#  'Bratři Ebenové': ['Q11333078', 'Bratři Ebenové', 'Czech band'],
#  'Winona Oak': ['Q60194917', 'Winona Oak', 'Swedish singer-songwriter'],
#  'Bára Zemanová': ['Q54898925', 'Bára Zemanová', 'Czech pop-rock singer'],
#  'Skylar Grey': ['Q233750', 'Skylar Grey', 'American singer'],
#  'Caesars': ['Q740696', 'Caesars', 'Swedish musical group; indie rock band'],
#  'Slade': ['Q156872', 'Slade', 'British rock band'],
#  'Slipknot': ['Q254138', 'Slipknot', 'American metal band'],
#  'Ari Abdul': ['Q120760126', 'Ari Abdul', 'singer'],
#  'Busta Rhymes': ['Q59185',
#   'Busta Rhymes',
#   'American rapper, actor, record producer and record executive'],
#  'Sofi Tukker': ['Q22044898', 'Sofi Tukker', 'American musical duo'],
#  'Solid Base': ['Q3120943', 'Solid Base', 'swedish-Norwegian Eurodance duo'],
#  "Soulja Boy Tell 'Em": ['Q313080', 'Soulja Boy', 'American rapper'],
#  'Bushido': ['Q311961', 'Bushido', 'German rapper'],
#  'Brainstorm': ['Q14045', 'Moby', 'American musician'],
#  'Bpm': ['Q189214',
#   'tempo',
#   'musical concept indicating to the speed of interpretation'],
#  'Temperamento': ['Q7698296', 'Temperamento', 'Puerto Rican musician'],
#  'Blackpink': ['Q25056945', 'Blackpink', 'South Korean girl group'],
#  'Blackmore´S Night': ['Q735023',
#   "Blackmore's Night",
#   'British/American traditional folk rock band formed in 1997'],
#  "Blackmore'S Night": ['Q735023',
#   "Blackmore's Night",
#   'British/American traditional folk rock band formed in 1997'],
#  'The Hunna': ['Q27792569', 'The Hunna', 'British rock band'],
#  'Surf Mesa': ['Q93771412',
#   'Surf Mesa',
#   'American record producer and multi-instrumentalist'],
#  'Amber Van Day': ['Q62383653',
#   'Amber Van Day',
#   'British singer and songwriter'],
#  'The Tap Tap': ['Q59730363', 'The Tap Tap', 'Czech band'],
#  'Billy Talent': ['Q154815', 'Billy Talent', 'Canadian rock band'],
#  'Beth Hart': ['Q204804', 'Beth Hart', 'American blues rock musician'],
#  'Alunageorge': ['Q10353', 'AlunaGeorge', 'British pop music duo'],
#  'Wheatus': ['Q957718', 'Wheatus', 'American rock band'],
#  'Surfaces': ['Q76330429', 'Surfaces', 'American musical duo'],
#  'Bow Anderson': ['Q105720739', 'Bow Anderson', 'Scottish singer-songwriter'],
#  'Boston Bun': ['Q111901510', 'Boston Bun', 'French producer and DJ'],
#  'Switch Disco': ['Q119998852', 'Switch Disco', 'British DJ duo'],
#  "Why Don'T We": ['Q30113721', "Why Don't We", 'American boy band'],
#  'Tacabro': ['Q1634979', 'Tacabro', 'Italian dance music trio'],
#  'Bob Dylan': ['Q392', 'Bob Dylan', 'American singer-songwriter (born 1941)'],
#  'Taktici': ['Q12777231', 'Taktici', 'Slovak rock band'],
#  'Tame Impala': ['Q9619',
#   'Tame Impala',
#   'Australian psychedelic rock musical proyect'],
#  'Whitesnake': ['Q189965', 'Whitesnake', 'British hard rock band'],
#  'Bloodhound Gang': ['Q157497', 'Bloodhound Gang', 'American rap rock group'],
#  'White Lies': ['Q1331605', 'White Lies', 'English band'],
#  'Deorro': ['Q15921342', 'Deorro', 'American DJ and music producer'],
#  'J-Five': ['Q726352', 'J-five', 'American singer'],
#  'Martin Maxa': ['Q12035788', 'Martin Maxa', 'Czech singer'],
#  'Martina Pártlová': ['Q59391300',
#   'Martina Pártlová',
#   'Czech female vocalist'],
#  'Master Kg': ['Q87368609',
#   'Master KG',
#   'South African musician and record producer'],
#  'Matoma': ['Q19845354', 'Matoma', 'Norwegian DJ'],
#  'Matt Maeson': ['Q66712455', 'Matt Maeson', 'American singer'],
#  'Iva Frühlingová': ['Q202583', 'Iva Frühlingová', 'Czech model and singer'],
#  'Matt Terry': ['Q27994925', 'Matt Terry', 'English singer from Bromley'],
#  'Matěj Ruppert': ['Q12036129', 'Matěj Ruppert', 'Czech singer and actor'],
#  'Maxsta': ['Q6796028', 'Maxsta', 'British rapper'],
#  'Mc Gey': ['Q12034805', 'MC Gey', 'Czech poet, rapper and writer'],
#  'Mccartney Jesse': ['Q191842',
#   'Jesse McCartney',
#   'American singer and actor'],
#  'Italobrothers': ['Q708546', 'ItaloBrothers', 'German dance band'],
#  'J. Cole': ['Q204018', 'J. Cole', 'American rapper and record producer'],
#  'Jack Savoretti': ['Q2905668', 'Jack Savoretti', 'British musician'],
#  'Jackson Wang': ['Q16905948', 'Jackson Wang', 'Chinese rapper'],
#  'Marina And The Diamonds': ['Q234174', 'Marina Diamandis', 'British singer'],
#  'Marc Benjamin': ['Q21880688', 'Marc Benjamin', 'Swiss actor'],
#  'Marc E. Bassy': ['Q26435713',
#   'Marc E. Bassy',
#   'American singer and songwriter'],
#  'Marcus Revolta': ['Q23644798', 'Marek Kaleta', 'Czech rapper'],
#  'Jaroslav Uhlíř': ['Q12024097',
#   'Jaroslav Uhlíř',
#   'Czech composer and pianist'],
#  'Jaroslav Svěcený': ['Q12024082', 'Jaroslav Svěcený', 'Czech violinist'],
#  'Marilyn Manson': ['Q485893', 'Marilyn Manson', 'American rock band'],
#  'Jana Kratochvílová': ['Q12023431', 'Jana Kratochvílová', 'Czech singer'],
#  'Jain': ['Q21405456', 'Jain', 'French recording artist, singer'],
#  'Jana Boušková': ['Q12023397', 'Jana Boušková', 'Czech actress'],
#  'Jan Spálený': ['Q12023116',
#   'Jan Spálený',
#   'Czech musician, frontman of ASPM'],
#  'Jan Smigmator': ['Q15124031', 'Jan Smigmator', 'Czech singer'],
#  'James Newton Howard': ['Q213869',
#   'James Newton Howard',
#   'American composer and music producer (born 1951)'],
#  'James Newman': ['Q55614888', 'James Newman', 'British singer-songwriter'],
#  'James Hype': ['Q47472388', 'James Hype', 'English DJ and record producer'],
#  'Marsyas': ['Q599737', 'Marsyas', 'satyr musician in Greek mythology'],
#  'Inxs': ['Q489801', 'INXS', 'Australian rock band'],
#  'Manu Chao': ['Q207898',
#   'Manu Chao',
#   'French-Spanish singer, guitarist and record producer'],
#  'Hradišťan': ['Q12020603', 'Hradišťan', 'Czech musical ensemble'],
#  'Hot Chelle Rae': ['Q610047', 'Hot Chelle Rae', 'American band'],
#  'Hosh': ['Q1630361', 'Hosh', 'band'],
#  'Hoodie Allen': ['Q39224',
#   'Hoodie Allen',
#   'American rapper, singer and songwriter from New York'],
#  'Holki': ['Q12020002', 'Holki', 'Czech musical group'],
#  'Miloš Dodo Doležal': ['Q12037543',
#   'Miloš Dodo Doležal',
#   'Czech composer, guitarist and singer'],
#  'Miroslav Paleček': ['Q12037947', 'Miroslav Paleček', 'Czech singer'],
#  'Mkto': ['Q3273045', 'MKTO', 'American musical duo'],
#  'Helloween': ['Q158895', 'Helloween', 'German power metal band'],
#  'Hudba Praha': ['Q12020872', 'Hudba Praha', 'Czech rock band'],
#  'Incubus': ['Q1661036', 'Incubus', 'American rock band'],
#  'Indila': ['Q6024866', 'Indila', 'French singer and songwriter'],
#  'Melanie Thornton': ['Q235243',
#   'Melanie Thornton',
#   'American singer (1967–2001)'],
#  'Ilona Csáková': ['Q4181301', 'Ilona Csáková', 'Czech singer'],
#  'Iggy Pop': ['Q182665', 'Iggy Pop', 'American singer'],
#  'Michael Kevin': ['Q672357', 'Michael Paré', 'American actor'],
#  'I.M.T. Smile': ['Q12021379', 'IMT Smile', 'Slovakian musical group'],
#  'Michal Horáček': ['Q8042567',
#   'Michal Horáček',
#   'Czech poet, philanthropist, publicist, entrepreneur and lyricist'],
#  'Michal Pavlíček': ['Q2662052',
#   'Michal Pavlíček',
#   'Czech composer, jazz musician and guitarist'],
#  'Jawsh 685': ['Q96472235', 'Jawsh 685', 'New Zealand music producer'],
#  'Lil Jon': ['Q294449',
#   'Lil Jon',
#   'American rapper and record producer (born 1971)'],
#  'Katapult': ['Q1459279', 'Katapult', 'Czechoslovakian band'],
#  'Lil Pump': ['Q38002101', 'Lil Pump', 'American rapper'],
#  'Kat De Luna': ['Q230514', 'Kat DeLuna', 'American singer'],
#  'Karolína Krézlová': ['Q93367778',
#   'Karolína Krézlová',
#   'Czech actress and model'],
#  'Karmin': ['Q1167969', 'Karmin', 'American musical group; pop duo'],
#  'Karelll': ['Q81805754', 'Karelll', 'Czech singer-songwriter'],
#  'Karel Zich': ['Q3562802',
#   'Karel Zich',
#   'Czech singer, guitarist and composer (1949-2004)'],
#  'Karel Plíhal': ['Q2476370', 'Karel Plíhal', 'Czech guitarist and singer'],
#  'Katy B': ['Q120527', 'Katy B', 'British singer-songwriter'],
#  'Kenny Rogers': ['Q217160',
#   'Kenny Rogers',
#   'American country singer and songwriter (1938–2020)'],
#  'Korn': ['Q80304', 'Korn', 'American nu metal band'],
#  'Kollerband': ['Q107025035', 'Kollerband', 'Czech music band'],
#  'Leony': ['Q97483637', 'Leony', 'German pop singer'],
#  'Klára Kolomazníková': ['Q12029491', 'Klára Kolomazníková', 'Czech singer'],
#  'Lauren Jauregui': ['Q18921974', 'Lauren Jauregui', 'American singer'],
#  'Lauren Spencer-Smith': ['Q110630787',
#   'Lauren Spencer-Smith',
#   'Canadian singer and songwriter'],
#  'Kid Rock': ['Q158175', 'Kid Rock', 'American musician (born 1971)'],
#  'Listenbee': ['Q166796', 'GoonRock', 'American musician'],
#  'Manian': ['Q61415',
#   'DJ Manian',
#   'German music producer, DJ, and label owner'],
#  'Joe Cocker': ['Q190076', 'Joe Cocker', 'English musician (1944–2014)'],
#  'Jodie Harsh': ['Q6207970', 'Jodie Harsh', 'British DJ'],
#  'Mac Miller': ['Q324726',
#   'Mac Miller',
#   'American rapper and record producer (1992–2018)'],
#  'Jiří Suchý': ['Q4177305',
#   'Jiří Suchý',
#   'Czech poet, theater manager, playwright, film director, actor, composer, comedian, writer, artist and singer'],
#  'Jiří Korn': ['Q349116', 'Jiří Korn', 'Czech musician and actor'],
#  'Magdalena Kožená': ['Q240430', 'Magdalena Kožená', 'Czech mezzo-soprano'],
#  'Jethro Tull': ['Q192353', 'Jethro Tull', 'British rock band'],
#  'Jeremih': ['Q472891', 'Jeremih', 'American R&B singer'],
#  'Luude': ['Q110517126', 'Luude', 'Australian music producer and artist'],
#  "K'Naan": ['Q297693', 'K’naan Warsame', 'Somali-Canadian musician'],
#  'Justin Wellington': ['Q107183445', 'Justin Wellington', 'Papuan singer'],
#  'Junior Caldera': ['Q2635908', 'Junior Caldera', 'French DJ'],
#  'Jung Kook': ['Q22338877', 'Jungkook', 'South Korean singer'],
#  'Loud Luxury': ['Q48697885', 'Loud Luxury', 'Canadian musical duo'],
#  'Luboš Pospíšil': ['Q12034136', 'Luboš Pospíšil', 'Czech musician'],
#  'Jp Saxe': ['Q86009464', 'JP Saxe', 'Canadian musician and singer'],
#  'Jordan Haj': ['Q65943308', 'Jordan Haj', 'Czech musician and actor'],
#  'Jon Bellion': ['Q18044284',
#   'Jon Bellion',
#   'American singer, rapper, songwriter, and record producer'],
#  'Jojo': ['Q215219', 'JoJo', 'American singer and actress'],
#  'Hard-Fi': ['Q1123510', 'Hard-Fi', 'Music band'],
#  'Escape The Fate': ['Q991278', 'Escape the Fate', 'American rock band'],
#  'Peggy Gou': ['Q64158576',
#   'Peggy Gou',
#   'South Korean DJ and fashion designer'],
#  'Pet Shop Boys': ['Q485625', 'Pet Shop Boys', 'British synth-pop duo'],
#  'Eric Clapton': ['Q48187',
#   'Eric Clapton',
#   'English guitarist, singer, and songwriter (born 1945)'],
#  'Enya': ['Q38257', 'Enya', 'Irish singer'],
#  'Peter Cmorik': ['Q3509090', 'Peter Cmorik', 'Slovak singer'],
#  'Petite Meller': ['Q20742885', 'Petite Meller', 'French singer and model'],
#  'Petr Hapka': ['Q1348605',
#   'Petr Hapka',
#   'Czech composer and singer (1944–2014)'],
#  'Petr Janda': ['Q504840',
#   'Petr Janda',
#   'Czech rock singer, guitarist, band leader'],
#  'Petr Kalandra': ['Q3299446',
#   'Petr Kalandra',
#   'Czech mouth organ player, guitarist and singer'],
#  'Petr Nekoranec': ['Q79127300', 'Petr Nekoranec', 'opera singer'],
#  'Eva Olmerová': ['Q5415145', 'Eva Olmerová', 'Czech singer'],
#  'Paul Van Dyk': ['Q77034',
#   'Paul van Dyk',
#   'German DJ and trance music producer'],
#  'Originální Pražský Synkopický Orchestr': ['Q7102571',
#   'Original Prague Syncopated Orchestra',
#   'Czech jazz band'],
#  'Fetty Wap': ['Q19361511', 'Fetty Wap', 'American rapper (born 1991)'],
#  'P.O.D.': ['Q494743', 'P.O.D.', 'American nu metal band'],
#  'Feed Me': ['Q1453940', 'Jon Gooch', 'British DJ'],
#  'Faydee': ['Q17148744',
#   'Faydee',
#   'Australian Arabic-language singer-songwriter'],
#  'Fattypillow': ['Q21019433', 'FattyPillow', 'Czech YouTuber'],
#  'Parra For Cuva': ['Q18763221', 'Parra for Cuva', 'German DJ'],
#  'Farruko': ['Q5436372', 'Farruko', 'Puerto Rican singer'],
#  'Emeli Sandé': ['Q470429', 'Emeli Sandé', 'British singer-songwriter'],
#  'Phil Collins': ['Q144622',
#   'Phil Collins',
#   'English drummer, singer, and songwriter (born 1951)'],
#  'Philip George': ['Q18713875', 'Philip George', 'British DJ'],
#  'Public': ['Q211198',
#   'audience',
#   'group of people who participate in a show or encounter a work of art'],
#  'Dj Ross': ['Q280939', 'DJ Ross', 'Italian disc jockey'],
#  'Dj Gollum': ['Q1154096', 'DJ Gollum', 'German disc jockey'],
#  'Dj Cassidy': ['Q16202297', 'DJ Cassidy', 'American DJ and record producer'],
#  'Rachel Platten': ['Q7279360',
#   'Rachel Platten',
#   'American singer and songwriter'],
#  'Rae Sremmurd': ['Q18123226', 'Rae Sremmurd', 'American hip hop duo'],
#  'Discoboys': ['Q2410895', 'The Disco Boys', 'German DJ duo'],
#  'Disco Boys': ['Q2410895', 'The Disco Boys', 'German DJ duo'],
#  'Dirty Heads': ['Q2410892', 'The Dirty Heads', 'American reggae rock band'],
#  'Digital Farm Animals': ['Q24894854',
#   'Digital Farm Animals',
#   'British songwriter, music producer and DJ'],
#  'Diana Krall': ['Q155879',
#   'Diana Krall',
#   'Canadian recording artist; jazz singer and pianist'],
#  'Pink Angels': ['Q4641046', 'Pink Angels', 'Czech girl band'],
#  'Prodigy': ['Q522739',
#   'Prodigy',
#   'American rapper from New York (1974–2017)'],
#  'Dream Theater': ['Q162586',
#   'Dream Theater',
#   'American progressive metal band'],
#  'Portugal. The Man': ['Q606879', 'Portugal. The Man', 'American rock band'],
#  'Dr. Dre': ['Q6078',
#   'Dr. Dre',
#   'American rapper, record producer, and businessman (born 1965)'],
#  'Powfu': ['Q89069821', 'Powfu', 'Canadian rapper and singer'],
#  'Filip Topol': ['Q740044', 'Filip Topol', 'Czech musician (1965-2013)'],
#  'One Ok Rock': ['Q1072736', 'One Ok Rock', 'Japanese rock band'],
#  'One Night Only': ['Q900597', 'One Night Only', 'band'],
#  'Five Finger Death Punch': ['Q749502',
#   'Five Finger Death Punch',
#   'American heavy metal band'],
#  'Naďa Urbánková': ['Q12040463', 'Naďa Urbánková', 'Czech actress and singer'],
#  'Grace Vanderwaal': ['Q26897673',
#   'Grace VanderWaal',
#   'American singer-songwriter'],
#  'Goodboys': ['Q65052503', 'Goodboys', 'English house music group'],
#  'Goldfrapp': ['Q606250', 'Goldfrapp', 'English electronic music duo'],
#  'Gloria Estefan': ['Q184697',
#   'Gloria Estefan',
#   'Cuban-American singer (born 1957)'],
#  'Giorgio Moroder': ['Q312674',
#   'Giorgio Moroder',
#   'Italian record producer and composer'],
#  'Gesaffelstein': ['Q381562', 'Gesaffelstein', 'French electronic musician'],
#  'Gerard Way': ['Q204132', 'Gerard Way', 'American singer'],
#  'Natálie Grossová': ['Q95149181',
#   'Natálie Grossová',
#   'Czech actor, singer, and dancer'],
#  'Greenhorns': ['Q12018456', 'Greenhorns', 'czech country music band'],
#  'Monrose': ['Q30773', 'Monrose', 'German pop band'],
#  'Morcheeba': ['Q749019', 'Morcheeba', 'English electronic band'],
#  'Hadouken!': ['Q1522079', 'Hadouken!', 'British rock/electronica band'],
#  'Haddaway': ['Q156783', 'Haddaway', 'Trinidadian-German singer'],
#  'Gregory Porter': ['Q3116385',
#   'Gregory Porter',
#   'American jazz vocalist, songwriter, and actor'],
#  'Grouplove': ['Q1153346', 'Grouplove', 'American rock band'],
#  'Natalie La Rose': ['Q19019113',
#   'Natalie La Rose',
#   'Dutch–Surinamese singer, songwriter and dancer'],
#  'Greta Van Fleet': ['Q30636835',
#   'Greta Van Fleet',
#   'American rock band from Frankenmuth, Michigan'],
#  'George Michael': ['Q130311',
#   'George Michael',
#   'English singer-songwriter (1963–2016)'],
#  'Geo Da Silva': ['Q5533940', 'Geo Da Silva', 'Romanian DJ'],
#  'Frankie Goes To Hollywood': ['Q73597',
#   'Frankie Goes to Hollywood',
#   'British band'],
#  ...}

# %%
pochybni = {key: value for key, value in qecka.items() if value[2] is not None and not any(word in value[2] for word in hudebni_slova)}

# %%
len(pochybni)
# Out:
# 375

# %%
pochybni
# Out:
# {'Kryštof': ['Q1770777', 'Kryštof', 'male given name'],
#  'Verona': ['Q2028', 'Verona', 'city in Veneto, northern Italy'],
#  'Anna K.': ['Q86723556', 'Anna K.', 'refrigerated cargo ship built in 1949'],
#  'O5': ['Q6544459',
#   'lieutenant colonel',
#   'military rank of the United States'],
#  'Lucie': ['Q1617357', 'Lucie', 'female given name'],
#  'Ego': ['Q4426116', 'ego', 'self-identity in the psyche'],
#  'Petr Kolář': ['Q7178537', 'Petr Kolář', 'Czech diplomat'],
#  'Mig 21': ['Q150609', 'MiG-21', 'fighter aircraft family by Mikoyan'],
#  'Billy Mack': ['Q100878487',
#   'Billy Mack',
#   'college basketball player (1989–1989) Long Island University'],
#  'Drake': ['Q7559', 'dragon', 'legendary creature'],
#  'Queen': ['Q116', 'monarch', 'person at the head of a monarchy'],
#  'Lenny': ['Q1667498', 'Lenny', 'male given name'],
#  'Bastille': ['Q1865480', 'Bastille', 'former fortress in Paris, France'],
#  'Jelen': ['Q12024449', 'Jelen', 'family name'],
#  'Madonna': ['Q345', 'Virgin Mary', 'Mother of Jesus'],
#  'Sebastian': ['Q4844560', 'Sebastian', 'male given name'],
#  'Voxel': ['Q663554',
#   'voxel',
#   'element representing a value on a grid in three dimensional space'],
#  'Mirai': ['Q1790116',
#   'Miraí',
#   'Brazilian municipality located in the state of Minas Gerais'],
#  'Train': ['Q870',
#   'train',
#   'form of rail transport consisting of a series of connected vehicles'],
#  'Lake Malawi': ['Q5532', 'Lake Malawi', 'African Great Lake'],
#  'Poetika': ['Q50811691',
#   'Jurnal Poetika',
#   'Academic journal published by Universitas Gadjah Mada , covering the subjects:  Language and Literature: Literature (General)'],
#  'Script': ['Q8192',
#   'writing system',
#   'any conventional method of visually representing verbal or signed communication'],
#  'Lipo': ['Q898512',
#   'lithium polymer battery',
#   'lithium-ion battery using a polymer electrolyte'],
#  'Různí': ['Q115480582',
#   'Ruzniyati binti Mohammad Norwawi',
#   'Daughter of Mohammad Norwawi bin Mohammad Lassim (born 1967)'],
#  'Sigala': ['Q658864', 'Sigale', 'commune in Alpes-Maritimes, France'],
#  'Calin': ['Q64785850', 'George A. Calin', 'Molecular Pathology researcher'],
#  'Seeb': ['Q948050', 'Seeb', 'City in Oman'],
#  'Dara Rolins': ['Q3502562',
#   'Dara Rolins',
#   'Slovak recording artist and entrepreneur'],
#  'Clou': ['Q8074',
#   'cloud',
#   'visible mass of liquid droplets or frozen crystals suspended in the atmosphere'],
#  'Marquess': ['Q209726',
#   'marquess',
#   'hereditary rank in various European peerages'],
#  'Lp': ['Q841983', 'LP record', 'longplay record'],
#  'Rest': ['Q35831',
#   'sleep',
#   'naturally recurring resting state of mind and body'],
#  'Sima': ['Q338009', 'Shima', 'city in Mie Prefecture, Japan'],
#  'Alok': ['Q736329', 'Clarias', 'genus of fishes'],
#  'Gleb': ['Q3787148', 'Gleb', 'male given name (Глеб)'],
#  'Nebe': ['Q1973208', 'Nebe', 'family name'],
#  'Sigma': ['Q14413', 'Σ', 'eighteenth letter of the Greek alphabet'],
#  'Kali': ['Q51103',
#   'Cali',
#   'capital of the Colombian department of Valle del Cauca'],
#  'Smack': ['Q60168',
#   'heroin',
#   'chemical compound; opioid most commonly used as a recreational drug for its euphoric effects'],
#  'Mista': ['Q1787955', 'Mista', 'Spanish footballer'],
#  'Tina': ['Q1670074', 'Tina', 'female given name'],
#  'Earth': ['Q2', 'Earth', 'third planet from the Sun in the Solar System'],
#  'Milion+': ['Q101418887', 'Milion+ Entertainment', 'Czech hip-hop label'],
#  'Milow': ['Q674445', 'Milow', 'municipality of Germany'],
#  'Fate Magazine': ['Q3067175',
#   'Fate',
#   'American magazine about paranormal phenomena'],
#  'Offspring': ['Q239526',
#   'offspring',
#   'in biology, the product of reproduction of an organism'],
#  'Decky': ['Q91078730',
#   'Decky I Junaedi',
#   'researcher (ORCID 0000-0001-5846-6135)'],
#  'Dj Wich': ['Q5205502', 'DJ Wich', 'Czech disk jockey'],
#  'Example': ['Q14944328',
#   'example',
#   'thing which acts as a typical representative of a set of things'],
#  'Timmy White': ['Q19663658', 'Timothy White', 'American kidnap victim'],
#  'Meduza': ['Q18340732',
#   'Meduza',
#   'Russian bilingual online newspaper headquartered in Riga'],
#  'Udg': ['Q1814503',
#   'University of Girona',
#   'public university based in Girona'],
#  'B.O.B.': ['Q2876628', 'B.O.B.', '1993 video game'],
#  'Anne-Marie': ['Q18091413', 'Anne-Marie', 'female given name'],
#  'Wiley': ['Q1479654', 'Wiley', 'American multinational publishing company'],
#  'Like-It': ['Q61993939', 'Like It', '2019 single by Zinaida Kupriyanovich'],
#  'Victoria': ['Q36687', 'Victoria', 'state of Australia'],
#  'Lenka': ['Q1865968', 'Lenka', 'female given name'],
#  'Separ': ['Q6130863',
#   'Sociedad Española de Neumología y Cirugía Torácica',
#   'other organization in Barcelona, Spain'],
#  'Lauv': ['Q804970', 'Liu', 'surname (劉/刘)'],
#  'Muse': ['Q579348', 'alprostadil', 'chemical compound'],
#  'Sheppard': ['Q27429821', 'Sheppard', 'family name'],
#  'Kristina': ['Q19798802', 'Kristina', 'female given name'],
#  'Scooter': ['Q193234',
#   'motor scooter',
#   'type of motorcycle with an emphasis on fuel economy and a riding position of sitting upright'],
#  'September': ['Q123',
#   'September',
#   'ninth month in the Julian and Gregorian calendars'],
#  'Hasan': ['Q13564155', 'Hasan', 'male given name'],
#  'Labello': ['Q1799401', 'Labello', 'brand of lip balm stick'],
#  'Monkey Business': ['Q580022',
#   'Monkey Business',
#   '2005 studio album by Black Eyed Peas'],
#  'Light': ['Q76299',
#   'visible spectrum',
#   'portion of the electromagnetic spectrum that is visible to the human eye'],
#  'Mk': ['Q221', 'North Macedonia', 'country in southeastern Europe'],
#  'Milk': ['Q8495',
#   'milk',
#   'white liquid produced by the mammary glands of mammals'],
#  'Olympic': ['Q321007',
#   'RMS Olympic',
#   'Lead ship of the Olympic-Class ocean liners. Sister ship to RMS Titanic and HMHS Britannic'],
#  'Mabel': ['Q949355', 'Mabel', 'female given name'],
#  'Faul': ['Q56245818', 'Faul', 'family name'],
#  'James Harries': ['Q75297546', 'James Hugh Harries', '(born 1972)'],
#  'J.A.R.': ['Q933794', 'J.A.R.', 'single'],
#  'Dorian': ['Q909104', 'Dorian', 'male given name'],
#  'Anna Jiřina': ['Q81906077',
#   'Anna Jiřina Pavlasová',
#   'Czech ice hockey player'],
#  'Tereza Mašková': ['Q90726700',
#   'Tereza Mašková',
#   'researcher (ORCID 0000-0001-8386-5146)'],
#  'Wanted': ['Q4444', 'Wanted', '2008 film directed by Timur Bekmambetov'],
#  'Dido': ['Q905162', 'Dido', 'legendary founder and first queen of Carthage'],
#  'Topic': ['Q2751586',
#   'resolution',
#   'written declaration adopted by a deliberative body'],
#  'Rodan': ['Q30755', 'Auguste Rodin', 'French sculptor'],
#  'Atb': ['Q855199',
#   'CD Atlético Baleares',
#   'association football club in Palma, Majorca, Spain'],
#  'Digital Fever': ['Q58548836',
#   "Digital fever: A scholar's copyright dilemma1",
#   'article'],
#  'Sensey': ['Q30263181',
#   'SENSEYE LIMITED',
#   'company in Southampton, United Kingdom'],
#  'Dms': ['Q831677',
#   'document management system',
#   'software that provides an automated way to store, manage and track electronic documents'],
#  'Seal': ['Q162919',
#   'seal',
#   'mark of a personal distinctive emblem intended to guarantee the authenticity of the author of a document onto which it is printed, embossed or affixed'],
#  'Years': ['Q24564698', 'years old', 'unit for age'],
#  'Jackson Michael': ['Q3701494', 'Dane', 'comic character'],
#  'Sigrid': ['Q634916', 'Sigrid', 'female given name'],
#  'Momo': ['Q22508', 'Momo', 'Italian comune in Piedmont'],
#  'Markéta': ['Q17457234', 'Markéta', 'female given name'],
#  'Indy': ['Q6346',
#   'Indianapolis',
#   'city in and county seat of Marion County, Indiana, United States and the Indiana federated state capital city'],
#  'Minelli': ['Q37543529', 'Minelli', 'family name'],
#  'Marcell': ['Q27553744', 'Marcell', 'male given name'],
#  'Ajr': ['Q1430874', 'Arvidsjaur Airport', 'airport'],
#  'Alma': ['Q656870', 'Alma', 'female given name'],
#  'Agnes': ['Q394431', 'Agnes', 'female given name'],
#  'Lany': ['Q1852483',
#   'Lány',
#   'village in Kladno District of Central Bohemian region'],
#  '58G': ['Q61667270',
#   'Washington County Regional Medical Center heliport',
#   'heliport in Washington County, Georgia, United States'],
#  'Koky': ['Q15208105', 'Koky', 'family name'],
#  'Kokab': ['Q4260626', 'Kokabiel', 'fallen angel in the Hebrew bible'],
#  'Zayo': ['Q428311',
#   'Józef Zajączek',
#   'Polish general and politician (1752-1826)'],
#  'Le Monde': ['Q12461',
#   'Le Monde',
#   'French daily evening newspaper founded in 1944'],
#  'Killers': ['Q275550', 'Killers', '1981 studio album by Iron Maiden'],
#  'Logic': ['Q8078', 'logic', 'study of correct reasoning'],
#  'Avener': ['Q4828049', 'Avener', 'chief officer of the stables of a king'],
#  'Maduar': ['Q60376371', 'Maduarchak', 'village in Bankura district'],
#  'Jessie J.': ['Q69773990',
#   'Jessie J. Edwards Public Library',
#   'public library in Coldwater, Mississippi, USA'],
#  'Traktor': ['Q1985954', 'Torpedo Olleart FC', 'Russian football club'],
#  'Maniak': ['Q36913816', 'Maniak', 'family name'],
#  'Annabelle': ['Q15816857', 'Annabelle', 'female given name'],
#  'Lucas': ['Q320980', 'Lucas van Leyden', 'artist, painter (1494-1533)'],
#  'Shouse': ['Q56245135', 'Shouse', 'family name'],
#  'Dalyb': ['Q1958225', 'Ivan Vahylevych', 'Ukrainian poet'],
#  'Passenger': ['Q319604',
#   'passenger',
#   'person who travels in a vehicle without operating it'],
#  'D.Y.K.': ['Q61657631', 'Deryck Chan', 'researcher, Wikimedian'],
#  'Gayle': ['Q1417358', 'Gayle', 'unisex given name'],
#  'P T K': ['Q47749550', 'Praveen T. Krishnamurthy', 'researcher'],
#  'Deethane': ['Q69481982', 'DeeThane', 'Czech streamer'],
#  'Nea': ['Q217526',
#   'near-Earth asteroid',
#   'objects in a near-Earth orbit without the tail or coma of a comet'],
#  'Remme': ['Q36991563', 'Remme', 'family name'],
#  'Patricie': ['Q18060507', 'Patricie', 'female given name'],
#  'Reginald': ['Q16280865', 'Reginald', 'male given name'],
#  'Placebo': ['Q269829',
#   'placebo',
#   'substance or treatment of no therapeutic value'],
#  'Zagorová': ['Q99771809', 'Zagorová', 'family name; Czech female surname'],
#  'Lena': ['Q654581', 'Lena', 'female given name'],
#  'Puerto': ['Q1183',
#   'Puerto Rico',
#   'unincorporated territory of the United States of America'],
#  'Laurell': ['Q28150740', 'Laurell', 'family name'],
#  'Zemětřesení': ['Q7944',
#   'earthquake',
#   "result of a sudden release of energy in the Earth's crust that creates seismic waves"],
#  'Psy': ['Q622871', 'psychedelic trance', 'subgenre of trance music'],
#  'Portless': ['Q80590485',
#   'Portless endoscopic adrenalectomy via a single minimal incision using a retroperitoneal approach: experience with initial 30 cases',
#   'scientific article published on 01 September 2004'],
#  'Pekař': ['Q55808182', 'Pekař', 'family name'],
#  'Wilkinson': ['Q347929', 'Wilkinson', 'family name'],
#  'Lindemann': ['Q1826030', 'Lindemann', 'family name'],
#  'Peter Bjorn': ['Q91908430', 'Peter Bjorn', 'Canadian sailor'],
#  'Peter Nagy': ['Q39050287', 'Peter Nagy', 'Hungarian biologist'],
#  'Picture This': ['Q1510089',
#   'Picture This',
#   '2008 film directed by Stephen Herek'],
#  'Lexter': ['Q100723870',
#   'Lexter Bailey',
#   'college basketball player (1981–1981) Xavier'],
#  'Vesna': ['Q1520457', 'Vesna', 'female given name'],
#  'Nedvědi': ['Q1611797',
#   'Nedvědice',
#   'městys in South Moravian, Czech Republic'],
#  'Supafly Inc.': ['Q2114694', 'Supafly', 'English dance act'],
#  'Mikael': ['Q45581',
#   'Michael',
#   'archangel in Jewish, Christian, and Islamic teachings'],
#  'Svěrák': ['Q1175513', 'Svěrák', 'family name'],
#  'Michal Horák': ['Q85413487', 'Michal Horák', 'researcher'],
#  'Nela': ['Q18086568', 'Nela', 'female given name'],
#  'Saul': ['Q9200',
#   'Paul the Apostle',
#   'Early Christian apostle and missionary (c. AD 5 – c. 64/65)'],
#  'Metro Station': ['Q928830',
#   'metro station',
#   'railway station of a rapid transit system'],
#  'Verve': ['Q16682455',
#   'Verve',
#   'French magazine devoted to art and literature'],
#  'Shifty': ['Q21528271', 'Shifty', 'Happy Tree Friends character'],
#  'Shimmi': ['Q26444682', 'Shinmi', 'Japanese family name (人見)'],
#  'Sheen': ['Q2303477',
#   'Sheen',
#   'village and civil parish in Staffordshire, England'],
#  'Mustard': ['Q58677', 'Brassica', 'genus of plants'],
#  'Skyline': ['Q43261',
#   'horizon',
#   'apparent line that separates earth from sky'],
#  'Mo': ['Q105', 'Monday', 'day of the week'],
#  'Mimoza': ['Q20000751', 'Mimoza', 'female given name'],
#  'Tool': ['Q39546',
#   'tool',
#   'physical item that can be used to achieve a goal'],
#  'Oceana': ['Q148360', '224 Oceana', 'main-belt asteroid'],
#  'Rooney': ['Q16882268', 'Rooney', 'surname of Irish origins'],
#  'Omi': ['Q1336967',
#   'Missionary Oblates of Mary Immaculate',
#   'Catholic missionary congregation for men'],
#  'Normandie': ['Q18677875', 'Normandy', 'region of France'],
#  'Matrix': ['Q44337',
#   'matrix',
#   'rectangular array of numbers, symbols, or expressions, arranged in rows and columns'],
#  'Thomas Gold': ['Q93562',
#   'Thomas Gold',
#   'Austrian astrophysicist (1920-2004)'],
#  'Rumpál': ['Q12050356', 'Rumpál', 'protected area in Czech Republic'],
#  'Niko': ['Q11884464', 'Niko', 'male given name'],
#  'Nohavica': ['Q282947', '6539 Nohavica', 'asteroid'],
#  'Mike Perry': ['Q27749823',
#   'Mike Perry',
#   'American mixed martial arts fighter'],
#  'Bingo Players': ['Q863851',
#   'Bingo Players',
#   'Dutch electronic music project by Maarten Hoogstraten'],
#  'Hex': ['Q82828', 'hexadecimal', 'numeral system with 16 as its base'],
#  'Hello Goodbye': ['Q281911',
#   'Hello, Goodbye',
#   'original song written and composed by Lennon-McCartney; first recorded by The Beatles'],
#  'Gracey (': ['Q5591483',
#   'Gracey (Leontine) Elementary School',
#   'in Merced, California'],
#  'Gabriela': ['Q11971424', 'Gabriela', 'female given name'],
#  'Cann': ['Q16825463', 'Cann', 'family name'],
#  'James Bay': ['Q223810',
#   'James Bay',
#   'bay in Nunavut at the southern end of the Hudson Bay, Canada'],
#  'Iglu': ['Q23045094', 'Iglu', 'public art in Turku, Finland'],
#  'Frans': ['Q3480175', 'Frans', 'male given name'],
#  'Frank Wild': ['Q591807',
#   'Frank Wild',
#   'British Antarctica explorer (1873-1939)'],
#  'Elly': ['Q2293288', 'Elly', 'female given name'],
#  'Daniell': ['Q708907',
#   'Thomas Daniell',
#   'English landscape painter (1749-1840)'],
#  'Elize': ['Q21142460', 'Elize', 'given name'],
#  'Eli': ['Q1328791', 'Eli', 'unisex given name'],
#  'Elena': ['Q1209486', 'Elena', 'female given name'],
#  'Dommi': ['Q12045',
#   'Dommitzsch',
#   'town in the district Nordsachsen, in the Free State of Saxony, Germany'],
#  'David Michal': ['Q20755140', 'David Michal', 'Czech lawyer'],
#  'Disciples': ['Q1541206',
#   'Christian Church (Disciples of Christ)',
#   'Restorationist Mainline Protestant denomination in the United States and Canada'],
#  'Dagny': ['Q1418583', 'Dagny', 'commune in Seine-et-Marne, France'],
#  'Ceha': ['Q67587235',
#   'Centro de Estudos de História do Atlântico',
#   'Portuguese research center in Madeira'],
#  'Fort Minor': ['Q493729',
#   'Fort Minor',
#   'Hip hop side project of Mike Shinoda'],
#  'Cherish': ['Q1070284', 'Cherish', 'Madonna song'],
#  'Chipmunk': ['Q22364', 'Tamias', 'genus of mammals'],
#  'Fences': ['Q25136220', 'Fences', '2016 film by Denzel Washington'],
#  'Feder': ['Q1399295', 'Feder', 'family name'],
#  'Coolers': ['Q31621233',
#   'Coolers Knob Mountain',
#   'mountain in North Carolina, United States of America'],
#  'Empire Of The Sun': ['Q271281',
#   'Empire of the Sun',
#   '1987 film directed by Steven Spielberg'],
#  'Alžběta': ['Q18073645', 'Alžběta', 'female given name'],
#  'Klaas': ['Q19688670', 'Klaas', 'male given name'],
#  'Klara': ['Q18199028', 'Klara', 'female given name'],
#  'Karlo': ['Q18683428', 'Karlo', 'male given name'],
#  'Kamrad': ['Q37541161', 'Kamrad', 'family name'],
#  'All Saints': ['Q587', "All Saints' Day", 'Christian feast day'],
#  'Ac': ['Q81292', 'acre', 'unit of area'],
#  'Ak': ['Q797', 'Alaska', 'state of the United States of America'],
#  'Jubel': ['Q15702941',
#   'Jubel',
#   'song directed by Michael Johansson & Johan Rosell'],
#  'Koukr': ['Q28302267', 'Koukr', 'hill in Morocco'],
#  'Kris': ['Q1430023', 'Kris', 'unisex given name'],
#  '2 Pac': ['Q112240732', '2 Packesel', 'painting by H.v. Zügel'],
#  'Rembrandts': ['Q352864', 'Pieter Lastman', 'Dutch painter'],
#  'Shalom': ['Q240562', 'Shalom', 'word'],
#  'Set It Off': ['Q962544', 'Set It Off', '1996 film directed by F. Gary Gray'],
#  'Chawki': ['Q7491265', 'Chawqi', 'Arabic name: given name, surname'],
#  'Clayton Adam': ['Q86650545', 'Clayton Adam', 'researcher'],
#  'Clare Alex': ['Q113277698',
#   'Clare Alexandra Balboni',
#   'former doctoral candidate at the London School of Economics and Political Science'],
#  'Rene La Taupe': ['Q1911104', 'René la Taupe', 'fictional character'],
#  'Scorpions': ['Q19125', 'scorpion', 'order of arachnids'],
#  'Citron': ['Q150064', 'Citrus medica', 'species of citrus plant'],
#  'Ren': ['Q7386141', 'Rén', 'Chinese surname (任)'],
#  'Delano': ['Q775868', 'Delano', 'city in California'],
#  'Redl': ['Q20727042', 'Redl', 'family name'],
#  'Calling': ['Q2478472', 'Calling', '2009 video game'],
#  'Skardu': ['Q976955', 'Skardu', 'city in Gilgit-Baltistan, Pakistan'],
#  'Shy Martin': ['Q30331222', 'Shy Martin', 'Swedish artist'],
#  'Carter': ['Q16101731', 'Carter', 'family name'],
#  'Alessandra': ['Q4960889', 'Alessandra', 'female given name'],
#  'Celeste': ['Q3664222', 'Celeste', 'male or female given name'],
#  'Cavalier': ['Q2284765',
#   'Cavalier',
#   'royalist supporter during and following the English Civil War'],
#  'Wombats': ['Q23175', 'Vombatidae', 'family of mammals'],
#  'Rema': ['Q1949189', 'Moses Isserles', 'Polish rabbi'],
#  'Sasha': ['Q17501806', 'Aleksandr', 'male given name (Александр)'],
#  'Dance Nation': ['Q3013343', 'Dance Nation', 'British record label'],
#  'David Ross': ['Q1364954',
#   'William David Ross',
#   'Scottish philosopher and translator'],
#  'Roe-Deer': ['Q122069', 'roe deer', 'species of mammal'],
#  'Zhu': ['Q13391907', 'Zhu', 'surname (朱)'],
#  'Dar': ['Q1441762', 'aspect ratio', 'width/height proportion of an image'],
#  'Roch Jean': ['Q122382171',
#   'Roch Jean Baptiste Donas',
#   'Born to a family originally from Angers. French, Painter, sculptor, engraver. Active at the beginning of the 19th century.'],
#  'Robert Grace': ['Q91121090',
#   'Robert F Grace',
#   'researcher (ORCID 0000-0003-1523-9674)'],
#  'Corrs': ['Q5173038',
#   'Corrs Chambers Westgarth',
#   'Australian commercial law firm'],
#  'Corina': ['Q18177251', 'Corina', 'female given name'],
#  'Code Red': ['Q1105649', 'Code Red', 'a computer worm'],
#  'Skipe': ['Q24943172', 'Skipe', 'human settlement in India'],
#  'Bazzi': ['Q8506', 'Il Sodoma', 'Italian Renaissance painter (1477-1549)'],
#  'Top 10': ['Q50376815',
#   'top list',
#   'list of the top, biggest, best, or other superlative items'],
#  'Another Way': ['Q1475218', 'Another Way', '1982 film by Károly Makk'],
#  'Tom Ferry': ['Q102205885',
#   'Thomas Alan Ferryman',
#   'Ph.D. University of California, Riverside 1995'],
#  'Tkx': ['Q7677281', 'Takaroa Airport', 'airport in France'],
#  'Válová': ['Q111777771', 'Válová', 'family name'],
#  'Banket': ['Q2268252', 'Banket', 'type of pastry or cookie'],
#  'Uniting Nations': ['Q1476064', 'Uniting Nations', 'British dance music act'],
#  'Valerie': ['Q1068242', 'Valerie', 'female given name'],
#  'Vamps': ['Q222573',
#   'femme fatale',
#   'stock character; beautiful but mischievous and traitorous woman'],
#  'Asbjorn': ['Q721398', 'Asbjørn', 'male given name'],
#  'Aviva': ['Q791179', 'Aviva', 'British insurance company'],
#  'Travis': ['Q14500511', 'Travis', 'male given name'],
#  'Aqua': ['Q283',
#   'water',
#   'chemical compound with raw molecular formula H₂O; main constituent of the fluids of most living organisms'],
#  'Ty Nikdy': ['Q12060045', 'Ty Nikdy', 'Ty Nikdy (Recording Label)'],
#  'Berre': ['Q2332816', 'Berre', 'River in France'],
#  'Andrea Kalousová': ['Q19902537', 'Andrea Kalousová', 'Czech model'],
#  'Alice Springs': ['Q17872',
#   'Alice Springs',
#   'city in the Northern Territory, Australia'],
#  'Stargate': ['Q11927',
#   'Stargate',
#   'American adventure military science fiction franchise'],
#  'Willy William': ['Q17016749', 'Willy William', 'French artist'],
#  'Style': ['Q1792644',
#   'art style',
#   'classification of artwork, based on how it is perceived by the audience, specific to an artist, or shared with other works of the same movement or school'],
#  'Sunblock': ['Q827658',
#   'sunscreen',
#   'topical skin product that helps protect against sunburn'],
#  'Sunshine': ['Q478212', 'Sunshine', '2007 film directed by Danny Boyle'],
#  'Thomas Rob': ['Q43390200', 'Thomas Rob', 'accused of witchcraft'],
#  'Skye': ['Q107393',
#   'Isle of Skye',
#   'largest and most northerly large island in the Inner Hebrides of Scotland'],
#  'Source': ['Q7376362', 'river source', 'starting point of a river'],
#  'Southpaw': ['Q17276718', 'Southpaw', '2015 film directed by Antoine Fuqua'],
#  'Bow Wave': ['Q1413252',
#   'bow wave',
#   'wave that forms at the bow of a ship when it moves through the water'],
#  'The Mag': ['Q63070', 'Mary Magdalene', 'follower of Jesus'],
#  'Blanka': ['Q804338', 'Blanka', 'female given name'],
#  'Wen': ['Q313324', 'Bai Juyi', 'Chinese poet of the Tang Dynasty (772-846)'],
#  'Amco': ['Q48803426', 'AMCO', 'Italian financial company'],
#  'Americanos': ['Q4745598', 'Americanos', '1989 single by Holly Johnson'],
#  'Rebels': ['Q28787',
#   'Star Wars Rebels',
#   'American 3D CGI animated television series from 2014–2018'],
#  'System Of': ['Q315', 'language', 'structured system of communication'],
#  'Blonde': ['Q66823622', 'Blonde', '2022 film directed by Andrew Dominik'],
#  'Kubb': ['Q1501493', 'Kubb', 'game of skill'],
#  'Martin John': ['Q6775821', 'Martin John', 'footballer'],
#  'J-Art': ['Q27720716',
#   'Journal of artificial organs : the official journal of the Japanese Society for Artificial Organs',
#   'journal'],
#  'Matadors': ['Q5018231',
#   'Cal State Northridge Matadors',
#   'intercollegiate sports program of California State University, Northridge'],
#  'Iva': ['Q3467906', 'virtual assistant', 'mobile software agent'],
#  'Marcus': ['Q31966',
#   'Mark the Evangelist',
#   'credited author of the Gospel of Mark and Christian saint; traditionally identified with John Mark'],
#  'Marek': ['Q17520946', 'Marek', 'male given name'],
#  'Jan Bartoš': ['Q18746011', 'Jan Bartoš', 'Czech sculptor'],
#  'Jam': ['Q766', 'Jamaica', 'country in the Caribbean Sea'],
#  'Hráč Roku': ['Q477964', 'IHF World Player of the Year', 'award'],
#  'Horal': ['Q1874026',
#   'High Council for Artisanal Lambic Beers',
#   'organization from Belgium'],
#  'Milion Plus': ['Q101418887', 'Milion+ Entertainment', 'Czech hip-hop label'],
#  'Holly Rae': ['Q76087398', 'Holly Rae', 'Peerage person ID=521431'],
#  'Hilton Paris': ['Q2992084', 'Hilton Paris Opera', 'hotel in Paris, France'],
#  'Highland': ['Q208279', 'Highland', 'council area in the Scottish Highlands'],
#  'Mighty Oaks': ['Q15835180',
#   'Mighty Oaks',
#   'multinational Indie-Folkpop-Band from Berlin'],
#  'Michele Lea': ['Q18814454', 'Kristiaan Reuder', 'Dutch painter'],
#  'Melee': ['Q1052131',
#   'Super Smash Bros. Melee',
#   'crossover fighting video game developed by Nintendo for the Nintendo GameCube in 2001'],
#  'Memphis': ['Q16563',
#   'Memphis',
#   'city in and county seat of Shelby County, Tennessee, United States'],
#  'Indigo': ['Q422662', 'indigo', 'chemical compound; food additive and dye'],
#  'Hugel': ['Q526673',
#   'Charles von Hügel',
#   'Austrian noble, army officer, diplomat, botanist, and explorer'],
#  'Ille': ['Q1244595', 'Ille', 'river in France'],
#  'I Love Makonnen': ['Q18713668',
#   'ILoveMakonnen',
#   'extended play by ILoveMakonnen'],
#  'Marasco': ['Q37127335', 'Marasco', 'family name'],
#  'Dev': ['Q5482740', 'programmer', 'person who writes computer software'],
#  'Katherine': ['Q108631', 'Katherine', 'feminine given name'],
#  'Lil Huddy': ['Q90354235', 'Huddy', 'American Internet celebrity'],
#  'Kat Von D': ['Q234527',
#   'Kat Von D',
#   'American tattoo artist and television personality'],
#  'Lily Moore': ['Q76150606', 'Lily Moore', 'Peerage person ID=565784'],
#  'Karma': ['Q132196', 'karma', 'spiritual concept'],
#  'Lip': ['Q15173', 'lip', 'visible body part at the mouth'],
#  'Kelvin Jones': ['Q56513900', 'Kelvin E Jones', 'researcher'],
#  'Kriss': ['Q331220',
#   'Kris',
#   'traditional Javanese dagger and sword (usually curvy) originally from Java'],
#  'L.L.A.M.A': ['Q63411699', 'L.L.A.M.A.', '2019 board game'],
#  'La Vision': ['Q76339512',
#   'La Vision',
#   'print in the National Gallery of Art (NGA 135541)'],
#  'Kooks': ['Q6430557', 'Kooks', 'David Bowie song'],
#  'Koa': ['Q1777801', 'Acacia koa', 'species of plant'],
#  'Lmc': ['Q49957',
#   'Large Magellanic Cloud',
#   'irregular galaxy, satellite of the Milky Way'],
#  'Loko Loko': ['Q35345176',
#   'Loko Lokoboro',
#   'stream in East Nusa Tenggara, Indonesia'],
#  'Jewel': ['Q83437', 'gemstone', 'piece of mineral used to make jewelry'],
#  'Magic Box': ['Q2067812', 'Star TV', 'Turkish television station'],
#  'Mairee': ['Q6736922', 'Maireella', 'genus of fungi'],
#  'Majestic': ['Q1322943', 'The Majestic', '2001 film by Frank Darabont'],
#  'Jeanette': ['Q2300098', 'Jeanette', 'female given name'],
#  'Lokomotiva': ['Q3449286',
#   'RK Lokomotiva Zagreb',
#   'handball club in Zagreb, Croatia'],
#  'Luciana': ['Q11247717', 'Luciana', 'female given name'],
#  'Luisa': ['Q18092018', 'Luisa', 'female given name'],
#  'Embassy': ['Q3917681',
#   'embassy',
#   'permanent diplomatic mission of higher level, representing its operator in the country the embassy is in'],
#  'Estelle': ['Q744012', 'Estelle', 'female given name'],
#  'Pestalozzi': ['Q150450', '2970 Pestalozzi', 'asteroid'],
#  'Endor': ['Q79734', 'Middle-earth', 'fictional continent in Arda'],
#  'Endless Summer': ['Q847722', 'Endless Summer', 'Oceana song/single'],
#  'Peter Pann': ['Q75847742',
#   'Pieter de Pannemaker',
#   'South Netherlandish tapestry weaver, flourished 1517-1532'],
#  'Emily': ['Q18121477', 'Emily', 'female given name'],
#  'Petr Novák': ['Q57330890',
#   'Petr Novák',
#   'Czech microbiologist and mycologist'],
#  'Pain': ['Q81938', 'pain', 'type of unpleasant feeling'],
#  'Opus': ['Q1466199', 'Opus', 'audio compression format'],
#  'Orson': ['Q16585237', 'Orson', 'male given name'],
#  'Fellas': ['Q7371', 'Federico Fellini', 'Italian filmmaker (1920–1993)'],
#  'Exit': ['Q854429', 'portal', 'opening in the walls of a structure'],
#  'Fast Boy': ['Q5436890', 'Fast Boy/Liquid Lips', 'single by The Bluetones'],
#  'Fame': ['Q640994', 'Fame', '1982 TV series'],
#  'Hannah': ['Q1554377', 'Hannah', 'female given name'],
#  'Rangers': ['Q19597',
#   'Rangers F.C.',
#   'association football club in Glasgow, Scotland'],
#  'Doga': ['Q1484546', '10504 Doga', 'asteroid'],
#  'Psh': ['Q339353',
#   'pumped-storage power station',
#   'hydroelectric energy storage station using two water reservoirs connected with a pump and a turbine'],
#  'Pilot': ['Q2095549',
#   'aircraft pilot',
#   'person controlling an aircraft in flight'],
#  'Pirates': ['Q653772',
#   'Pittsburgh Pirates',
#   'baseball team and Major League Baseball franchise in Pittsburgh, Pennsylvania, United States'],
#  'Elizabeth': ['Q138311',
#   'Elizabeth',
#   'city in and county seat of Union County, New Jersey, United States'],
#  'Elis': ['Q217667',
#   'Elis',
#   'ancient city-state, capital city of the district of Elis'],
#  'Eki': ['Q18041828',
#   'ETNK1',
#   'protein-coding gene in the species Homo sapiens'],
#  'Eamon': ['Q20804431', 'Eamon', 'male given name'],
#  'Post': ['Q49845',
#   'mail',
#   'system for transporting documents and other small packages'],
#  'Prezioso': ['Q37555394', 'Prezioso', 'family name'],
#  'Priessnitz': ['Q113077', 'Vincenz Priessnitz', 'Austrian hydrotherapist'],
#  'Prince': ['Q2747456',
#   'prince',
#   'son of a prince, king, queen, emperor or empress, or other high-ranking person (such as a grand duke)'],
#  'Grant Hugh': ['Q47696983', 'Grant L Hughes', 'researcher'],
#  'Navos': ['Q58039499', 'NAVOS', 'Czech company'],
#  'Grace': ['Q1541047', 'Grace', 'female given name'],
#  'Gossip': ['Q854648',
#   'gossip',
#   'idle talk or rumor, especially about personal or private affairs of others'],
#  'Gojira': ['Q6567',
#   'Godzilla',
#   'fictional giant monster that first appeared in the 1954 Godzilla movie "Gojira".'],
#  'Gnash': ['Q1142317',
#   'Gnash',
#   'discontinued media player for playing SWF files'],
#  'Neny': ['Q65111345', 'Neny', 'family name'],
#  'Gisele': ['Q16880343', 'Gisele', 'female given name'],
#  'Hank': ['Q19819765', 'Hank', 'male given name'],
#  'Hana': ['Q3126650', 'Hana', 'female given name'],
#  'Mumford': ['Q16877603', 'Mumford', 'family name'],
#  'Griff': ['Q165349',
#   'Frederick, Prince of Wales',
#   'heir apparent to the British throne from 1727 until his death'],
#  'Grey': ['Q42519',
#   'grey',
#   'intermediate color between black and white; for e.g. color of a cloud-covered sky, ash and lead'],
#  'Ola': ['Q209685', 'stearic acid', 'chemical compound'],
#  'Oasis': ['Q786014',
#   'rest area',
#   'public area, usually adjacent to limited-access highway, used for rest from travel'],
#  'Oceán': ['Q9430', 'ocean', 'very large body of saline water'],
#  'Foxy': ['Q2983762',
#   '5-methoxy-N,N-diisopropyltryptamine',
#   'chemical compound'],
#  'Florence': ['Q2044', 'Florence', 'Italian city, located in Tuscany'],
#  'Fred Roberts': ['Q1622327', 'Fred Roberts', 'basketball player'],
#  'Gentleman': ['Q8441', 'man', 'male adult human'],
#  'Future': ['Q344',
#   'future',
#   'events, developments or states in time which has yet to occur'],
#  'Noga': ['Q27876758', 'Noga', 'family name'],
#  'Žalman': ['Q18600514',
#   'Žalman',
#   'memorable tree in Karlovy Vary District, Czech Republic']}

# %%
spravne = ['Jaromír Nohavica','Emma Smetana','Dara Rolins','Avicii','Deethane','Radim Hladík','Vojtěch Dyk','František Segrado','David Guetta','Bára Tlučhořová','Discoboys','Tiësto','Ty Nikdy','Jaroslav Svěcený','Jaroslav Uhlíř','Michal Horáček','Fattypillow','Pavel Šporcl','Přemek Forejt','Ondřej G. Brzobohatý','Robin Schulz','Ondřej Brzobohatý','Martina Pártlová','David Guetta','André Rieu','Bára Tlučhořová','Tiësto','Bob Sinclair','Discoboys','Michal Horáček','Andrea Kalousová','Sára Milfajtová','Bryan Adams','Tomáš Hanák','Jana Boušková','Jaroslav Svěcený','Jaroslav Uhlíř','Magdalena Kožená','Karolína Krézlová','Pavel Šporcl','Gregory Porter']

# %%
for key, val in qecka.items():
    if not val[2]:
        print(f"{key}")
# Out:
# Rybičky 48
# Chainsmokers
# Atmo Music
# Guetta David
# Guru Josh Project
# Walda Gang
# Cruz Taio
# Airfare
# The Silver Spoons
# Robin Zoot
# Band Aid Ii.
# Doctor P.P.
# Gaudino Alex
# Medjmedj Sofian
# Wolf Laurent
# Stein27
# Linakaro
# Joy Vance
# Kamakawiwo´ Ole Israel
# Kingston Sean
# Hodiny
# Hilson Keri
# Joe Face
# Grey256
# Matej Smutný
# Coco Jambo
# Scherzinger Nicole
# Dione Aura
# Deaf Heart
# Robin Mood
# Czech It
# Ryan Kate
# Tiggi Hawke
# Za100Let
# Hard Rico
# Mena Maria
# Michael Burian
# Sparks Jordin
# Mind Michael
# Ingrosso Sebastian
# The Carsleepers
# Mccoy Travie
# Avidan Asaf
# Wolf Karl
# K´ Naan
# Last Goodnight
# Kid Laroi
# Vadak
# Andrews Michael
# Nykki
# Rowland Kelly
# Guetta David Vs. The Egg
# Onemanshow Foundation
# Popcorn Drama
# Dollar Prync
# E2 Crew
# Gym Class Heros
# Pam Rabbit
# We On The Moon
# Lloyd Cher
# Vibekingz
# Vojtaano
# Refew
# Lota Jana
# Mount Cashmore
# Webbe Simon
# Lenka Nová
# Puppet Generation
# Pokora Matt
# Psycho Rhyme
# Porsche Boy
# Laidback Luke Vs. Example
# Šafařík Daniel
# Šenková Leona
# Šinkorová D.
# Wesome
# Wolfhooker John
# Lily Amelia
# Rakovicky
# Rahman A.R.
# Robert Burian
# Strumbellas
# Superstar 2009
# Nerez
# Simon From Deep Divas
# Morrison James
# Sia Diplo Labrinth
# Molly Petersson Hammar
# Sinclair Didier
# Tavares David
# Teló Michel
# Samson Sidney
# Torrini Emiliana
# Ropero Jerry
# Tribbs
# Moss Kena
# Roby Lion
# One Night Band
# Orrico Stacie
# Mark Dann
# Mcclarnon Liz
# Rudolf Kevin
# Noel Sak
# - Universal Music
# Blige Mary J.
# Hansard Glen
# Bomfunk Mcďs
# Buena Mutya
# Bălan Dan
# Bimbo Jones
# Avaion
# Janota Adam
# Bek Ofis
# I.M.T.Smile
# I Am Kuba
# Berry Maty
# Houston Whitney
# Kroeger Chad
# Duncan And Wilde
# Domi Band
# Dj Kadr
# Dj Boccelli
# Declan J Donovan
# Forks Jasper
# Fobia Kid
# Charming Horses
# Fiedlerski
# Fiasco Lupe
# Felix  Jaehn
# Clean Bandit Ft. Louisa Johnson
# Clockclock
# Cocoman
# Crapfruit
# Andy Cermak
# Annet Charitonova
# Aj Brix
# Jickson
# 2Choice
# Koyu Deniz
# 4 Tenoři
# Yeal Main
# Afrojack Ft. Wrabel
# Churaq Sputnik
# Clamaran Antoine
# Adolfeen
# Cincotti Peter
# Cico Band
# Carrie Kirsten
# Deluna Kat
# Denis First
# Capella Mariana
# Simons Eva
# Sinclair Bob
# Calin Fadex
# Albi John Brix
# Xx_Lucenzo
# Charai Sophia
# Reid Alyssa
# Óčko Allstars
# Zdena Predná
# Daniel Mrózek
# 4Tet
# Ro(C)K Podvraťáků-Zpívá V.Dyk
# David Guetta, Mista Jam
# David Freedom
# Darell Dave
# Zoči Voči
# 7 Ladies
# Damichi
# Royal Freakz
# Rhymes Busta
# Cornell Chris
# Rezai Ramin
# Sanchez Roger
# 2Kbaby
# D-Lete Funk-K
# Crossband
# Rybak Alexander
# Skinny Barber
# Bareilles Sara
# Battaglia Kaci
# Tomas Robin
# Tome Prince
# Basiková Bára
# Václav Rouček
# Toneless
# Torye Sivan
# Totally Nothin
# Bernasconi Rico
# Timberlake Justin
# Anika Iris
# Všichni Svatí
# Tisdale Ashley
# Beachbag
# Van Buuren Armin
# Avicii Vs. Nicky Romero
# Urban Keith
# Vivaldianno
# Astralkid22
# Arundo Quartet
# Arian730
# Aquababes
# Balan Dan
# Trautenberk
# Aplin Gabrielle
# Balageband
# Trick Or Threat
# Triko Trako
# B-Side Band
# Twan Ray
# Bruno Pietri
# Starzoom
# Brown Havana
# Brown Charlie
# Sue Selah
# Bregovic Goran
# Summer All Stars
# Breakz
# Specialbeatz
# Cab Cris
# Bůhví
# Sparro Sam
# Sofia Kalberg
# Bugg Jake
# The Atavists
# Bisbal David
# Thomas Natasha
# Amon Amarath
# Tea Sofia
# Suvereno
# Wildvibes
# Bobby Karotka
# Desďree
# Meghan Sheppards
# Martin Hayek
# Ivanna Bagová
# Matt Pardus
# Maynard Conor
# Jaro Smejkal
# Mcfadden Brian
# Meizyy
# Mikuláš Hrbáček
# Miloš Novotný
# Hodor Liviu
# Hoboes
# Hills 97
# Henry Moodie
# Mellow Power
# Memorial Kreyson
# Mendler Bridgit
# Merriweather Daniel
# Iby Pop
# Michael Jackson Ft. Justin Timberlake
# Little Mix Vs. Missy Elliott
# Lil Grippie
# Kassel Alex
# Lil´ Wayne
# Lima Gusttavo
# Limetall
# Lion Of Ido
# Komajota
# Kris Kross Amsterdam, Shaggy
# Kygo, Avicii
# Krausberry
# Kotlár Security
# Klara.
# Ld X Yzomandias
# Kin Chi Kat
# Kills Natalia
# Jižní Pól
# Macca Wiles
# Madskill
# Jessie J, Ariana Grande, Nicki Minaj
# Majkjepan
# Mamba Dasha
# Jayne Erika
# Jax Jones, Martin Solveig, Raye
# John Gibbson
# Johnson Jack
# Luca Brassi10X
# Lopez Sasha
# Justin Bieber Feat, Ludacris
# Johnson Paul
# Jordan Alexis
# Jon Marianek
# Johny Rainbow
# Lukáš Chromek
# Hayes Darren
# Harlej
# Erza George
# Emma Louise Wankelmut
# Emerald Caro
# Evropa 2 All Stars Team 2022
# Osment Emily
# Fider Peter
# Fešáci
# Ferrari Alex
# Pallot Nerina
# Palmer Robert
# Pulse Tom
# Dj Rockstar
# R3Hab, Clara Mae
# Dizm Tay
# Ramirez Robert
# Dimzy
# Ranx Jutty
# Rascal Dizzee
# Diesel Jay
# Prowizorium
# Eddie Fresco
# Phillips Phillip
# Pitbull Feat Chris Brown
# Pjay Cz
# Pop David
# Gough Ivan
# Neno 1312
# Glockenbach
# Nesbitt Nina
# Gigi D'Agostino, Vize
# Naughton Naturi
# Gába Al Dhaba
# Hakimali
# Mousse T. Vs. Dandy Warhols
# Mr. Le Monde
# Mraz Jason
# Gufrau
# Naflexx
# Naim Yael
# Nicky Blitz
# Nový Orchestr Jaroslava Ježka
# O'Donis Colby
# Oakenfold Paul
# Foxx Ray
# Forest Blunt
# Ondray
# Ondřej Ruml
# Fizistyle
# Generace O
# Gates Gareth
# Gabry Ponte, Lum!X
# Nika Karch
# Nikita Kingston
# Nilsen Kurt
# No Pan!C

# %%
opravy = {'Obří Broskev': 'Q12042097',
 'Fešáci': 'Q12006120',
 'Vláďa Hron': 'Q11905431',
 'Děda Mládek Ilegal Band': 'Q1266721',
 'Basiková Bára': 'Q7472854',
 'Nerez': 'Q12040732',
 'Neřež': 'Q12040879',
 'Cocotte Minute': 'Q11773587',
 'Drake': 'Q33240',
 'Lisa': 'Q26707663',
 'Fiedlerski': 'Q114388633',
 'Kryštof': 'Q6774073',
 'Y2K': 'Q66937797',
 'Topic': 'Q20804322',
 'Script': 'Q459585',
 'Shouse': 'Q107478988',
 'Sigala': 'Q20973111',
 'Omi': 'Q18510281',
 'Koky': 'Q107782406',
 'Lucie': 'Q4963472',
 'Verona': 'Q3496586',
 'Anna K.': 'Q3508515',
 'O5': 'Q12041806',
 'Petr Kolář': 'Q12044915',
 'Mig 21': 'Q3062747',
 'Ego': 'Q12765182',
 'Kristina': 'Q430744',
 'Voxel': 'Q19602849',
 'Lenny': 'Q15249858',
 'Jelen': 'Q19820296',
 'Udg': 'Q9363989',
 'Clou': 'Q3508418',
 'Lipo': 'Q12033603',
 'Sebastian': 'Q93945457',
 'Mirai': 'Q51007660',
 'Lake Malawi': 'Q21874590',
 'Peter Nagy': 'Q721760',
 'Tina': 'Q12058991',
 'J.A.R.': 'Q12022161',
 'Calin': 'Q113000776',
 'Monkey Business': 'Q1572459',
 'Alice Springs': 'Q15220322',
 'Rest': 'Q12049263',
 'Queen': 'Q15862',
 'Anna Jiřina': 'Q12025003',
 'Mista': 'Q12038112',
 'Smack': 'Q18042809',
 'Citron': 'Q11773549',
 'Milion+': 'Q101418887',
 'Kali': 'Q18014983',
 'Sima': 'Q14788904',
 'Olympic': 'Q836316',
 'Gleb': 'Q50737405',
 'Dj Wich': 'Q5205502',
 'Hasan': 'Q105423912',
 'Konex': 'Q21041087',
 'Tereza Mašková': 'Q54936095',
 'Separ': 'Q15905720',
 'Vesna': 'Q116540455',
 'Memphis': 'Q17573669',
 'Michal Horák': 'Q87750083',
 'Svěrák': 'Q169065',
 'Madonna': 'Q1744',
 'Momo': 'Q12771912',
 'Turbo': 'Q12059895',
 'Traktor': 'Q18915770',
 'Zagorová': 'Q3507535',
 'Maniak': 'Q102259889',
 'Maduar': 'Q350376',
 'Annabelle': 'Q104973309',
 'Anne-Marie': 'Q25396976',
 'Nohavica': 'Q942232',
 'Radim Hladík': 'Q3566227',
 'Gladiator': 'Q349698',
 'Elis': 'Q684837',
 'D.Y.K.': 'Q11925857',
 'Petr Novák': 'Q3507475',
 'Deethane': 'Q69481982',
 'David Michal': 'Q3506625',
 'Priessnitz': 'Q1571044',
 'Leon': 'Q22278840',
 'Shalom': 'Q45280',
 'Lindemann': 'Q19612750',
 'Skyline': 'Q2156270',
 'Metro Boomin': 'Q16235273',
 'Szabo Peter': 'Szabo Peter',
 'Misha': 'Q3561477',
 'Tool': 'Q184827',
 'Müller': 'Q1373537',
 'Sheen': 'Q75939796',
 'Muse': 'Q22151',
 'Pekař': 'Q30153021',
 'Jan Křížek': 'Q29966329',
 'James Bay': 'Q17811637',
 'Argema': 'Q10855450',
 'Cann': 'Q3495406',
 'Hex': 'Q730601',
 'Bow Wave': 'Q13583891',
 'Goodfellas': 'Q15729998',
 'František Segrado': 'Q46094764',
 'Doga': 'Q60600348',
 'ACDC': 'Q27593',
 'Koa': 'Q12029682',
 'Dommi': 'Q110157843',
 'Sunshine': 'Q12057236',
 'Carter': 'Q301818',
 'Cavalier': 'Q115893508',
 'Dido': 'Q202550',
 'Southpaw': 'Q12055484',
 'Damiens': 'Q11774142',
 'Scorpions': 'Q124147',
 'Vojta D': 'Q11925857',
 'Vltava': 'Q11918168',
 'Žalman': 'Q10270121',
 'Abraxas': 'Q3565031',
 'Absolonová': 'Q3508501',
 'České Srdce': 'Q42709632',
 'Yvonne Sanchez': 'Q10856985',
 'Bobr': 'Q19941635',
 'Vanessa': 'Q26335890',
 'Banket': 'Q3565119',
 'Bastille': 'Q689',
 'James Harries': 'Q12022357',
 'Matadors': 'Q3504469',
 'Mumford': 'Q953918',
 'Placebo': 'Q484839',
 'Petr Poláček': 'Q12045008',
 'Fellas': 'Q15729998',
 'Five O´Clock Tea': 'Q8501198',
 'Embassy': 'Q7731860',
 'Redl': 'Q7939029',
 'Rebels': 'Q12049012',
 'Rangers': 'Q3508537',
 'Psh': 'Q2786669',
 'Niceland': 'Q12040895',
 'Neruda': 'Q12040742',
 'Hematom': 'Q1642053',
 'Highland': 'Q222796',
 'Future': 'Q3445057',
 'Pain': 'Q206378',
 'Gojira': 'Q1011412',
 'Offspring': 'Q157041',
 'Oceán': 'Q11795631',
 'Kašpárek V Rohlíku': 'Q8311588',
 'Rybičky 48': 'Q12050408',
 'Kamelot':'Q12027773',
'Cruz Taio': 'Q313370',
         'Sigma': 'Q16333772',
         'Last Goodnight': 'Q372706',
         'Kid Laroi':'Q82890761',
         'Alok': 'Q28007321',
         'Gnarls Barkley':'Q726773',
         'Welshly Arms': 'Q28452843',
         'Flipsyde': 'Q761385',
         'Kamakawiwo´ Ole Israel': 'Q42180',
         'Scooter':'Q156255',
         'Seal': 'Q218091',
                 "Milow": "Q784453",
         'Junge Junge': 'Q30589129'}

# %%
nejsou = ['58G',
 'Ak',
 'Amco',
 'Andrea Mea',
 'Balet',
 'Bruno Ferrari',
 'Ceha',
 'Chimera',
 'Coolers',
 'D.N.A.',
 'Dalyb',
 'Daniell',
 'Dar',
 'Darwin',
 'Digital Fever',
 'Dms',
 'Dorian',
 'Eastpark',
 'Egotrip',
 'Eki',
 'Eli',
 'Elizabeth',
 'Elly',
 'Emily',
 'Erion',
 'Frank Wild',
 'Gabriela',
 'Gibon',
 'Grey'
 'Hana',
 'Hank',
 'Hattrick',
 'Heebie Jeebies',
 'Heidi',
 'Horal',
 'Hráč Roku',
 'Ille',
 'Indigo',
 'Indy',
 'Iva',
 'Jan Bartoš',
 'Jean Luc',
 'Jolly Joker',
 'Karlo',
 'Klara',
 'Kocáb',
 'Koukr',
 'L. A.',
 'Le Monde',
 'Lenka',
 'Lenya',
 'Light',
 'Loko Loko',
 'Lokomotiva',
 'Luisa',
 'Mairee',
 'Marcell',
 'Marcus',
 'Marek',
 'Matahari',
 'Mikael',
 'Milion Plus',
 'Naděje',
 'Napořád',
 'Natalie',
 'Nedvědi',
 'Nela',
 'Neny',
 'Nevím',
 'Niko',
 'Nikol',
 'No Guitars',
 'P T K',
 'Patricie',
 'Pestalozzi',
 'Peter Pann',
 'Pilot',
 'Post',
 'Puerto',
 'Reginald',
 'Rodan',
 'Roe-Deer',
 'Rumpál',
 'Sabina',
 'Saul',
 'Sensey',
 'Shimmi',
 'Skardu',
 'Source',
 'Style',
 'Swan',
 'Switch',
 'The Mag',
 'Tibet',
 'Timmy White',
 'Tkx',
 'Top 10',
 'Ty Nikdy',
 'Valerie',
 'Válová',
 'Wen',
 'Zayo',
 'Zemětřesení',
 'Zoo',
 'Čhavorenge',
'Alžběta']

# %% [markdown]
# ## Příprava slovníku

# %%
wikimatro = {}
for key, value in nepochybni.items():
    wikimatro[key] = value[0]
for key, value in opravy.items():
    wikimatro[key] = value
for n in nejsou:
    wikimatro[n] = None

# %% [markdown]
# ## Kdopa nám tam ještě chybí

# %%
import pandas as pd

# %%
data = ["CZ_ALBUMS_TOP_100_mesicni.csv","CZ_SINGLES_DIGITAL_TOP_50__CZ_tydenni.csv","CZ_RADIO_TOP_50_CZ_tydenni.csv"]

# %%
df = pd.DataFrame()
for f in data:
    df = pd.concat([df,pd.read_csv(os.path.join("data",f))])

# %%
zebr = pd.DataFrame(df.groupby('interpret_hlavni')['pozice'].min().nsmallest(5000))
wikimdf = pd.DataFrame.from_dict(wikimatro, orient='index', columns=['id'])
wikimdf['interpret_hlavni'] = wikimdf.index
zebr2 = zebr.merge(wikimdf, on='interpret_hlavni')

# %%
zebr2[(zebr2['id'].isnull())].shape
# Out:
# (104, 3)

# %%
zebr2[(~zebr2['id'].isnull())].shape
# Out:
# (534, 3)

# %%
zebr2[(zebr2['id'].isnull())].head(50)
# Out:
#     interpret_hlavni  pozice    id
# 41             P T K       1  None
# 51                Ak       1  None
# 60            Puerto       1  None
# 99             Karlo       2  None
# 105          Alžběta       2  None
# 125    Digital Fever       3  None
# 131            Light       3  None
# 134      Milion Plus       3  None
# 143         Le Monde       4  None
# 157           Dorian       4  None
# 159             Ceha       5  None
# 163              58G       5  None
# 167          Daniell       5  None
# 177         Gabriela       6  None
# 178             Nela       6  None
# 179            Dalyb       6  None
# 182      Timmy White       6  None
# 187             Elly       6  None
# 188        Elizabeth       6  None
# 192       Frank Wild       7  None
# 194           Sensey       7  None
# 201           Mikael       7  None
# 215            Rodan       8  None
# 218         Patricie       8  None
# 222         Reginald       9  None
# 226          Coolers       9  None
# 233           Skardu       9  None
# 238           Source      10  None
# 240            Klara      10  None
# 266              Dar      12  None
# 269            Style      12  None
# 271              Tkx      13  None
# 283              Wen      13  None
# 288             Indy      14  None
# 292             Post      14  None
# 297          Valerie      14  None
# 300             Zayo      14  None
# 301          Marcell      14  None
# 304            Marek      15  None
# 305           Top 10      15  None
# 313              Iva      15  None
# 317          Nedvědi      16  None
# 320            Pilot      16  None
# 321           Shimmi      16  None
# 325              Eli      17  None
# 336              Eki      18  None
# 340            Emily      19  None
# 343         Roe-Deer      19  None
# 344             Amco      19  None
# 347        Loko Loko      20  None

# %%
extra_opravy = {
    'Walda Gang': 'Q28837978',
    'Doctor P.P.': 'Q11813331',
    'Atmo Music': 'Q21296181',
    'Robin Zoot':'Q107751694',
    'Chainsmokers':'Q7721993',
    'The Silver Spoons':'Q62678764',
    'Harlej':'Q12019224',
    'Czech It':'Q63365318',
    'Cocoman':'Q95182331',
    'Kurtizány Z 25. Avenue':'Q12031962',
    'Trautenberk':'Q63161631',
    'Atmo Music':'Q21296181',
    'Carrie Kirsten':'Q66614837'
}

# %%
for key, value in extra_opravy.items():
    wikimatro[key] = value

# %%
with open(os.path.join("wikidata","wiki_ids.json"), "w+") as file:
    json.dump(wikimatro, file)
